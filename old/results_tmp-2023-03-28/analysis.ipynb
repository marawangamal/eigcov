# %% [markdown]
# # Analysis

# %%
import os, sys

# Environment setup (equivalent to shell exports)
sys.path.insert(0, os.path.abspath(".."))
os.environ["SSL_CERT_DIR"] = "/etc/ssl/certs"
os.environ.setdefault("OPENCLIP_CACHEDIR", os.path.expandvars("$SCRATCH/openclip"))
# Out:
# '/network/scratch/m/marawan.gamal/openclip'

# %%
# !pip install -q torch numpy matplotlib seaborn pandas peft

# %% [markdown]
# ## Fig.1a: EigCov Estimation Error (Vision)

# %%
import sys
import os
import math
from tqdm import tqdm
from itertools import product

import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sys.path.append("..") # Add src to path
import src.mhas as mhas
from src.vision.task_vectors import LinearizedTaskVector, NonLinearTaskVector


MODELS = ["ViT-B-16", "ViT-L-14"]
# MODELS = ["ViT-B-16"]
DATASETS = ["Cars", "DTD", "EuroSAT", "GTSRB", "MNIST", "SVHN"]
FT_METHODS = ["standard"]
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
BATCH_SIZE = 32
NUM_SAMPLES = 10
MAX_LAYERS = None
RESULTS_ROOT = "../results"
CHECKPOINTS_ROOT = "../checkpoints"
SAVE_PATH = os.path.join(RESULTS_ROOT, f"eigcov_estimation_error_vision_n{NUM_SAMPLES}_b{BATCH_SIZE}.csv")

param_name_to_module_name = lambda name: "image_encoder." + name.replace(".weight", "")
def dist_cos_noabs(A: torch.Tensor, B: torch.Tensor, *args, **kwargs) -> torch.Tensor:
    a = A.flatten()
    b = B.flatten()
    cos_theta = torch.dot(a, b) / (a.norm() * b.norm())
    return (1 - cos_theta)

max_layers_per_combo = MAX_LAYERS + 1 if MAX_LAYERS is not None else None
TOTAL = len(MODELS) * len(FT_METHODS) * len(DATASETS) * (max_layers_per_combo or 0)
global_step = 0

rows = []
for model_name in MODELS:
    results_dir = os.path.join(RESULTS_ROOT, model_name)
    checkpoint_dir = os.path.join(CHECKPOINTS_ROOT, model_name)
    # checkpoint_dir = f"../checkpoints/{model_name}"

    for ft_method, dataset in product(FT_METHODS, DATASETS):
        # Load covariance
        covs = np.load(f"{results_dir}/covariances_strain_n{NUM_SAMPLES}_b{BATCH_SIZE}_tsm_attnsplit_efull_ft{ft_method}/covariance_{dataset}.npz", allow_pickle=True)

        # Load task vector
        if ft_method == "linear":
            pretrained_checkpoint = f"{checkpoint_dir}/{dataset}Val/linear_zeroshot.pt"
            finetuned_checkpoint = f"{checkpoint_dir}/{dataset}Val/linear_finetuned.pt"
            pretrained_nonlinear_checkpoint = f"{checkpoint_dir}/{dataset}Val/zeroshot.pt"

            nonlinear_encoder = torch.load(
                pretrained_nonlinear_checkpoint, map_location="cpu", weights_only=False
            )
            param_names = [n for n, _ in nonlinear_encoder.named_parameters()]
            del nonlinear_encoder

            tv = LinearizedTaskVector(
                pretrained_checkpoint,
                finetuned_checkpoint,
            )
            encoder = tv.apply_to_nonlinear(
                pretrained_nonlinear_checkpoint, param_names, scaling_coef=1.0
            )
            task_vector = NonLinearTaskVector(
                vector=encoder.state_dict(),
            )
        elif ft_method == "lora":
            pretrained_checkpoint = f"{checkpoint_dir}/{dataset}Val/zeroshot.pt"
            finetuned_checkpoint = f"{checkpoint_dir}/{dataset}Val/lora_finetuned.pt"
            task_vector = NonLinearTaskVector(
                pretrained_checkpoint,
                finetuned_checkpoint,
            )
        else:
            pretrained_checkpoint = f"{checkpoint_dir}/{dataset}Val/zeroshot.pt"
            finetuned_checkpoint = f"{checkpoint_dir}/{dataset}Val/finetuned.pt"
            task_vector = NonLinearTaskVector(
                pretrained_checkpoint,
                finetuned_checkpoint,
            )

        task_vector = task_vector.map(mhas.copy_from_pytorch_state_dict)

        num_added = 0
        if TOTAL == 0 and MAX_LAYERS is None:
            TOTAL = len(MODELS) * len(FT_METHODS) * len(DATASETS) * len(task_vector.vector)
        for k, m in task_vector.vector.items():
            kp = param_name_to_module_name(k)
            if len(m.shape) != 2 or kp not in covs.keys():
                continue
            m = m.to(DEVICE)
            c = torch.from_numpy(covs[kp]).to(m.dtype).to(DEVICE)
            c_hat_ident = torch.eye(c.shape[0], c.shape[1], dtype=c.dtype, device=DEVICE)
            c_hat_ec = m.T @ m
            c_hat_rand = torch.randn_like(c, device=DEVICE)
            for method, c_hat in [
                ("EigenCov", c_hat_ec),
                ("Random", c_hat_rand),
                ("Identity", c_hat_ident),
            ]:
                rows.append({
                    "model": model_name, "dataset": dataset, "layer_name": k,
                    "layer_idx": num_added, "method": method,
                    "error": dist_cos_noabs(c, c_hat).item(), "ft_method": ft_method,
                })
            global_step += 1
            print(f"[{global_step}/{TOTAL}] {model_name} | {ft_method} | {dataset} | layer {num_added} | {k.split('.')[-2]}")
            num_added += 1
            if MAX_LAYERS is not None and num_added > MAX_LAYERS:
                break

# Save
df = pd.DataFrame(rows)
df.to_csv(SAVE_PATH, index=False)
# Out:
# [1/2472] ViT-B-16 | standard | Cars | layer 0 | c_fc
# [2/2472] ViT-B-16 | standard | Cars | layer 1 | c_proj
# [3/2472] ViT-B-16 | standard | Cars | layer 2 | c_fc
# [4/2472] ViT-B-16 | standard | Cars | layer 3 | c_proj
# [5/2472] ViT-B-16 | standard | Cars | layer 4 | c_fc
# [6/2472] ViT-B-16 | standard | Cars | layer 5 | c_proj
# [7/2472] ViT-B-16 | standard | Cars | layer 6 | c_fc
# [8/2472] ViT-B-16 | standard | Cars | layer 7 | c_proj
# [9/2472] ViT-B-16 | standard | Cars | layer 8 | c_fc
# [10/2472] ViT-B-16 | standard | Cars | layer 9 | c_proj
# [11/2472] ViT-B-16 | standard | Cars | layer 10 | c_fc
# [12/2472] ViT-B-16 | standard | Cars | layer 11 | c_proj
# [13/2472] ViT-B-16 | standard | Cars | layer 12 | c_fc
# [14/2472] ViT-B-16 | standard | Cars | layer 13 | c_proj
# [15/2472] ViT-B-16 | standard | Cars | layer 14 | c_fc
# [16/2472] ViT-B-16 | standard | Cars | layer 15 | c_proj
# [17/2472] ViT-B-16 | standard | Cars | layer 16 | c_fc
# [18/2472] ViT-B-16 | standard | Cars | layer 17 | c_proj
# [19/2472] ViT-B-16 | standard | Cars | layer 18 | c_fc
# [20/2472] ViT-B-16 | standard | Cars | layer 19 | c_proj
# [21/2472] ViT-B-16 | standard | Cars | layer 20 | c_fc
# [22/2472] ViT-B-16 | standard | Cars | layer 21 | c_proj
# [23/2472] ViT-B-16 | standard | Cars | layer 22 | c_fc
# [24/2472] ViT-B-16 | standard | Cars | layer 23 | c_proj
# [25/2472] ViT-B-16 | standard | Cars | layer 24 | q
# [26/2472] ViT-B-16 | standard | Cars | layer 25 | k
# [27/2472] ViT-B-16 | standard | Cars | layer 26 | v
# [28/2472] ViT-B-16 | standard | Cars | layer 27 | o
# [29/2472] ViT-B-16 | standard | Cars | layer 28 | q
# [30/2472] ViT-B-16 | standard | Cars | layer 29 | k
# [31/2472] ViT-B-16 | standard | Cars | layer 30 | v
# [32/2472] ViT-B-16 | standard | Cars | layer 31 | o
# [33/2472] ViT-B-16 | standard | Cars | layer 32 | q
# [34/2472] ViT-B-16 | standard | Cars | layer 33 | k
# [35/2472] ViT-B-16 | standard | Cars | layer 34 | v
# [36/2472] ViT-B-16 | standard | Cars | layer 35 | o
# [37/2472] ViT-B-16 | standard | Cars | layer 36 | q
# [38/2472] ViT-B-16 | standard | Cars | layer 37 | k
# [39/2472] ViT-B-16 | standard | Cars | layer 38 | v
# [40/2472] ViT-B-16 | standard | Cars | layer 39 | o
# [41/2472] ViT-B-16 | standard | Cars | layer 40 | q
# [42/2472] ViT-B-16 | standard | Cars | layer 41 | k
# [43/2472] ViT-B-16 | standard | Cars | layer 42 | v
# [44/2472] ViT-B-16 | standard | Cars | layer 43 | o
# [45/2472] ViT-B-16 | standard | Cars | layer 44 | q
# [46/2472] ViT-B-16 | standard | Cars | layer 45 | k
# [47/2472] ViT-B-16 | standard | Cars | layer 46 | v
# [48/2472] ViT-B-16 | standard | Cars | layer 47 | o
# [49/2472] ViT-B-16 | standard | Cars | layer 48 | q
# [50/2472] ViT-B-16 | standard | Cars | layer 49 | k
# [51/2472] ViT-B-16 | standard | Cars | layer 50 | v
# [52/2472] ViT-B-16 | standard | Cars | layer 51 | o
# [53/2472] ViT-B-16 | standard | Cars | layer 52 | q
# [54/2472] ViT-B-16 | standard | Cars | layer 53 | k
# [55/2472] ViT-B-16 | standard | Cars | layer 54 | v
# [56/2472] ViT-B-16 | standard | Cars | layer 55 | o
# [57/2472] ViT-B-16 | standard | Cars | layer 56 | q
# [58/2472] ViT-B-16 | standard | Cars | layer 57 | k
# [59/2472] ViT-B-16 | standard | Cars | layer 58 | v
# [60/2472] ViT-B-16 | standard | Cars | layer 59 | o
# [61/2472] ViT-B-16 | standard | Cars | layer 60 | q
# [62/2472] ViT-B-16 | standard | Cars | layer 61 | k
# [63/2472] ViT-B-16 | standard | Cars | layer 62 | v
# [64/2472] ViT-B-16 | standard | Cars | layer 63 | o
# [65/2472] ViT-B-16 | standard | Cars | layer 64 | q
# [66/2472] ViT-B-16 | standard | Cars | layer 65 | k
# [67/2472] ViT-B-16 | standard | Cars | layer 66 | v
# [68/2472] ViT-B-16 | standard | Cars | layer 67 | o
# [69/2472] ViT-B-16 | standard | Cars | layer 68 | q
# [70/2472] ViT-B-16 | standard | Cars | layer 69 | k
# [71/2472] ViT-B-16 | standard | Cars | layer 70 | v
# [72/2472] ViT-B-16 | standard | Cars | layer 71 | o
# [73/2472] ViT-B-16 | standard | DTD | layer 0 | c_fc
# [74/2472] ViT-B-16 | standard | DTD | layer 1 | c_proj
# [75/2472] ViT-B-16 | standard | DTD | layer 2 | c_fc
# [76/2472] ViT-B-16 | standard | DTD | layer 3 | c_proj
# [77/2472] ViT-B-16 | standard | DTD | layer 4 | c_fc
# [78/2472] ViT-B-16 | standard | DTD | layer 5 | c_proj
# [79/2472] ViT-B-16 | standard | DTD | layer 6 | c_fc
# [80/2472] ViT-B-16 | standard | DTD | layer 7 | c_proj
# [81/2472] ViT-B-16 | standard | DTD | layer 8 | c_fc
# [82/2472] ViT-B-16 | standard | DTD | layer 9 | c_proj
# [83/2472] ViT-B-16 | standard | DTD | layer 10 | c_fc
# [84/2472] ViT-B-16 | standard | DTD | layer 11 | c_proj
# [85/2472] ViT-B-16 | standard | DTD | layer 12 | c_fc
# [86/2472] ViT-B-16 | standard | DTD | layer 13 | c_proj
# [87/2472] ViT-B-16 | standard | DTD | layer 14 | c_fc
# [88/2472] ViT-B-16 | standard | DTD | layer 15 | c_proj
# [89/2472] ViT-B-16 | standard | DTD | layer 16 | c_fc
# [90/2472] ViT-B-16 | standard | DTD | layer 17 | c_proj
# [91/2472] ViT-B-16 | standard | DTD | layer 18 | c_fc
# [92/2472] ViT-B-16 | standard | DTD | layer 19 | c_proj
# [93/2472] ViT-B-16 | standard | DTD | layer 20 | c_fc
# [94/2472] ViT-B-16 | standard | DTD | layer 21 | c_proj
# [95/2472] ViT-B-16 | standard | DTD | layer 22 | c_fc
# [96/2472] ViT-B-16 | standard | DTD | layer 23 | c_proj
# [97/2472] ViT-B-16 | standard | DTD | layer 24 | q
# [98/2472] ViT-B-16 | standard | DTD | layer 25 | k
# [99/2472] ViT-B-16 | standard | DTD | layer 26 | v
# [100/2472] ViT-B-16 | standard | DTD | layer 27 | o
# [101/2472] ViT-B-16 | standard | DTD | layer 28 | q
# [102/2472] ViT-B-16 | standard | DTD | layer 29 | k
# [103/2472] ViT-B-16 | standard | DTD | layer 30 | v
# [104/2472] ViT-B-16 | standard | DTD | layer 31 | o
# [105/2472] ViT-B-16 | standard | DTD | layer 32 | q
# [106/2472] ViT-B-16 | standard | DTD | layer 33 | k
# [107/2472] ViT-B-16 | standard | DTD | layer 34 | v
# [108/2472] ViT-B-16 | standard | DTD | layer 35 | o
# [109/2472] ViT-B-16 | standard | DTD | layer 36 | q
# [110/2472] ViT-B-16 | standard | DTD | layer 37 | k
# [111/2472] ViT-B-16 | standard | DTD | layer 38 | v
# [112/2472] ViT-B-16 | standard | DTD | layer 39 | o
# [113/2472] ViT-B-16 | standard | DTD | layer 40 | q
# [114/2472] ViT-B-16 | standard | DTD | layer 41 | k
# [115/2472] ViT-B-16 | standard | DTD | layer 42 | v
# [116/2472] ViT-B-16 | standard | DTD | layer 43 | o
# [117/2472] ViT-B-16 | standard | DTD | layer 44 | q
# [118/2472] ViT-B-16 | standard | DTD | layer 45 | k
# [119/2472] ViT-B-16 | standard | DTD | layer 46 | v
# [120/2472] ViT-B-16 | standard | DTD | layer 47 | o
# [121/2472] ViT-B-16 | standard | DTD | layer 48 | q
# [122/2472] ViT-B-16 | standard | DTD | layer 49 | k
# [123/2472] ViT-B-16 | standard | DTD | layer 50 | v
# [124/2472] ViT-B-16 | standard | DTD | layer 51 | o
# [125/2472] ViT-B-16 | standard | DTD | layer 52 | q
# [126/2472] ViT-B-16 | standard | DTD | layer 53 | k
# [127/2472] ViT-B-16 | standard | DTD | layer 54 | v
# [128/2472] ViT-B-16 | standard | DTD | layer 55 | o
# [129/2472] ViT-B-16 | standard | DTD | layer 56 | q
# [130/2472] ViT-B-16 | standard | DTD | layer 57 | k
# [131/2472] ViT-B-16 | standard | DTD | layer 58 | v
# [132/2472] ViT-B-16 | standard | DTD | layer 59 | o
# [133/2472] ViT-B-16 | standard | DTD | layer 60 | q
# [134/2472] ViT-B-16 | standard | DTD | layer 61 | k
# [135/2472] ViT-B-16 | standard | DTD | layer 62 | v
# [136/2472] ViT-B-16 | standard | DTD | layer 63 | o
# [137/2472] ViT-B-16 | standard | DTD | layer 64 | q
# [138/2472] ViT-B-16 | standard | DTD | layer 65 | k
# [139/2472] ViT-B-16 | standard | DTD | layer 66 | v
# [140/2472] ViT-B-16 | standard | DTD | layer 67 | o
# [141/2472] ViT-B-16 | standard | DTD | layer 68 | q
# [142/2472] ViT-B-16 | standard | DTD | layer 69 | k
# [143/2472] ViT-B-16 | standard | DTD | layer 70 | v
# [144/2472] ViT-B-16 | standard | DTD | layer 71 | o
# [145/2472] ViT-B-16 | standard | EuroSAT | layer 0 | c_fc
# [146/2472] ViT-B-16 | standard | EuroSAT | layer 1 | c_proj
# [147/2472] ViT-B-16 | standard | EuroSAT | layer 2 | c_fc
# [148/2472] ViT-B-16 | standard | EuroSAT | layer 3 | c_proj
# [149/2472] ViT-B-16 | standard | EuroSAT | layer 4 | c_fc
# [150/2472] ViT-B-16 | standard | EuroSAT | layer 5 | c_proj
# [151/2472] ViT-B-16 | standard | EuroSAT | layer 6 | c_fc
# [152/2472] ViT-B-16 | standard | EuroSAT | layer 7 | c_proj
# [153/2472] ViT-B-16 | standard | EuroSAT | layer 8 | c_fc
# [154/2472] ViT-B-16 | standard | EuroSAT | layer 9 | c_proj
# [155/2472] ViT-B-16 | standard | EuroSAT | layer 10 | c_fc
# [156/2472] ViT-B-16 | standard | EuroSAT | layer 11 | c_proj
# [157/2472] ViT-B-16 | standard | EuroSAT | layer 12 | c_fc
# [158/2472] ViT-B-16 | standard | EuroSAT | layer 13 | c_proj
# [159/2472] ViT-B-16 | standard | EuroSAT | layer 14 | c_fc
# [160/2472] ViT-B-16 | standard | EuroSAT | layer 15 | c_proj
# [161/2472] ViT-B-16 | standard | EuroSAT | layer 16 | c_fc
# [162/2472] ViT-B-16 | standard | EuroSAT | layer 17 | c_proj
# [163/2472] ViT-B-16 | standard | EuroSAT | layer 18 | c_fc
# [164/2472] ViT-B-16 | standard | EuroSAT | layer 19 | c_proj
# [165/2472] ViT-B-16 | standard | EuroSAT | layer 20 | c_fc
# [166/2472] ViT-B-16 | standard | EuroSAT | layer 21 | c_proj
# [167/2472] ViT-B-16 | standard | EuroSAT | layer 22 | c_fc
# [168/2472] ViT-B-16 | standard | EuroSAT | layer 23 | c_proj
# [169/2472] ViT-B-16 | standard | EuroSAT | layer 24 | q
# [170/2472] ViT-B-16 | standard | EuroSAT | layer 25 | k
# [171/2472] ViT-B-16 | standard | EuroSAT | layer 26 | v
# [172/2472] ViT-B-16 | standard | EuroSAT | layer 27 | o
# [173/2472] ViT-B-16 | standard | EuroSAT | layer 28 | q
# [174/2472] ViT-B-16 | standard | EuroSAT | layer 29 | k
# [175/2472] ViT-B-16 | standard | EuroSAT | layer 30 | v
# [176/2472] ViT-B-16 | standard | EuroSAT | layer 31 | o
# [177/2472] ViT-B-16 | standard | EuroSAT | layer 32 | q
# [178/2472] ViT-B-16 | standard | EuroSAT | layer 33 | k
# [179/2472] ViT-B-16 | standard | EuroSAT | layer 34 | v
# [180/2472] ViT-B-16 | standard | EuroSAT | layer 35 | o
# [181/2472] ViT-B-16 | standard | EuroSAT | layer 36 | q
# [182/2472] ViT-B-16 | standard | EuroSAT | layer 37 | k
# [183/2472] ViT-B-16 | standard | EuroSAT | layer 38 | v
# [184/2472] ViT-B-16 | standard | EuroSAT | layer 39 | o
# [185/2472] ViT-B-16 | standard | EuroSAT | layer 40 | q
# [186/2472] ViT-B-16 | standard | EuroSAT | layer 41 | k
# [187/2472] ViT-B-16 | standard | EuroSAT | layer 42 | v
# [188/2472] ViT-B-16 | standard | EuroSAT | layer 43 | o
# [189/2472] ViT-B-16 | standard | EuroSAT | layer 44 | q
# [190/2472] ViT-B-16 | standard | EuroSAT | layer 45 | k
# [191/2472] ViT-B-16 | standard | EuroSAT | layer 46 | v
# [192/2472] ViT-B-16 | standard | EuroSAT | layer 47 | o
# [193/2472] ViT-B-16 | standard | EuroSAT | layer 48 | q
# [194/2472] ViT-B-16 | standard | EuroSAT | layer 49 | k
# [195/2472] ViT-B-16 | standard | EuroSAT | layer 50 | v
# [196/2472] ViT-B-16 | standard | EuroSAT | layer 51 | o
# [197/2472] ViT-B-16 | standard | EuroSAT | layer 52 | q
# [198/2472] ViT-B-16 | standard | EuroSAT | layer 53 | k
# [199/2472] ViT-B-16 | standard | EuroSAT | layer 54 | v
# [200/2472] ViT-B-16 | standard | EuroSAT | layer 55 | o
# [201/2472] ViT-B-16 | standard | EuroSAT | layer 56 | q
# [202/2472] ViT-B-16 | standard | EuroSAT | layer 57 | k
# [203/2472] ViT-B-16 | standard | EuroSAT | layer 58 | v
# [204/2472] ViT-B-16 | standard | EuroSAT | layer 59 | o
# [205/2472] ViT-B-16 | standard | EuroSAT | layer 60 | q
# [206/2472] ViT-B-16 | standard | EuroSAT | layer 61 | k
# [207/2472] ViT-B-16 | standard | EuroSAT | layer 62 | v
# [208/2472] ViT-B-16 | standard | EuroSAT | layer 63 | o
# [209/2472] ViT-B-16 | standard | EuroSAT | layer 64 | q
# [210/2472] ViT-B-16 | standard | EuroSAT | layer 65 | k
# [211/2472] ViT-B-16 | standard | EuroSAT | layer 66 | v
# [212/2472] ViT-B-16 | standard | EuroSAT | layer 67 | o
# [213/2472] ViT-B-16 | standard | EuroSAT | layer 68 | q
# [214/2472] ViT-B-16 | standard | EuroSAT | layer 69 | k
# [215/2472] ViT-B-16 | standard | EuroSAT | layer 70 | v
# [216/2472] ViT-B-16 | standard | EuroSAT | layer 71 | o
# [217/2472] ViT-B-16 | standard | GTSRB | layer 0 | c_fc
# [218/2472] ViT-B-16 | standard | GTSRB | layer 1 | c_proj
# [219/2472] ViT-B-16 | standard | GTSRB | layer 2 | c_fc
# [220/2472] ViT-B-16 | standard | GTSRB | layer 3 | c_proj
# [221/2472] ViT-B-16 | standard | GTSRB | layer 4 | c_fc
# [222/2472] ViT-B-16 | standard | GTSRB | layer 5 | c_proj
# [223/2472] ViT-B-16 | standard | GTSRB | layer 6 | c_fc
# [224/2472] ViT-B-16 | standard | GTSRB | layer 7 | c_proj
# [225/2472] ViT-B-16 | standard | GTSRB | layer 8 | c_fc
# [226/2472] ViT-B-16 | standard | GTSRB | layer 9 | c_proj
# [227/2472] ViT-B-16 | standard | GTSRB | layer 10 | c_fc
# [228/2472] ViT-B-16 | standard | GTSRB | layer 11 | c_proj
# [229/2472] ViT-B-16 | standard | GTSRB | layer 12 | c_fc
# [230/2472] ViT-B-16 | standard | GTSRB | layer 13 | c_proj
# [231/2472] ViT-B-16 | standard | GTSRB | layer 14 | c_fc
# [232/2472] ViT-B-16 | standard | GTSRB | layer 15 | c_proj
# [233/2472] ViT-B-16 | standard | GTSRB | layer 16 | c_fc
# [234/2472] ViT-B-16 | standard | GTSRB | layer 17 | c_proj
# [235/2472] ViT-B-16 | standard | GTSRB | layer 18 | c_fc
# [236/2472] ViT-B-16 | standard | GTSRB | layer 19 | c_proj
# [237/2472] ViT-B-16 | standard | GTSRB | layer 20 | c_fc
# [238/2472] ViT-B-16 | standard | GTSRB | layer 21 | c_proj
# [239/2472] ViT-B-16 | standard | GTSRB | layer 22 | c_fc
# [240/2472] ViT-B-16 | standard | GTSRB | layer 23 | c_proj
# [241/2472] ViT-B-16 | standard | GTSRB | layer 24 | q
# [242/2472] ViT-B-16 | standard | GTSRB | layer 25 | k
# [243/2472] ViT-B-16 | standard | GTSRB | layer 26 | v
# [244/2472] ViT-B-16 | standard | GTSRB | layer 27 | o
# [245/2472] ViT-B-16 | standard | GTSRB | layer 28 | q
# [246/2472] ViT-B-16 | standard | GTSRB | layer 29 | k
# [247/2472] ViT-B-16 | standard | GTSRB | layer 30 | v
# [248/2472] ViT-B-16 | standard | GTSRB | layer 31 | o
# [249/2472] ViT-B-16 | standard | GTSRB | layer 32 | q
# [250/2472] ViT-B-16 | standard | GTSRB | layer 33 | k
# [251/2472] ViT-B-16 | standard | GTSRB | layer 34 | v
# [252/2472] ViT-B-16 | standard | GTSRB | layer 35 | o
# [253/2472] ViT-B-16 | standard | GTSRB | layer 36 | q
# [254/2472] ViT-B-16 | standard | GTSRB | layer 37 | k
# [255/2472] ViT-B-16 | standard | GTSRB | layer 38 | v
# [256/2472] ViT-B-16 | standard | GTSRB | layer 39 | o
# [257/2472] ViT-B-16 | standard | GTSRB | layer 40 | q
# [258/2472] ViT-B-16 | standard | GTSRB | layer 41 | k
# [259/2472] ViT-B-16 | standard | GTSRB | layer 42 | v
# [260/2472] ViT-B-16 | standard | GTSRB | layer 43 | o
# [261/2472] ViT-B-16 | standard | GTSRB | layer 44 | q
# [262/2472] ViT-B-16 | standard | GTSRB | layer 45 | k
# [263/2472] ViT-B-16 | standard | GTSRB | layer 46 | v
# [264/2472] ViT-B-16 | standard | GTSRB | layer 47 | o
# [265/2472] ViT-B-16 | standard | GTSRB | layer 48 | q
# [266/2472] ViT-B-16 | standard | GTSRB | layer 49 | k
# [267/2472] ViT-B-16 | standard | GTSRB | layer 50 | v
# [268/2472] ViT-B-16 | standard | GTSRB | layer 51 | o
# [269/2472] ViT-B-16 | standard | GTSRB | layer 52 | q
# [270/2472] ViT-B-16 | standard | GTSRB | layer 53 | k
# [271/2472] ViT-B-16 | standard | GTSRB | layer 54 | v
# [272/2472] ViT-B-16 | standard | GTSRB | layer 55 | o
# [273/2472] ViT-B-16 | standard | GTSRB | layer 56 | q
# [274/2472] ViT-B-16 | standard | GTSRB | layer 57 | k
# [275/2472] ViT-B-16 | standard | GTSRB | layer 58 | v
# [276/2472] ViT-B-16 | standard | GTSRB | layer 59 | o
# [277/2472] ViT-B-16 | standard | GTSRB | layer 60 | q
# [278/2472] ViT-B-16 | standard | GTSRB | layer 61 | k
# [279/2472] ViT-B-16 | standard | GTSRB | layer 62 | v
# [280/2472] ViT-B-16 | standard | GTSRB | layer 63 | o
# [281/2472] ViT-B-16 | standard | GTSRB | layer 64 | q
# [282/2472] ViT-B-16 | standard | GTSRB | layer 65 | k
# [283/2472] ViT-B-16 | standard | GTSRB | layer 66 | v
# [284/2472] ViT-B-16 | standard | GTSRB | layer 67 | o
# [285/2472] ViT-B-16 | standard | GTSRB | layer 68 | q
# [286/2472] ViT-B-16 | standard | GTSRB | layer 69 | k
# [287/2472] ViT-B-16 | standard | GTSRB | layer 70 | v
# [288/2472] ViT-B-16 | standard | GTSRB | layer 71 | o
# [289/2472] ViT-B-16 | standard | MNIST | layer 0 | c_fc
# [290/2472] ViT-B-16 | standard | MNIST | layer 1 | c_proj
# [291/2472] ViT-B-16 | standard | MNIST | layer 2 | c_fc
# [292/2472] ViT-B-16 | standard | MNIST | layer 3 | c_proj
# [293/2472] ViT-B-16 | standard | MNIST | layer 4 | c_fc
# [294/2472] ViT-B-16 | standard | MNIST | layer 5 | c_proj
# [295/2472] ViT-B-16 | standard | MNIST | layer 6 | c_fc
# [296/2472] ViT-B-16 | standard | MNIST | layer 7 | c_proj
# [297/2472] ViT-B-16 | standard | MNIST | layer 8 | c_fc
# [298/2472] ViT-B-16 | standard | MNIST | layer 9 | c_proj
# [299/2472] ViT-B-16 | standard | MNIST | layer 10 | c_fc
# [300/2472] ViT-B-16 | standard | MNIST | layer 11 | c_proj
# [301/2472] ViT-B-16 | standard | MNIST | layer 12 | c_fc
# [302/2472] ViT-B-16 | standard | MNIST | layer 13 | c_proj
# [303/2472] ViT-B-16 | standard | MNIST | layer 14 | c_fc
# [304/2472] ViT-B-16 | standard | MNIST | layer 15 | c_proj
# [305/2472] ViT-B-16 | standard | MNIST | layer 16 | c_fc
# [306/2472] ViT-B-16 | standard | MNIST | layer 17 | c_proj
# [307/2472] ViT-B-16 | standard | MNIST | layer 18 | c_fc
# [308/2472] ViT-B-16 | standard | MNIST | layer 19 | c_proj
# [309/2472] ViT-B-16 | standard | MNIST | layer 20 | c_fc
# [310/2472] ViT-B-16 | standard | MNIST | layer 21 | c_proj
# [311/2472] ViT-B-16 | standard | MNIST | layer 22 | c_fc
# [312/2472] ViT-B-16 | standard | MNIST | layer 23 | c_proj
# [313/2472] ViT-B-16 | standard | MNIST | layer 24 | q
# [314/2472] ViT-B-16 | standard | MNIST | layer 25 | k
# [315/2472] ViT-B-16 | standard | MNIST | layer 26 | v
# [316/2472] ViT-B-16 | standard | MNIST | layer 27 | o
# [317/2472] ViT-B-16 | standard | MNIST | layer 28 | q
# [318/2472] ViT-B-16 | standard | MNIST | layer 29 | k
# [319/2472] ViT-B-16 | standard | MNIST | layer 30 | v
# [320/2472] ViT-B-16 | standard | MNIST | layer 31 | o
# [321/2472] ViT-B-16 | standard | MNIST | layer 32 | q
# [322/2472] ViT-B-16 | standard | MNIST | layer 33 | k
# [323/2472] ViT-B-16 | standard | MNIST | layer 34 | v
# [324/2472] ViT-B-16 | standard | MNIST | layer 35 | o
# [325/2472] ViT-B-16 | standard | MNIST | layer 36 | q
# [326/2472] ViT-B-16 | standard | MNIST | layer 37 | k
# [327/2472] ViT-B-16 | standard | MNIST | layer 38 | v
# [328/2472] ViT-B-16 | standard | MNIST | layer 39 | o
# [329/2472] ViT-B-16 | standard | MNIST | layer 40 | q
# [330/2472] ViT-B-16 | standard | MNIST | layer 41 | k
# [331/2472] ViT-B-16 | standard | MNIST | layer 42 | v
# [332/2472] ViT-B-16 | standard | MNIST | layer 43 | o
# [333/2472] ViT-B-16 | standard | MNIST | layer 44 | q
# [334/2472] ViT-B-16 | standard | MNIST | layer 45 | k
# [335/2472] ViT-B-16 | standard | MNIST | layer 46 | v
# [336/2472] ViT-B-16 | standard | MNIST | layer 47 | o
# [337/2472] ViT-B-16 | standard | MNIST | layer 48 | q
# [338/2472] ViT-B-16 | standard | MNIST | layer 49 | k
# [339/2472] ViT-B-16 | standard | MNIST | layer 50 | v
# [340/2472] ViT-B-16 | standard | MNIST | layer 51 | o
# [341/2472] ViT-B-16 | standard | MNIST | layer 52 | q
# [342/2472] ViT-B-16 | standard | MNIST | layer 53 | k
# [343/2472] ViT-B-16 | standard | MNIST | layer 54 | v
# [344/2472] ViT-B-16 | standard | MNIST | layer 55 | o
# [345/2472] ViT-B-16 | standard | MNIST | layer 56 | q
# [346/2472] ViT-B-16 | standard | MNIST | layer 57 | k
# [347/2472] ViT-B-16 | standard | MNIST | layer 58 | v
# [348/2472] ViT-B-16 | standard | MNIST | layer 59 | o
# [349/2472] ViT-B-16 | standard | MNIST | layer 60 | q
# [350/2472] ViT-B-16 | standard | MNIST | layer 61 | k
# [351/2472] ViT-B-16 | standard | MNIST | layer 62 | v
# [352/2472] ViT-B-16 | standard | MNIST | layer 63 | o
# [353/2472] ViT-B-16 | standard | MNIST | layer 64 | q
# [354/2472] ViT-B-16 | standard | MNIST | layer 65 | k
# [355/2472] ViT-B-16 | standard | MNIST | layer 66 | v
# [356/2472] ViT-B-16 | standard | MNIST | layer 67 | o
# [357/2472] ViT-B-16 | standard | MNIST | layer 68 | q
# [358/2472] ViT-B-16 | standard | MNIST | layer 69 | k
# [359/2472] ViT-B-16 | standard | MNIST | layer 70 | v
# [360/2472] ViT-B-16 | standard | MNIST | layer 71 | o
# [361/2472] ViT-B-16 | standard | SVHN | layer 0 | c_fc
# [362/2472] ViT-B-16 | standard | SVHN | layer 1 | c_proj
# [363/2472] ViT-B-16 | standard | SVHN | layer 2 | c_fc
# [364/2472] ViT-B-16 | standard | SVHN | layer 3 | c_proj
# [365/2472] ViT-B-16 | standard | SVHN | layer 4 | c_fc
# [366/2472] ViT-B-16 | standard | SVHN | layer 5 | c_proj
# [367/2472] ViT-B-16 | standard | SVHN | layer 6 | c_fc
# [368/2472] ViT-B-16 | standard | SVHN | layer 7 | c_proj
# [369/2472] ViT-B-16 | standard | SVHN | layer 8 | c_fc
# [370/2472] ViT-B-16 | standard | SVHN | layer 9 | c_proj
# [371/2472] ViT-B-16 | standard | SVHN | layer 10 | c_fc
# [372/2472] ViT-B-16 | standard | SVHN | layer 11 | c_proj
# [373/2472] ViT-B-16 | standard | SVHN | layer 12 | c_fc
# [374/2472] ViT-B-16 | standard | SVHN | layer 13 | c_proj
# [375/2472] ViT-B-16 | standard | SVHN | layer 14 | c_fc
# [376/2472] ViT-B-16 | standard | SVHN | layer 15 | c_proj
# [377/2472] ViT-B-16 | standard | SVHN | layer 16 | c_fc
# [378/2472] ViT-B-16 | standard | SVHN | layer 17 | c_proj
# [379/2472] ViT-B-16 | standard | SVHN | layer 18 | c_fc
# [380/2472] ViT-B-16 | standard | SVHN | layer 19 | c_proj
# [381/2472] ViT-B-16 | standard | SVHN | layer 20 | c_fc
# [382/2472] ViT-B-16 | standard | SVHN | layer 21 | c_proj
# [383/2472] ViT-B-16 | standard | SVHN | layer 22 | c_fc
# [384/2472] ViT-B-16 | standard | SVHN | layer 23 | c_proj
# [385/2472] ViT-B-16 | standard | SVHN | layer 24 | q
# [386/2472] ViT-B-16 | standard | SVHN | layer 25 | k
# [387/2472] ViT-B-16 | standard | SVHN | layer 26 | v
# [388/2472] ViT-B-16 | standard | SVHN | layer 27 | o
# [389/2472] ViT-B-16 | standard | SVHN | layer 28 | q
# [390/2472] ViT-B-16 | standard | SVHN | layer 29 | k
# [391/2472] ViT-B-16 | standard | SVHN | layer 30 | v
# [392/2472] ViT-B-16 | standard | SVHN | layer 31 | o
# [393/2472] ViT-B-16 | standard | SVHN | layer 32 | q
# [394/2472] ViT-B-16 | standard | SVHN | layer 33 | k
# [395/2472] ViT-B-16 | standard | SVHN | layer 34 | v
# [396/2472] ViT-B-16 | standard | SVHN | layer 35 | o
# [397/2472] ViT-B-16 | standard | SVHN | layer 36 | q
# [398/2472] ViT-B-16 | standard | SVHN | layer 37 | k
# [399/2472] ViT-B-16 | standard | SVHN | layer 38 | v
# [400/2472] ViT-B-16 | standard | SVHN | layer 39 | o
# [401/2472] ViT-B-16 | standard | SVHN | layer 40 | q
# [402/2472] ViT-B-16 | standard | SVHN | layer 41 | k
# [403/2472] ViT-B-16 | standard | SVHN | layer 42 | v
# [404/2472] ViT-B-16 | standard | SVHN | layer 43 | o
# [405/2472] ViT-B-16 | standard | SVHN | layer 44 | q
# [406/2472] ViT-B-16 | standard | SVHN | layer 45 | k
# [407/2472] ViT-B-16 | standard | SVHN | layer 46 | v
# [408/2472] ViT-B-16 | standard | SVHN | layer 47 | o
# [409/2472] ViT-B-16 | standard | SVHN | layer 48 | q
# [410/2472] ViT-B-16 | standard | SVHN | layer 49 | k
# [411/2472] ViT-B-16 | standard | SVHN | layer 50 | v
# [412/2472] ViT-B-16 | standard | SVHN | layer 51 | o
# [413/2472] ViT-B-16 | standard | SVHN | layer 52 | q
# [414/2472] ViT-B-16 | standard | SVHN | layer 53 | k
# [415/2472] ViT-B-16 | standard | SVHN | layer 54 | v
# [416/2472] ViT-B-16 | standard | SVHN | layer 55 | o
# [417/2472] ViT-B-16 | standard | SVHN | layer 56 | q
# [418/2472] ViT-B-16 | standard | SVHN | layer 57 | k
# [419/2472] ViT-B-16 | standard | SVHN | layer 58 | v
# [420/2472] ViT-B-16 | standard | SVHN | layer 59 | o
# [421/2472] ViT-B-16 | standard | SVHN | layer 60 | q
# [422/2472] ViT-B-16 | standard | SVHN | layer 61 | k
# [423/2472] ViT-B-16 | standard | SVHN | layer 62 | v
# [424/2472] ViT-B-16 | standard | SVHN | layer 63 | o
# [425/2472] ViT-B-16 | standard | SVHN | layer 64 | q
# [426/2472] ViT-B-16 | standard | SVHN | layer 65 | k
# [427/2472] ViT-B-16 | standard | SVHN | layer 66 | v
# [428/2472] ViT-B-16 | standard | SVHN | layer 67 | o
# [429/2472] ViT-B-16 | standard | SVHN | layer 68 | q
# [430/2472] ViT-B-16 | standard | SVHN | layer 69 | k
# [431/2472] ViT-B-16 | standard | SVHN | layer 70 | v
# [432/2472] ViT-B-16 | standard | SVHN | layer 71 | o
# [433/2472] ViT-L-14 | standard | Cars | layer 0 | c_fc
# [434/2472] ViT-L-14 | standard | Cars | layer 1 | c_proj
# [435/2472] ViT-L-14 | standard | Cars | layer 2 | c_fc
# [436/2472] ViT-L-14 | standard | Cars | layer 3 | c_proj
# [437/2472] ViT-L-14 | standard | Cars | layer 4 | c_fc
# [438/2472] ViT-L-14 | standard | Cars | layer 5 | c_proj
# [439/2472] ViT-L-14 | standard | Cars | layer 6 | c_fc
# [440/2472] ViT-L-14 | standard | Cars | layer 7 | c_proj
# [441/2472] ViT-L-14 | standard | Cars | layer 8 | c_fc
# [442/2472] ViT-L-14 | standard | Cars | layer 9 | c_proj
# [443/2472] ViT-L-14 | standard | Cars | layer 10 | c_fc
# [444/2472] ViT-L-14 | standard | Cars | layer 11 | c_proj
# [445/2472] ViT-L-14 | standard | Cars | layer 12 | c_fc
# [446/2472] ViT-L-14 | standard | Cars | layer 13 | c_proj
# [447/2472] ViT-L-14 | standard | Cars | layer 14 | c_fc
# [448/2472] ViT-L-14 | standard | Cars | layer 15 | c_proj
# [449/2472] ViT-L-14 | standard | Cars | layer 16 | c_fc
# [450/2472] ViT-L-14 | standard | Cars | layer 17 | c_proj
# [451/2472] ViT-L-14 | standard | Cars | layer 18 | c_fc
# [452/2472] ViT-L-14 | standard | Cars | layer 19 | c_proj
# [453/2472] ViT-L-14 | standard | Cars | layer 20 | c_fc
# [454/2472] ViT-L-14 | standard | Cars | layer 21 | c_proj
# [455/2472] ViT-L-14 | standard | Cars | layer 22 | c_fc
# [456/2472] ViT-L-14 | standard | Cars | layer 23 | c_proj
# [457/2472] ViT-L-14 | standard | Cars | layer 24 | c_fc
# [458/2472] ViT-L-14 | standard | Cars | layer 25 | c_proj
# [459/2472] ViT-L-14 | standard | Cars | layer 26 | c_fc
# [460/2472] ViT-L-14 | standard | Cars | layer 27 | c_proj
# [461/2472] ViT-L-14 | standard | Cars | layer 28 | c_fc
# [462/2472] ViT-L-14 | standard | Cars | layer 29 | c_proj
# [463/2472] ViT-L-14 | standard | Cars | layer 30 | c_fc
# [464/2472] ViT-L-14 | standard | Cars | layer 31 | c_proj
# [465/2472] ViT-L-14 | standard | Cars | layer 32 | c_fc
# [466/2472] ViT-L-14 | standard | Cars | layer 33 | c_proj
# [467/2472] ViT-L-14 | standard | Cars | layer 34 | c_fc
# [468/2472] ViT-L-14 | standard | Cars | layer 35 | c_proj
# [469/2472] ViT-L-14 | standard | Cars | layer 36 | c_fc
# [470/2472] ViT-L-14 | standard | Cars | layer 37 | c_proj
# [471/2472] ViT-L-14 | standard | Cars | layer 38 | c_fc
# [472/2472] ViT-L-14 | standard | Cars | layer 39 | c_proj
# [473/2472] ViT-L-14 | standard | Cars | layer 40 | c_fc
# [474/2472] ViT-L-14 | standard | Cars | layer 41 | c_proj
# [475/2472] ViT-L-14 | standard | Cars | layer 42 | c_fc
# [476/2472] ViT-L-14 | standard | Cars | layer 43 | c_proj
# [477/2472] ViT-L-14 | standard | Cars | layer 44 | c_fc
# [478/2472] ViT-L-14 | standard | Cars | layer 45 | c_proj
# [479/2472] ViT-L-14 | standard | Cars | layer 46 | c_fc
# [480/2472] ViT-L-14 | standard | Cars | layer 47 | c_proj
# [481/2472] ViT-L-14 | standard | Cars | layer 48 | q
# [482/2472] ViT-L-14 | standard | Cars | layer 49 | k
# [483/2472] ViT-L-14 | standard | Cars | layer 50 | v
# [484/2472] ViT-L-14 | standard | Cars | layer 51 | o
# [485/2472] ViT-L-14 | standard | Cars | layer 52 | q
# [486/2472] ViT-L-14 | standard | Cars | layer 53 | k
# [487/2472] ViT-L-14 | standard | Cars | layer 54 | v
# [488/2472] ViT-L-14 | standard | Cars | layer 55 | o
# [489/2472] ViT-L-14 | standard | Cars | layer 56 | q
# [490/2472] ViT-L-14 | standard | Cars | layer 57 | k
# [491/2472] ViT-L-14 | standard | Cars | layer 58 | v
# [492/2472] ViT-L-14 | standard | Cars | layer 59 | o
# [493/2472] ViT-L-14 | standard | Cars | layer 60 | q
# [494/2472] ViT-L-14 | standard | Cars | layer 61 | k
# [495/2472] ViT-L-14 | standard | Cars | layer 62 | v
# [496/2472] ViT-L-14 | standard | Cars | layer 63 | o
# [497/2472] ViT-L-14 | standard | Cars | layer 64 | q
# [498/2472] ViT-L-14 | standard | Cars | layer 65 | k
# [499/2472] ViT-L-14 | standard | Cars | layer 66 | v
# [500/2472] ViT-L-14 | standard | Cars | layer 67 | o
# [501/2472] ViT-L-14 | standard | Cars | layer 68 | q
# [502/2472] ViT-L-14 | standard | Cars | layer 69 | k
# [503/2472] ViT-L-14 | standard | Cars | layer 70 | v
# [504/2472] ViT-L-14 | standard | Cars | layer 71 | o
# [505/2472] ViT-L-14 | standard | Cars | layer 72 | q
# [506/2472] ViT-L-14 | standard | Cars | layer 73 | k
# [507/2472] ViT-L-14 | standard | Cars | layer 74 | v
# [508/2472] ViT-L-14 | standard | Cars | layer 75 | o
# [509/2472] ViT-L-14 | standard | Cars | layer 76 | q
# [510/2472] ViT-L-14 | standard | Cars | layer 77 | k
# [511/2472] ViT-L-14 | standard | Cars | layer 78 | v
# [512/2472] ViT-L-14 | standard | Cars | layer 79 | o
# [513/2472] ViT-L-14 | standard | Cars | layer 80 | q
# [514/2472] ViT-L-14 | standard | Cars | layer 81 | k
# [515/2472] ViT-L-14 | standard | Cars | layer 82 | v
# [516/2472] ViT-L-14 | standard | Cars | layer 83 | o
# [517/2472] ViT-L-14 | standard | Cars | layer 84 | q
# [518/2472] ViT-L-14 | standard | Cars | layer 85 | k
# [519/2472] ViT-L-14 | standard | Cars | layer 86 | v
# [520/2472] ViT-L-14 | standard | Cars | layer 87 | o
# [521/2472] ViT-L-14 | standard | Cars | layer 88 | q
# [522/2472] ViT-L-14 | standard | Cars | layer 89 | k
# [523/2472] ViT-L-14 | standard | Cars | layer 90 | v
# [524/2472] ViT-L-14 | standard | Cars | layer 91 | o
# [525/2472] ViT-L-14 | standard | Cars | layer 92 | q
# [526/2472] ViT-L-14 | standard | Cars | layer 93 | k
# [527/2472] ViT-L-14 | standard | Cars | layer 94 | v
# [528/2472] ViT-L-14 | standard | Cars | layer 95 | o
# [529/2472] ViT-L-14 | standard | Cars | layer 96 | q
# [530/2472] ViT-L-14 | standard | Cars | layer 97 | k
# [531/2472] ViT-L-14 | standard | Cars | layer 98 | v
# [532/2472] ViT-L-14 | standard | Cars | layer 99 | o
# [533/2472] ViT-L-14 | standard | Cars | layer 100 | q
# [534/2472] ViT-L-14 | standard | Cars | layer 101 | k
# [535/2472] ViT-L-14 | standard | Cars | layer 102 | v
# [536/2472] ViT-L-14 | standard | Cars | layer 103 | o
# [537/2472] ViT-L-14 | standard | Cars | layer 104 | q
# [538/2472] ViT-L-14 | standard | Cars | layer 105 | k
# [539/2472] ViT-L-14 | standard | Cars | layer 106 | v
# [540/2472] ViT-L-14 | standard | Cars | layer 107 | o
# [541/2472] ViT-L-14 | standard | Cars | layer 108 | q
# [542/2472] ViT-L-14 | standard | Cars | layer 109 | k
# [543/2472] ViT-L-14 | standard | Cars | layer 110 | v
# [544/2472] ViT-L-14 | standard | Cars | layer 111 | o
# [545/2472] ViT-L-14 | standard | Cars | layer 112 | q
# [546/2472] ViT-L-14 | standard | Cars | layer 113 | k
# [547/2472] ViT-L-14 | standard | Cars | layer 114 | v
# [548/2472] ViT-L-14 | standard | Cars | layer 115 | o
# [549/2472] ViT-L-14 | standard | Cars | layer 116 | q
# [550/2472] ViT-L-14 | standard | Cars | layer 117 | k
# [551/2472] ViT-L-14 | standard | Cars | layer 118 | v
# [552/2472] ViT-L-14 | standard | Cars | layer 119 | o
# [553/2472] ViT-L-14 | standard | Cars | layer 120 | q
# [554/2472] ViT-L-14 | standard | Cars | layer 121 | k
# [555/2472] ViT-L-14 | standard | Cars | layer 122 | v
# [556/2472] ViT-L-14 | standard | Cars | layer 123 | o
# [557/2472] ViT-L-14 | standard | Cars | layer 124 | q
# [558/2472] ViT-L-14 | standard | Cars | layer 125 | k
# [559/2472] ViT-L-14 | standard | Cars | layer 126 | v
# [560/2472] ViT-L-14 | standard | Cars | layer 127 | o
# [561/2472] ViT-L-14 | standard | Cars | layer 128 | q
# [562/2472] ViT-L-14 | standard | Cars | layer 129 | k
# [563/2472] ViT-L-14 | standard | Cars | layer 130 | v
# [564/2472] ViT-L-14 | standard | Cars | layer 131 | o
# [565/2472] ViT-L-14 | standard | Cars | layer 132 | q
# [566/2472] ViT-L-14 | standard | Cars | layer 133 | k
# [567/2472] ViT-L-14 | standard | Cars | layer 134 | v
# [568/2472] ViT-L-14 | standard | Cars | layer 135 | o
# [569/2472] ViT-L-14 | standard | Cars | layer 136 | q
# [570/2472] ViT-L-14 | standard | Cars | layer 137 | k
# [571/2472] ViT-L-14 | standard | Cars | layer 138 | v
# [572/2472] ViT-L-14 | standard | Cars | layer 139 | o
# [573/2472] ViT-L-14 | standard | Cars | layer 140 | q
# [574/2472] ViT-L-14 | standard | Cars | layer 141 | k
# [575/2472] ViT-L-14 | standard | Cars | layer 142 | v
# [576/2472] ViT-L-14 | standard | Cars | layer 143 | o
# [577/2472] ViT-L-14 | standard | DTD | layer 0 | c_fc
# [578/2472] ViT-L-14 | standard | DTD | layer 1 | c_proj
# [579/2472] ViT-L-14 | standard | DTD | layer 2 | c_fc
# [580/2472] ViT-L-14 | standard | DTD | layer 3 | c_proj
# [581/2472] ViT-L-14 | standard | DTD | layer 4 | c_fc
# [582/2472] ViT-L-14 | standard | DTD | layer 5 | c_proj
# [583/2472] ViT-L-14 | standard | DTD | layer 6 | c_fc
# [584/2472] ViT-L-14 | standard | DTD | layer 7 | c_proj
# [585/2472] ViT-L-14 | standard | DTD | layer 8 | c_fc
# [586/2472] ViT-L-14 | standard | DTD | layer 9 | c_proj
# [587/2472] ViT-L-14 | standard | DTD | layer 10 | c_fc
# [588/2472] ViT-L-14 | standard | DTD | layer 11 | c_proj
# [589/2472] ViT-L-14 | standard | DTD | layer 12 | c_fc
# [590/2472] ViT-L-14 | standard | DTD | layer 13 | c_proj
# [591/2472] ViT-L-14 | standard | DTD | layer 14 | c_fc
# [592/2472] ViT-L-14 | standard | DTD | layer 15 | c_proj
# [593/2472] ViT-L-14 | standard | DTD | layer 16 | c_fc
# [594/2472] ViT-L-14 | standard | DTD | layer 17 | c_proj
# [595/2472] ViT-L-14 | standard | DTD | layer 18 | c_fc
# [596/2472] ViT-L-14 | standard | DTD | layer 19 | c_proj
# [597/2472] ViT-L-14 | standard | DTD | layer 20 | c_fc
# [598/2472] ViT-L-14 | standard | DTD | layer 21 | c_proj
# [599/2472] ViT-L-14 | standard | DTD | layer 22 | c_fc
# [600/2472] ViT-L-14 | standard | DTD | layer 23 | c_proj
# [601/2472] ViT-L-14 | standard | DTD | layer 24 | c_fc
# [602/2472] ViT-L-14 | standard | DTD | layer 25 | c_proj
# [603/2472] ViT-L-14 | standard | DTD | layer 26 | c_fc
# [604/2472] ViT-L-14 | standard | DTD | layer 27 | c_proj
# [605/2472] ViT-L-14 | standard | DTD | layer 28 | c_fc
# [606/2472] ViT-L-14 | standard | DTD | layer 29 | c_proj
# [607/2472] ViT-L-14 | standard | DTD | layer 30 | c_fc
# [608/2472] ViT-L-14 | standard | DTD | layer 31 | c_proj
# [609/2472] ViT-L-14 | standard | DTD | layer 32 | c_fc
# [610/2472] ViT-L-14 | standard | DTD | layer 33 | c_proj
# [611/2472] ViT-L-14 | standard | DTD | layer 34 | c_fc
# [612/2472] ViT-L-14 | standard | DTD | layer 35 | c_proj
# [613/2472] ViT-L-14 | standard | DTD | layer 36 | c_fc
# [614/2472] ViT-L-14 | standard | DTD | layer 37 | c_proj
# [615/2472] ViT-L-14 | standard | DTD | layer 38 | c_fc
# [616/2472] ViT-L-14 | standard | DTD | layer 39 | c_proj
# [617/2472] ViT-L-14 | standard | DTD | layer 40 | c_fc
# [618/2472] ViT-L-14 | standard | DTD | layer 41 | c_proj
# [619/2472] ViT-L-14 | standard | DTD | layer 42 | c_fc
# [620/2472] ViT-L-14 | standard | DTD | layer 43 | c_proj
# [621/2472] ViT-L-14 | standard | DTD | layer 44 | c_fc
# [622/2472] ViT-L-14 | standard | DTD | layer 45 | c_proj
# [623/2472] ViT-L-14 | standard | DTD | layer 46 | c_fc
# [624/2472] ViT-L-14 | standard | DTD | layer 47 | c_proj
# [625/2472] ViT-L-14 | standard | DTD | layer 48 | q
# [626/2472] ViT-L-14 | standard | DTD | layer 49 | k
# [627/2472] ViT-L-14 | standard | DTD | layer 50 | v
# [628/2472] ViT-L-14 | standard | DTD | layer 51 | o
# [629/2472] ViT-L-14 | standard | DTD | layer 52 | q
# [630/2472] ViT-L-14 | standard | DTD | layer 53 | k
# [631/2472] ViT-L-14 | standard | DTD | layer 54 | v
# [632/2472] ViT-L-14 | standard | DTD | layer 55 | o
# [633/2472] ViT-L-14 | standard | DTD | layer 56 | q
# [634/2472] ViT-L-14 | standard | DTD | layer 57 | k
# [635/2472] ViT-L-14 | standard | DTD | layer 58 | v
# [636/2472] ViT-L-14 | standard | DTD | layer 59 | o
# [637/2472] ViT-L-14 | standard | DTD | layer 60 | q
# [638/2472] ViT-L-14 | standard | DTD | layer 61 | k
# [639/2472] ViT-L-14 | standard | DTD | layer 62 | v
# [640/2472] ViT-L-14 | standard | DTD | layer 63 | o
# [641/2472] ViT-L-14 | standard | DTD | layer 64 | q
# [642/2472] ViT-L-14 | standard | DTD | layer 65 | k
# [643/2472] ViT-L-14 | standard | DTD | layer 66 | v
# [644/2472] ViT-L-14 | standard | DTD | layer 67 | o
# [645/2472] ViT-L-14 | standard | DTD | layer 68 | q
# [646/2472] ViT-L-14 | standard | DTD | layer 69 | k
# [647/2472] ViT-L-14 | standard | DTD | layer 70 | v
# [648/2472] ViT-L-14 | standard | DTD | layer 71 | o
# [649/2472] ViT-L-14 | standard | DTD | layer 72 | q
# [650/2472] ViT-L-14 | standard | DTD | layer 73 | k
# [651/2472] ViT-L-14 | standard | DTD | layer 74 | v
# [652/2472] ViT-L-14 | standard | DTD | layer 75 | o
# [653/2472] ViT-L-14 | standard | DTD | layer 76 | q
# [654/2472] ViT-L-14 | standard | DTD | layer 77 | k
# [655/2472] ViT-L-14 | standard | DTD | layer 78 | v
# [656/2472] ViT-L-14 | standard | DTD | layer 79 | o
# [657/2472] ViT-L-14 | standard | DTD | layer 80 | q
# [658/2472] ViT-L-14 | standard | DTD | layer 81 | k
# [659/2472] ViT-L-14 | standard | DTD | layer 82 | v
# [660/2472] ViT-L-14 | standard | DTD | layer 83 | o
# [661/2472] ViT-L-14 | standard | DTD | layer 84 | q
# [662/2472] ViT-L-14 | standard | DTD | layer 85 | k
# [663/2472] ViT-L-14 | standard | DTD | layer 86 | v
# [664/2472] ViT-L-14 | standard | DTD | layer 87 | o
# [665/2472] ViT-L-14 | standard | DTD | layer 88 | q
# [666/2472] ViT-L-14 | standard | DTD | layer 89 | k
# [667/2472] ViT-L-14 | standard | DTD | layer 90 | v
# [668/2472] ViT-L-14 | standard | DTD | layer 91 | o
# [669/2472] ViT-L-14 | standard | DTD | layer 92 | q
# [670/2472] ViT-L-14 | standard | DTD | layer 93 | k
# [671/2472] ViT-L-14 | standard | DTD | layer 94 | v
# [672/2472] ViT-L-14 | standard | DTD | layer 95 | o
# [673/2472] ViT-L-14 | standard | DTD | layer 96 | q
# [674/2472] ViT-L-14 | standard | DTD | layer 97 | k
# [675/2472] ViT-L-14 | standard | DTD | layer 98 | v
# [676/2472] ViT-L-14 | standard | DTD | layer 99 | o
# [677/2472] ViT-L-14 | standard | DTD | layer 100 | q
# [678/2472] ViT-L-14 | standard | DTD | layer 101 | k
# [679/2472] ViT-L-14 | standard | DTD | layer 102 | v
# [680/2472] ViT-L-14 | standard | DTD | layer 103 | o
# [681/2472] ViT-L-14 | standard | DTD | layer 104 | q
# [682/2472] ViT-L-14 | standard | DTD | layer 105 | k
# [683/2472] ViT-L-14 | standard | DTD | layer 106 | v
# [684/2472] ViT-L-14 | standard | DTD | layer 107 | o
# [685/2472] ViT-L-14 | standard | DTD | layer 108 | q
# [686/2472] ViT-L-14 | standard | DTD | layer 109 | k
# [687/2472] ViT-L-14 | standard | DTD | layer 110 | v
# [688/2472] ViT-L-14 | standard | DTD | layer 111 | o
# [689/2472] ViT-L-14 | standard | DTD | layer 112 | q
# [690/2472] ViT-L-14 | standard | DTD | layer 113 | k
# [691/2472] ViT-L-14 | standard | DTD | layer 114 | v
# [692/2472] ViT-L-14 | standard | DTD | layer 115 | o
# [693/2472] ViT-L-14 | standard | DTD | layer 116 | q
# [694/2472] ViT-L-14 | standard | DTD | layer 117 | k
# [695/2472] ViT-L-14 | standard | DTD | layer 118 | v
# [696/2472] ViT-L-14 | standard | DTD | layer 119 | o
# [697/2472] ViT-L-14 | standard | DTD | layer 120 | q
# [698/2472] ViT-L-14 | standard | DTD | layer 121 | k
# [699/2472] ViT-L-14 | standard | DTD | layer 122 | v
# [700/2472] ViT-L-14 | standard | DTD | layer 123 | o
# [701/2472] ViT-L-14 | standard | DTD | layer 124 | q
# [702/2472] ViT-L-14 | standard | DTD | layer 125 | k
# [703/2472] ViT-L-14 | standard | DTD | layer 126 | v
# [704/2472] ViT-L-14 | standard | DTD | layer 127 | o
# [705/2472] ViT-L-14 | standard | DTD | layer 128 | q
# [706/2472] ViT-L-14 | standard | DTD | layer 129 | k
# [707/2472] ViT-L-14 | standard | DTD | layer 130 | v
# [708/2472] ViT-L-14 | standard | DTD | layer 131 | o
# [709/2472] ViT-L-14 | standard | DTD | layer 132 | q
# [710/2472] ViT-L-14 | standard | DTD | layer 133 | k
# [711/2472] ViT-L-14 | standard | DTD | layer 134 | v
# [712/2472] ViT-L-14 | standard | DTD | layer 135 | o
# [713/2472] ViT-L-14 | standard | DTD | layer 136 | q
# [714/2472] ViT-L-14 | standard | DTD | layer 137 | k
# [715/2472] ViT-L-14 | standard | DTD | layer 138 | v
# [716/2472] ViT-L-14 | standard | DTD | layer 139 | o
# [717/2472] ViT-L-14 | standard | DTD | layer 140 | q
# [718/2472] ViT-L-14 | standard | DTD | layer 141 | k
# [719/2472] ViT-L-14 | standard | DTD | layer 142 | v
# [720/2472] ViT-L-14 | standard | DTD | layer 143 | o
# [721/2472] ViT-L-14 | standard | EuroSAT | layer 0 | c_fc
# [722/2472] ViT-L-14 | standard | EuroSAT | layer 1 | c_proj
# [723/2472] ViT-L-14 | standard | EuroSAT | layer 2 | c_fc
# [724/2472] ViT-L-14 | standard | EuroSAT | layer 3 | c_proj
# [725/2472] ViT-L-14 | standard | EuroSAT | layer 4 | c_fc
# [726/2472] ViT-L-14 | standard | EuroSAT | layer 5 | c_proj
# [727/2472] ViT-L-14 | standard | EuroSAT | layer 6 | c_fc
# [728/2472] ViT-L-14 | standard | EuroSAT | layer 7 | c_proj
# [729/2472] ViT-L-14 | standard | EuroSAT | layer 8 | c_fc
# [730/2472] ViT-L-14 | standard | EuroSAT | layer 9 | c_proj
# [731/2472] ViT-L-14 | standard | EuroSAT | layer 10 | c_fc
# [732/2472] ViT-L-14 | standard | EuroSAT | layer 11 | c_proj
# [733/2472] ViT-L-14 | standard | EuroSAT | layer 12 | c_fc
# [734/2472] ViT-L-14 | standard | EuroSAT | layer 13 | c_proj
# [735/2472] ViT-L-14 | standard | EuroSAT | layer 14 | c_fc
# [736/2472] ViT-L-14 | standard | EuroSAT | layer 15 | c_proj
# [737/2472] ViT-L-14 | standard | EuroSAT | layer 16 | c_fc
# [738/2472] ViT-L-14 | standard | EuroSAT | layer 17 | c_proj
# [739/2472] ViT-L-14 | standard | EuroSAT | layer 18 | c_fc
# [740/2472] ViT-L-14 | standard | EuroSAT | layer 19 | c_proj
# [741/2472] ViT-L-14 | standard | EuroSAT | layer 20 | c_fc
# [742/2472] ViT-L-14 | standard | EuroSAT | layer 21 | c_proj
# [743/2472] ViT-L-14 | standard | EuroSAT | layer 22 | c_fc
# [744/2472] ViT-L-14 | standard | EuroSAT | layer 23 | c_proj
# [745/2472] ViT-L-14 | standard | EuroSAT | layer 24 | c_fc
# [746/2472] ViT-L-14 | standard | EuroSAT | layer 25 | c_proj
# [747/2472] ViT-L-14 | standard | EuroSAT | layer 26 | c_fc
# [748/2472] ViT-L-14 | standard | EuroSAT | layer 27 | c_proj
# [749/2472] ViT-L-14 | standard | EuroSAT | layer 28 | c_fc
# [750/2472] ViT-L-14 | standard | EuroSAT | layer 29 | c_proj
# [751/2472] ViT-L-14 | standard | EuroSAT | layer 30 | c_fc
# [752/2472] ViT-L-14 | standard | EuroSAT | layer 31 | c_proj
# [753/2472] ViT-L-14 | standard | EuroSAT | layer 32 | c_fc
# [754/2472] ViT-L-14 | standard | EuroSAT | layer 33 | c_proj
# [755/2472] ViT-L-14 | standard | EuroSAT | layer 34 | c_fc
# [756/2472] ViT-L-14 | standard | EuroSAT | layer 35 | c_proj
# [757/2472] ViT-L-14 | standard | EuroSAT | layer 36 | c_fc
# [758/2472] ViT-L-14 | standard | EuroSAT | layer 37 | c_proj
# [759/2472] ViT-L-14 | standard | EuroSAT | layer 38 | c_fc
# [760/2472] ViT-L-14 | standard | EuroSAT | layer 39 | c_proj
# [761/2472] ViT-L-14 | standard | EuroSAT | layer 40 | c_fc
# [762/2472] ViT-L-14 | standard | EuroSAT | layer 41 | c_proj
# [763/2472] ViT-L-14 | standard | EuroSAT | layer 42 | c_fc
# [764/2472] ViT-L-14 | standard | EuroSAT | layer 43 | c_proj
# [765/2472] ViT-L-14 | standard | EuroSAT | layer 44 | c_fc
# [766/2472] ViT-L-14 | standard | EuroSAT | layer 45 | c_proj
# [767/2472] ViT-L-14 | standard | EuroSAT | layer 46 | c_fc
# [768/2472] ViT-L-14 | standard | EuroSAT | layer 47 | c_proj
# [769/2472] ViT-L-14 | standard | EuroSAT | layer 48 | q
# [770/2472] ViT-L-14 | standard | EuroSAT | layer 49 | k
# [771/2472] ViT-L-14 | standard | EuroSAT | layer 50 | v
# [772/2472] ViT-L-14 | standard | EuroSAT | layer 51 | o
# [773/2472] ViT-L-14 | standard | EuroSAT | layer 52 | q
# [774/2472] ViT-L-14 | standard | EuroSAT | layer 53 | k
# [775/2472] ViT-L-14 | standard | EuroSAT | layer 54 | v
# [776/2472] ViT-L-14 | standard | EuroSAT | layer 55 | o
# [777/2472] ViT-L-14 | standard | EuroSAT | layer 56 | q
# [778/2472] ViT-L-14 | standard | EuroSAT | layer 57 | k
# [779/2472] ViT-L-14 | standard | EuroSAT | layer 58 | v
# [780/2472] ViT-L-14 | standard | EuroSAT | layer 59 | o
# [781/2472] ViT-L-14 | standard | EuroSAT | layer 60 | q
# [782/2472] ViT-L-14 | standard | EuroSAT | layer 61 | k
# [783/2472] ViT-L-14 | standard | EuroSAT | layer 62 | v
# [784/2472] ViT-L-14 | standard | EuroSAT | layer 63 | o
# [785/2472] ViT-L-14 | standard | EuroSAT | layer 64 | q
# [786/2472] ViT-L-14 | standard | EuroSAT | layer 65 | k
# [787/2472] ViT-L-14 | standard | EuroSAT | layer 66 | v
# [788/2472] ViT-L-14 | standard | EuroSAT | layer 67 | o
# [789/2472] ViT-L-14 | standard | EuroSAT | layer 68 | q
# [790/2472] ViT-L-14 | standard | EuroSAT | layer 69 | k
# [791/2472] ViT-L-14 | standard | EuroSAT | layer 70 | v
# [792/2472] ViT-L-14 | standard | EuroSAT | layer 71 | o
# [793/2472] ViT-L-14 | standard | EuroSAT | layer 72 | q
# [794/2472] ViT-L-14 | standard | EuroSAT | layer 73 | k
# [795/2472] ViT-L-14 | standard | EuroSAT | layer 74 | v
# [796/2472] ViT-L-14 | standard | EuroSAT | layer 75 | o
# [797/2472] ViT-L-14 | standard | EuroSAT | layer 76 | q
# [798/2472] ViT-L-14 | standard | EuroSAT | layer 77 | k
# [799/2472] ViT-L-14 | standard | EuroSAT | layer 78 | v
# [800/2472] ViT-L-14 | standard | EuroSAT | layer 79 | o
# [801/2472] ViT-L-14 | standard | EuroSAT | layer 80 | q
# [802/2472] ViT-L-14 | standard | EuroSAT | layer 81 | k
# [803/2472] ViT-L-14 | standard | EuroSAT | layer 82 | v
# [804/2472] ViT-L-14 | standard | EuroSAT | layer 83 | o
# [805/2472] ViT-L-14 | standard | EuroSAT | layer 84 | q
# [806/2472] ViT-L-14 | standard | EuroSAT | layer 85 | k
# [807/2472] ViT-L-14 | standard | EuroSAT | layer 86 | v
# [808/2472] ViT-L-14 | standard | EuroSAT | layer 87 | o
# [809/2472] ViT-L-14 | standard | EuroSAT | layer 88 | q
# [810/2472] ViT-L-14 | standard | EuroSAT | layer 89 | k
# [811/2472] ViT-L-14 | standard | EuroSAT | layer 90 | v
# [812/2472] ViT-L-14 | standard | EuroSAT | layer 91 | o
# [813/2472] ViT-L-14 | standard | EuroSAT | layer 92 | q
# [814/2472] ViT-L-14 | standard | EuroSAT | layer 93 | k
# [815/2472] ViT-L-14 | standard | EuroSAT | layer 94 | v
# [816/2472] ViT-L-14 | standard | EuroSAT | layer 95 | o
# [817/2472] ViT-L-14 | standard | EuroSAT | layer 96 | q
# [818/2472] ViT-L-14 | standard | EuroSAT | layer 97 | k
# [819/2472] ViT-L-14 | standard | EuroSAT | layer 98 | v
# [820/2472] ViT-L-14 | standard | EuroSAT | layer 99 | o
# [821/2472] ViT-L-14 | standard | EuroSAT | layer 100 | q
# [822/2472] ViT-L-14 | standard | EuroSAT | layer 101 | k
# [823/2472] ViT-L-14 | standard | EuroSAT | layer 102 | v
# [824/2472] ViT-L-14 | standard | EuroSAT | layer 103 | o
# [825/2472] ViT-L-14 | standard | EuroSAT | layer 104 | q
# [826/2472] ViT-L-14 | standard | EuroSAT | layer 105 | k
# [827/2472] ViT-L-14 | standard | EuroSAT | layer 106 | v
# [828/2472] ViT-L-14 | standard | EuroSAT | layer 107 | o
# [829/2472] ViT-L-14 | standard | EuroSAT | layer 108 | q
# [830/2472] ViT-L-14 | standard | EuroSAT | layer 109 | k
# [831/2472] ViT-L-14 | standard | EuroSAT | layer 110 | v
# [832/2472] ViT-L-14 | standard | EuroSAT | layer 111 | o
# [833/2472] ViT-L-14 | standard | EuroSAT | layer 112 | q
# [834/2472] ViT-L-14 | standard | EuroSAT | layer 113 | k
# [835/2472] ViT-L-14 | standard | EuroSAT | layer 114 | v
# [836/2472] ViT-L-14 | standard | EuroSAT | layer 115 | o
# [837/2472] ViT-L-14 | standard | EuroSAT | layer 116 | q
# [838/2472] ViT-L-14 | standard | EuroSAT | layer 117 | k
# [839/2472] ViT-L-14 | standard | EuroSAT | layer 118 | v
# [840/2472] ViT-L-14 | standard | EuroSAT | layer 119 | o
# [841/2472] ViT-L-14 | standard | EuroSAT | layer 120 | q
# [842/2472] ViT-L-14 | standard | EuroSAT | layer 121 | k
# [843/2472] ViT-L-14 | standard | EuroSAT | layer 122 | v
# [844/2472] ViT-L-14 | standard | EuroSAT | layer 123 | o
# [845/2472] ViT-L-14 | standard | EuroSAT | layer 124 | q
# [846/2472] ViT-L-14 | standard | EuroSAT | layer 125 | k
# [847/2472] ViT-L-14 | standard | EuroSAT | layer 126 | v
# [848/2472] ViT-L-14 | standard | EuroSAT | layer 127 | o
# [849/2472] ViT-L-14 | standard | EuroSAT | layer 128 | q
# [850/2472] ViT-L-14 | standard | EuroSAT | layer 129 | k
# [851/2472] ViT-L-14 | standard | EuroSAT | layer 130 | v
# [852/2472] ViT-L-14 | standard | EuroSAT | layer 131 | o
# [853/2472] ViT-L-14 | standard | EuroSAT | layer 132 | q
# [854/2472] ViT-L-14 | standard | EuroSAT | layer 133 | k
# [855/2472] ViT-L-14 | standard | EuroSAT | layer 134 | v
# [856/2472] ViT-L-14 | standard | EuroSAT | layer 135 | o
# [857/2472] ViT-L-14 | standard | EuroSAT | layer 136 | q
# [858/2472] ViT-L-14 | standard | EuroSAT | layer 137 | k
# [859/2472] ViT-L-14 | standard | EuroSAT | layer 138 | v
# [860/2472] ViT-L-14 | standard | EuroSAT | layer 139 | o
# [861/2472] ViT-L-14 | standard | EuroSAT | layer 140 | q
# [862/2472] ViT-L-14 | standard | EuroSAT | layer 141 | k
# [863/2472] ViT-L-14 | standard | EuroSAT | layer 142 | v
# [864/2472] ViT-L-14 | standard | EuroSAT | layer 143 | o
# [865/2472] ViT-L-14 | standard | GTSRB | layer 0 | c_fc
# [866/2472] ViT-L-14 | standard | GTSRB | layer 1 | c_proj
# [867/2472] ViT-L-14 | standard | GTSRB | layer 2 | c_fc
# [868/2472] ViT-L-14 | standard | GTSRB | layer 3 | c_proj
# [869/2472] ViT-L-14 | standard | GTSRB | layer 4 | c_fc
# [870/2472] ViT-L-14 | standard | GTSRB | layer 5 | c_proj
# [871/2472] ViT-L-14 | standard | GTSRB | layer 6 | c_fc
# [872/2472] ViT-L-14 | standard | GTSRB | layer 7 | c_proj
# [873/2472] ViT-L-14 | standard | GTSRB | layer 8 | c_fc
# ...
# [1012/2472] ViT-L-14 | standard | MNIST | layer 3 | c_proj
# [1013/2472] ViT-L-14 | standard | MNIST | layer 4 | c_fc
# [1014/2472] ViT-L-14 | standard | MNIST | layer 5 | c_proj
# [1015/2472] ViT-L-14 | standard | MNIST | layer 6 | c_fc
# [1016/2472] ViT-L-14 | standard | MNIST | layer 7 | c_proj
# [1017/2472] ViT-L-14 | standard | MNIST | layer 8 | c_fc
# [1018/2472] ViT-L-14 | standard | MNIST | layer 9 | c_proj
# [1019/2472] ViT-L-14 | standard | MNIST | layer 10 | c_fc
# [1020/2472] ViT-L-14 | standard | MNIST | layer 11 | c_proj
# [1021/2472] ViT-L-14 | standard | MNIST | layer 12 | c_fc
# [1022/2472] ViT-L-14 | standard | MNIST | layer 13 | c_proj
# [1023/2472] ViT-L-14 | standard | MNIST | layer 14 | c_fc
# [1024/2472] ViT-L-14 | standard | MNIST | layer 15 | c_proj
# [1025/2472] ViT-L-14 | standard | MNIST | layer 16 | c_fc
# [1026/2472] ViT-L-14 | standard | MNIST | layer 17 | c_proj
# [1027/2472] ViT-L-14 | standard | MNIST | layer 18 | c_fc
# [1028/2472] ViT-L-14 | standard | MNIST | layer 19 | c_proj
# [1029/2472] ViT-L-14 | standard | MNIST | layer 20 | c_fc
# [1030/2472] ViT-L-14 | standard | MNIST | layer 21 | c_proj
# [1031/2472] ViT-L-14 | standard | MNIST | layer 22 | c_fc
# [1032/2472] ViT-L-14 | standard | MNIST | layer 23 | c_proj
# [1033/2472] ViT-L-14 | standard | MNIST | layer 24 | c_fc
# [1034/2472] ViT-L-14 | standard | MNIST | layer 25 | c_proj
# [1035/2472] ViT-L-14 | standard | MNIST | layer 26 | c_fc
# [1036/2472] ViT-L-14 | standard | MNIST | layer 27 | c_proj
# [1037/2472] ViT-L-14 | standard | MNIST | layer 28 | c_fc
# [1038/2472] ViT-L-14 | standard | MNIST | layer 29 | c_proj
# [1039/2472] ViT-L-14 | standard | MNIST | layer 30 | c_fc
# [1040/2472] ViT-L-14 | standard | MNIST | layer 31 | c_proj
# [1041/2472] ViT-L-14 | standard | MNIST | layer 32 | c_fc
# [1042/2472] ViT-L-14 | standard | MNIST | layer 33 | c_proj
# [1043/2472] ViT-L-14 | standard | MNIST | layer 34 | c_fc
# [1044/2472] ViT-L-14 | standard | MNIST | layer 35 | c_proj
# [1045/2472] ViT-L-14 | standard | MNIST | layer 36 | c_fc
# [1046/2472] ViT-L-14 | standard | MNIST | layer 37 | c_proj
# [1047/2472] ViT-L-14 | standard | MNIST | layer 38 | c_fc
# [1048/2472] ViT-L-14 | standard | MNIST | layer 39 | c_proj
# [1049/2472] ViT-L-14 | standard | MNIST | layer 40 | c_fc
# [1050/2472] ViT-L-14 | standard | MNIST | layer 41 | c_proj
# [1051/2472] ViT-L-14 | standard | MNIST | layer 42 | c_fc
# [1052/2472] ViT-L-14 | standard | MNIST | layer 43 | c_proj
# [1053/2472] ViT-L-14 | standard | MNIST | layer 44 | c_fc
# [1054/2472] ViT-L-14 | standard | MNIST | layer 45 | c_proj
# [1055/2472] ViT-L-14 | standard | MNIST | layer 46 | c_fc
# [1056/2472] ViT-L-14 | standard | MNIST | layer 47 | c_proj
# [1057/2472] ViT-L-14 | standard | MNIST | layer 48 | q
# [1058/2472] ViT-L-14 | standard | MNIST | layer 49 | k
# [1059/2472] ViT-L-14 | standard | MNIST | layer 50 | v
# [1060/2472] ViT-L-14 | standard | MNIST | layer 51 | o
# [1061/2472] ViT-L-14 | standard | MNIST | layer 52 | q
# [1062/2472] ViT-L-14 | standard | MNIST | layer 53 | k
# [1063/2472] ViT-L-14 | standard | MNIST | layer 54 | v
# [1064/2472] ViT-L-14 | standard | MNIST | layer 55 | o
# [1065/2472] ViT-L-14 | standard | MNIST | layer 56 | q
# [1066/2472] ViT-L-14 | standard | MNIST | layer 57 | k
# [1067/2472] ViT-L-14 | standard | MNIST | layer 58 | v
# [1068/2472] ViT-L-14 | standard | MNIST | layer 59 | o
# [1069/2472] ViT-L-14 | standard | MNIST | layer 60 | q
# [1070/2472] ViT-L-14 | standard | MNIST | layer 61 | k
# [1071/2472] ViT-L-14 | standard | MNIST | layer 62 | v
# [1072/2472] ViT-L-14 | standard | MNIST | layer 63 | o
# [1073/2472] ViT-L-14 | standard | MNIST | layer 64 | q
# [1074/2472] ViT-L-14 | standard | MNIST | layer 65 | k
# [1075/2472] ViT-L-14 | standard | MNIST | layer 66 | v
# [1076/2472] ViT-L-14 | standard | MNIST | layer 67 | o
# [1077/2472] ViT-L-14 | standard | MNIST | layer 68 | q
# [1078/2472] ViT-L-14 | standard | MNIST | layer 69 | k
# [1079/2472] ViT-L-14 | standard | MNIST | layer 70 | v
# [1080/2472] ViT-L-14 | standard | MNIST | layer 71 | o
# [1081/2472] ViT-L-14 | standard | MNIST | layer 72 | q
# [1082/2472] ViT-L-14 | standard | MNIST | layer 73 | k
# [1083/2472] ViT-L-14 | standard | MNIST | layer 74 | v
# [1084/2472] ViT-L-14 | standard | MNIST | layer 75 | o
# [1085/2472] ViT-L-14 | standard | MNIST | layer 76 | q
# [1086/2472] ViT-L-14 | standard | MNIST | layer 77 | k
# [1087/2472] ViT-L-14 | standard | MNIST | layer 78 | v
# [1088/2472] ViT-L-14 | standard | MNIST | layer 79 | o
# [1089/2472] ViT-L-14 | standard | MNIST | layer 80 | q
# [1090/2472] ViT-L-14 | standard | MNIST | layer 81 | k
# [1091/2472] ViT-L-14 | standard | MNIST | layer 82 | v
# [1092/2472] ViT-L-14 | standard | MNIST | layer 83 | o
# [1093/2472] ViT-L-14 | standard | MNIST | layer 84 | q
# [1094/2472] ViT-L-14 | standard | MNIST | layer 85 | k
# [1095/2472] ViT-L-14 | standard | MNIST | layer 86 | v
# [1096/2472] ViT-L-14 | standard | MNIST | layer 87 | o
# [1097/2472] ViT-L-14 | standard | MNIST | layer 88 | q
# [1098/2472] ViT-L-14 | standard | MNIST | layer 89 | k
# [1099/2472] ViT-L-14 | standard | MNIST | layer 90 | v
# [1100/2472] ViT-L-14 | standard | MNIST | layer 91 | o
# [1101/2472] ViT-L-14 | standard | MNIST | layer 92 | q
# [1102/2472] ViT-L-14 | standard | MNIST | layer 93 | k
# [1103/2472] ViT-L-14 | standard | MNIST | layer 94 | v
# [1104/2472] ViT-L-14 | standard | MNIST | layer 95 | o
# [1105/2472] ViT-L-14 | standard | MNIST | layer 96 | q
# [1106/2472] ViT-L-14 | standard | MNIST | layer 97 | k
# [1107/2472] ViT-L-14 | standard | MNIST | layer 98 | v
# [1108/2472] ViT-L-14 | standard | MNIST | layer 99 | o
# [1109/2472] ViT-L-14 | standard | MNIST | layer 100 | q
# [1110/2472] ViT-L-14 | standard | MNIST | layer 101 | k
# [1111/2472] ViT-L-14 | standard | MNIST | layer 102 | v
# [1112/2472] ViT-L-14 | standard | MNIST | layer 103 | o
# [1113/2472] ViT-L-14 | standard | MNIST | layer 104 | q
# [1114/2472] ViT-L-14 | standard | MNIST | layer 105 | k
# [1115/2472] ViT-L-14 | standard | MNIST | layer 106 | v
# [1116/2472] ViT-L-14 | standard | MNIST | layer 107 | o
# [1117/2472] ViT-L-14 | standard | MNIST | layer 108 | q
# [1118/2472] ViT-L-14 | standard | MNIST | layer 109 | k
# [1119/2472] ViT-L-14 | standard | MNIST | layer 110 | v
# [1120/2472] ViT-L-14 | standard | MNIST | layer 111 | o
# [1121/2472] ViT-L-14 | standard | MNIST | layer 112 | q
# [1122/2472] ViT-L-14 | standard | MNIST | layer 113 | k
# [1123/2472] ViT-L-14 | standard | MNIST | layer 114 | v
# [1124/2472] ViT-L-14 | standard | MNIST | layer 115 | o
# [1125/2472] ViT-L-14 | standard | MNIST | layer 116 | q
# [1126/2472] ViT-L-14 | standard | MNIST | layer 117 | k
# [1127/2472] ViT-L-14 | standard | MNIST | layer 118 | v
# [1128/2472] ViT-L-14 | standard | MNIST | layer 119 | o
# [1129/2472] ViT-L-14 | standard | MNIST | layer 120 | q
# [1130/2472] ViT-L-14 | standard | MNIST | layer 121 | k
# [1131/2472] ViT-L-14 | standard | MNIST | layer 122 | v
# [1132/2472] ViT-L-14 | standard | MNIST | layer 123 | o
# [1133/2472] ViT-L-14 | standard | MNIST | layer 124 | q
# [1134/2472] ViT-L-14 | standard | MNIST | layer 125 | k
# [1135/2472] ViT-L-14 | standard | MNIST | layer 126 | v
# [1136/2472] ViT-L-14 | standard | MNIST | layer 127 | o
# [1137/2472] ViT-L-14 | standard | MNIST | layer 128 | q
# [1138/2472] ViT-L-14 | standard | MNIST | layer 129 | k
# [1139/2472] ViT-L-14 | standard | MNIST | layer 130 | v
# [1140/2472] ViT-L-14 | standard | MNIST | layer 131 | o
# [1141/2472] ViT-L-14 | standard | MNIST | layer 132 | q
# [1142/2472] ViT-L-14 | standard | MNIST | layer 133 | k
# [1143/2472] ViT-L-14 | standard | MNIST | layer 134 | v
# [1144/2472] ViT-L-14 | standard | MNIST | layer 135 | o
# [1145/2472] ViT-L-14 | standard | MNIST | layer 136 | q
# [1146/2472] ViT-L-14 | standard | MNIST | layer 137 | k
# [1147/2472] ViT-L-14 | standard | MNIST | layer 138 | v
# [1148/2472] ViT-L-14 | standard | MNIST | layer 139 | o
# [1149/2472] ViT-L-14 | standard | MNIST | layer 140 | q
# [1150/2472] ViT-L-14 | standard | MNIST | layer 141 | k
# [1151/2472] ViT-L-14 | standard | MNIST | layer 142 | v
# [1152/2472] ViT-L-14 | standard | MNIST | layer 143 | o
# [1153/2472] ViT-L-14 | standard | SVHN | layer 0 | c_fc
# [1154/2472] ViT-L-14 | standard | SVHN | layer 1 | c_proj
# [1155/2472] ViT-L-14 | standard | SVHN | layer 2 | c_fc
# [1156/2472] ViT-L-14 | standard | SVHN | layer 3 | c_proj
# [1157/2472] ViT-L-14 | standard | SVHN | layer 4 | c_fc
# [1158/2472] ViT-L-14 | standard | SVHN | layer 5 | c_proj
# [1159/2472] ViT-L-14 | standard | SVHN | layer 6 | c_fc
# [1160/2472] ViT-L-14 | standard | SVHN | layer 7 | c_proj
# [1161/2472] ViT-L-14 | standard | SVHN | layer 8 | c_fc
# [1162/2472] ViT-L-14 | standard | SVHN | layer 9 | c_proj
# [1163/2472] ViT-L-14 | standard | SVHN | layer 10 | c_fc
# [1164/2472] ViT-L-14 | standard | SVHN | layer 11 | c_proj
# [1165/2472] ViT-L-14 | standard | SVHN | layer 12 | c_fc
# [1166/2472] ViT-L-14 | standard | SVHN | layer 13 | c_proj
# [1167/2472] ViT-L-14 | standard | SVHN | layer 14 | c_fc
# [1168/2472] ViT-L-14 | standard | SVHN | layer 15 | c_proj
# [1169/2472] ViT-L-14 | standard | SVHN | layer 16 | c_fc
# [1170/2472] ViT-L-14 | standard | SVHN | layer 17 | c_proj
# [1171/2472] ViT-L-14 | standard | SVHN | layer 18 | c_fc
# [1172/2472] ViT-L-14 | standard | SVHN | layer 19 | c_proj
# [1173/2472] ViT-L-14 | standard | SVHN | layer 20 | c_fc
# [1174/2472] ViT-L-14 | standard | SVHN | layer 21 | c_proj
# [1175/2472] ViT-L-14 | standard | SVHN | layer 22 | c_fc
# [1176/2472] ViT-L-14 | standard | SVHN | layer 23 | c_proj
# [1177/2472] ViT-L-14 | standard | SVHN | layer 24 | c_fc
# [1178/2472] ViT-L-14 | standard | SVHN | layer 25 | c_proj
# [1179/2472] ViT-L-14 | standard | SVHN | layer 26 | c_fc
# [1180/2472] ViT-L-14 | standard | SVHN | layer 27 | c_proj
# [1181/2472] ViT-L-14 | standard | SVHN | layer 28 | c_fc
# [1182/2472] ViT-L-14 | standard | SVHN | layer 29 | c_proj
# [1183/2472] ViT-L-14 | standard | SVHN | layer 30 | c_fc
# [1184/2472] ViT-L-14 | standard | SVHN | layer 31 | c_proj
# [1185/2472] ViT-L-14 | standard | SVHN | layer 32 | c_fc
# [1186/2472] ViT-L-14 | standard | SVHN | layer 33 | c_proj
# [1187/2472] ViT-L-14 | standard | SVHN | layer 34 | c_fc
# [1188/2472] ViT-L-14 | standard | SVHN | layer 35 | c_proj
# [1189/2472] ViT-L-14 | standard | SVHN | layer 36 | c_fc
# [1190/2472] ViT-L-14 | standard | SVHN | layer 37 | c_proj
# [1191/2472] ViT-L-14 | standard | SVHN | layer 38 | c_fc
# [1192/2472] ViT-L-14 | standard | SVHN | layer 39 | c_proj
# [1193/2472] ViT-L-14 | standard | SVHN | layer 40 | c_fc
# [1194/2472] ViT-L-14 | standard | SVHN | layer 41 | c_proj
# [1195/2472] ViT-L-14 | standard | SVHN | layer 42 | c_fc
# [1196/2472] ViT-L-14 | standard | SVHN | layer 43 | c_proj
# [1197/2472] ViT-L-14 | standard | SVHN | layer 44 | c_fc
# [1198/2472] ViT-L-14 | standard | SVHN | layer 45 | c_proj
# [1199/2472] ViT-L-14 | standard | SVHN | layer 46 | c_fc
# [1200/2472] ViT-L-14 | standard | SVHN | layer 47 | c_proj
# [1201/2472] ViT-L-14 | standard | SVHN | layer 48 | q
# [1202/2472] ViT-L-14 | standard | SVHN | layer 49 | k
# [1203/2472] ViT-L-14 | standard | SVHN | layer 50 | v
# [1204/2472] ViT-L-14 | standard | SVHN | layer 51 | o
# [1205/2472] ViT-L-14 | standard | SVHN | layer 52 | q
# [1206/2472] ViT-L-14 | standard | SVHN | layer 53 | k
# [1207/2472] ViT-L-14 | standard | SVHN | layer 54 | v
# [1208/2472] ViT-L-14 | standard | SVHN | layer 55 | o
# [1209/2472] ViT-L-14 | standard | SVHN | layer 56 | q
# [1210/2472] ViT-L-14 | standard | SVHN | layer 57 | k
# [1211/2472] ViT-L-14 | standard | SVHN | layer 58 | v
# [1212/2472] ViT-L-14 | standard | SVHN | layer 59 | o
# [1213/2472] ViT-L-14 | standard | SVHN | layer 60 | q
# [1214/2472] ViT-L-14 | standard | SVHN | layer 61 | k
# [1215/2472] ViT-L-14 | standard | SVHN | layer 62 | v
# [1216/2472] ViT-L-14 | standard | SVHN | layer 63 | o
# [1217/2472] ViT-L-14 | standard | SVHN | layer 64 | q
# [1218/2472] ViT-L-14 | standard | SVHN | layer 65 | k
# [1219/2472] ViT-L-14 | standard | SVHN | layer 66 | v
# [1220/2472] ViT-L-14 | standard | SVHN | layer 67 | o
# [1221/2472] ViT-L-14 | standard | SVHN | layer 68 | q
# [1222/2472] ViT-L-14 | standard | SVHN | layer 69 | k
# [1223/2472] ViT-L-14 | standard | SVHN | layer 70 | v
# [1224/2472] ViT-L-14 | standard | SVHN | layer 71 | o
# [1225/2472] ViT-L-14 | standard | SVHN | layer 72 | q
# [1226/2472] ViT-L-14 | standard | SVHN | layer 73 | k
# [1227/2472] ViT-L-14 | standard | SVHN | layer 74 | v
# [1228/2472] ViT-L-14 | standard | SVHN | layer 75 | o
# [1229/2472] ViT-L-14 | standard | SVHN | layer 76 | q
# [1230/2472] ViT-L-14 | standard | SVHN | layer 77 | k
# [1231/2472] ViT-L-14 | standard | SVHN | layer 78 | v
# [1232/2472] ViT-L-14 | standard | SVHN | layer 79 | o
# [1233/2472] ViT-L-14 | standard | SVHN | layer 80 | q
# [1234/2472] ViT-L-14 | standard | SVHN | layer 81 | k
# [1235/2472] ViT-L-14 | standard | SVHN | layer 82 | v
# [1236/2472] ViT-L-14 | standard | SVHN | layer 83 | o
# [1237/2472] ViT-L-14 | standard | SVHN | layer 84 | q
# [1238/2472] ViT-L-14 | standard | SVHN | layer 85 | k
# [1239/2472] ViT-L-14 | standard | SVHN | layer 86 | v
# [1240/2472] ViT-L-14 | standard | SVHN | layer 87 | o
# [1241/2472] ViT-L-14 | standard | SVHN | layer 88 | q
# [1242/2472] ViT-L-14 | standard | SVHN | layer 89 | k
# [1243/2472] ViT-L-14 | standard | SVHN | layer 90 | v
# [1244/2472] ViT-L-14 | standard | SVHN | layer 91 | o
# [1245/2472] ViT-L-14 | standard | SVHN | layer 92 | q
# [1246/2472] ViT-L-14 | standard | SVHN | layer 93 | k
# [1247/2472] ViT-L-14 | standard | SVHN | layer 94 | v
# [1248/2472] ViT-L-14 | standard | SVHN | layer 95 | o
# [1249/2472] ViT-L-14 | standard | SVHN | layer 96 | q
# [1250/2472] ViT-L-14 | standard | SVHN | layer 97 | k
# [1251/2472] ViT-L-14 | standard | SVHN | layer 98 | v
# [1252/2472] ViT-L-14 | standard | SVHN | layer 99 | o
# [1253/2472] ViT-L-14 | standard | SVHN | layer 100 | q
# [1254/2472] ViT-L-14 | standard | SVHN | layer 101 | k
# [1255/2472] ViT-L-14 | standard | SVHN | layer 102 | v
# [1256/2472] ViT-L-14 | standard | SVHN | layer 103 | o
# [1257/2472] ViT-L-14 | standard | SVHN | layer 104 | q
# [1258/2472] ViT-L-14 | standard | SVHN | layer 105 | k
# [1259/2472] ViT-L-14 | standard | SVHN | layer 106 | v
# [1260/2472] ViT-L-14 | standard | SVHN | layer 107 | o
# [1261/2472] ViT-L-14 | standard | SVHN | layer 108 | q
# [1262/2472] ViT-L-14 | standard | SVHN | layer 109 | k
# [1263/2472] ViT-L-14 | standard | SVHN | layer 110 | v
# [1264/2472] ViT-L-14 | standard | SVHN | layer 111 | o
# [1265/2472] ViT-L-14 | standard | SVHN | layer 112 | q
# [1266/2472] ViT-L-14 | standard | SVHN | layer 113 | k
# [1267/2472] ViT-L-14 | standard | SVHN | layer 114 | v
# [1268/2472] ViT-L-14 | standard | SVHN | layer 115 | o
# [1269/2472] ViT-L-14 | standard | SVHN | layer 116 | q
# [1270/2472] ViT-L-14 | standard | SVHN | layer 117 | k
# [1271/2472] ViT-L-14 | standard | SVHN | layer 118 | v
# [1272/2472] ViT-L-14 | standard | SVHN | layer 119 | o
# [1273/2472] ViT-L-14 | standard | SVHN | layer 120 | q
# [1274/2472] ViT-L-14 | standard | SVHN | layer 121 | k
# [1275/2472] ViT-L-14 | standard | SVHN | layer 122 | v
# [1276/2472] ViT-L-14 | standard | SVHN | layer 123 | o
# [1277/2472] ViT-L-14 | standard | SVHN | layer 124 | q
# [1278/2472] ViT-L-14 | standard | SVHN | layer 125 | k
# [1279/2472] ViT-L-14 | standard | SVHN | layer 126 | v
# [1280/2472] ViT-L-14 | standard | SVHN | layer 127 | o
# [1281/2472] ViT-L-14 | standard | SVHN | layer 128 | q
# [1282/2472] ViT-L-14 | standard | SVHN | layer 129 | k
# [1283/2472] ViT-L-14 | standard | SVHN | layer 130 | v
# [1284/2472] ViT-L-14 | standard | SVHN | layer 131 | o
# [1285/2472] ViT-L-14 | standard | SVHN | layer 132 | q
# [1286/2472] ViT-L-14 | standard | SVHN | layer 133 | k
# [1287/2472] ViT-L-14 | standard | SVHN | layer 134 | v
# [1288/2472] ViT-L-14 | standard | SVHN | layer 135 | o
# [1289/2472] ViT-L-14 | standard | SVHN | layer 136 | q
# [1290/2472] ViT-L-14 | standard | SVHN | layer 137 | k
# [1291/2472] ViT-L-14 | standard | SVHN | layer 138 | v
# [1292/2472] ViT-L-14 | standard | SVHN | layer 139 | o
# [1293/2472] ViT-L-14 | standard | SVHN | layer 140 | q
# [1294/2472] ViT-L-14 | standard | SVHN | layer 141 | k
# [1295/2472] ViT-L-14 | standard | SVHN | layer 142 | v
# [1296/2472] ViT-L-14 | standard | SVHN | layer 143 | o

# %%
import re
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

BASE_FONTSIZE = 24
BATCH_SIZE = 32
NUM_SAMPLES = 10

sns.set_theme(rc={
    "font.size": BASE_FONTSIZE,
    "axes.titlesize": BASE_FONTSIZE,
    "axes.labelsize": BASE_FONTSIZE,
    "xtick.labelsize": BASE_FONTSIZE * 0.8,
    "ytick.labelsize": BASE_FONTSIZE * 0.8,
    "legend.fontsize": BASE_FONTSIZE * 0.8,
    "legend.title_fontsize": BASE_FONTSIZE * 0.8,
})

MODEL_MAP = {"ViT-B-16": "ViT-B/16", "ViT-B-32": "ViT-B/32", "ViT-L-14": "ViT-L/14"}

df = pd.read_csv(f"../results/eigcov_estimation_error_vision_n{NUM_SAMPLES}_b{BATCH_SIZE}.csv")
df = df[df["ft_method"] == "standard"]
df = df[df["method"] != "Zeros"]
df["model"] = df["model"].map(MODEL_MAP).fillna(df["model"])

# Re-index layers: natural sort by layer_name within each model
def natural_sort_key(s):
    return [int(tok) if tok.isdigit() else tok for tok in re.split(r'(\d+)', s)]

for model in df["model"].unique():
    sorted_layers = sorted(df.loc[df["model"] == model, "layer_name"].unique(), key=natural_sort_key)
    layer_to_idx = {name: idx for idx, name in enumerate(sorted_layers)}
    df.loc[df["model"] == model, "layer_idx"] = df.loc[df["model"] == model, "layer_name"].map(layer_to_idx)
df["layer_idx"] = df["layer_idx"].astype(int)
df = df.sort_values("layer_idx")

g = sns.relplot(
    data=df,
    x="layer_idx",
    y="error",
    hue="method",
    col="model",
    kind="line",
    legend="brief",
    facet_kws={"sharey": True, "sharex": False},
)

g.set_axis_labels("Layer Index", "Cosine Distance")
g.set_titles(col_template="{col_name}")
g.legend.set_title("Method")
g.figure.savefig(
    f"../results/eigcov_estimation_error_vision_layer_wise.pdf",
    dpi=300,
    bbox_inches="tight",
)

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

BASE_FONTSIZE = 24
BATCH_SIZE = 32
NUM_SAMPLES = 10

sns.set_theme(rc={
    "font.size": BASE_FONTSIZE,
    "axes.titlesize": BASE_FONTSIZE,
    "axes.labelsize": BASE_FONTSIZE,
    "xtick.labelsize": BASE_FONTSIZE * 0.8,
    "ytick.labelsize": BASE_FONTSIZE * 0.8,
    "legend.fontsize": BASE_FONTSIZE * 0.8,
    "legend.title_fontsize": BASE_FONTSIZE * 0.8,
})

MODEL_MAP = {"ViT-B-16": "ViT-B/16", "ViT-B-32": "ViT-B/32", "ViT-L-14": "ViT-L/14"}

df = pd.read_csv(f"../results/eigcov_estimation_error_vision_n{NUM_SAMPLES}_b{BATCH_SIZE}.csv")
df = df[df["ft_method"] == "standard"]
df = df[df["method"] != "Zeros"]
df["model"] = df["model"].map(MODEL_MAP).fillna(df["model"])

g = sns.catplot(
    data=df,
    x="dataset",
    y="error",
    hue="method",
    col="model",
    kind="bar",
    # legend="brief",
    legend=False,
    sharey=True,
    hue_order=["EigenCov", "Identity", "Random"],
)

g.set_axis_labels("Dataset", "Cosine Distance")
g.set_titles(col_template="{col_name}")
# g.legend.set_title("Method")
g.set_xticklabels(rotation=45, ha="right")
g.figure.savefig(
    f"../results/eigcov_estimation_error_vision_dataset_wise.pdf",
    dpi=300,
    bbox_inches="tight",
)

# %%
import re
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

BASE_FONTSIZE = 24
BATCH_SIZE = 32
NUM_SAMPLES = 10

sns.set_theme(rc={
    "font.size": BASE_FONTSIZE,
    "axes.titlesize": BASE_FONTSIZE,
    "axes.labelsize": BASE_FONTSIZE,
    "xtick.labelsize": BASE_FONTSIZE * 0.8,
    "ytick.labelsize": BASE_FONTSIZE * 0.8,
    "legend.fontsize": BASE_FONTSIZE * 0.8,
    "legend.title_fontsize": BASE_FONTSIZE * 0.8,
})

df = pd.read_csv(f"../results/eigcov_estimation_error_vision_n{NUM_SAMPLES}_b{BATCH_SIZE}.csv")
df = df[df["ft_method"] == "standard"]
df = df[df["method"] != "Zeros"]
df = df[df["model"] == "ViT-B-16"]

# Re-index layers: natural sort by layer_name
def natural_sort_key(s):
    return [int(tok) if tok.isdigit() else tok for tok in re.split(r'(\d+)', s)]

sorted_layers = sorted(df["layer_name"].unique(), key=natural_sort_key)
layer_to_idx = {name: idx for idx, name in enumerate(sorted_layers)}
df["layer_idx"] = df["layer_name"].map(layer_to_idx).astype(int)

df = df[df["layer_idx"] < 25]
df['layer_abbrv'] = df['layer_name'].apply(lambda k: k.replace("model.visual.transformer.resblocks.", ""))
df = df.sort_values("layer_idx")

g = sns.relplot(
    data=df,
    x="layer_abbrv",
    y="error",
    hue="method",
    kind="line",
    legend="brief",
    facet_kws={"sharey": True},
    height=6,
    aspect=2.2,
    hue_order=["EigenCov", "Identity", "Random"],
)

g.set_axis_labels("Layer Index", "Cosine Distance")
g.set_titles(col_template="{col_name}")

for ax in g.axes.flat:
    plt.setp(ax.get_xticklabels(), rotation=45, ha='right', rotation_mode='anchor')
    plt.setp(ax.get_yticklabels(), rotation=45, ha='right', rotation_mode='anchor')

if g.legend:
    g.legend.set_title("Method")

# %% [markdown]
# ## Fig.1b: EigCov Estimation Error (Language)

# %%
import sys
import os
from tqdm import tqdm
from itertools import product

import torch
import numpy as np
import pandas as pd

sys.path.append("..")
from src.language.task_vectors import LanguageNonLinearTaskVector

MODELS = ["t5-base", "t5-large"]
DATASETS = ["qasc", "wiki_qa", "quartz", "paws", "story_cloze", "winogrande", "wsc"]
FT_METHODS = ["standard"]
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
BATCH_SIZE = 32
NUM_SAMPLES = 10
RESULTS_ROOT = "../results"
CHECKPOINTS_ROOT = "../checkpoints"
SAVE_PATH = os.path.join(RESULTS_ROOT, f"eigcov_estimation_error_lang_n{NUM_SAMPLES}_b{BATCH_SIZE}.csv")

param_key_to_cov_key = lambda name: name.replace(".weight", "")

def dist_cos_noabs(A: torch.Tensor, B: torch.Tensor) -> torch.Tensor:
    a = A.flatten()
    b = B.flatten()
    cos_theta = torch.dot(a, b) / (a.norm() * b.norm())
    return (1 - cos_theta) / 2

max_layers_per_combo = MAX_LAYERS + 1 if MAX_LAYERS is not None else None
TOTAL = len(MODELS) * len(FT_METHODS) * len(DATASETS) * (max_layers_per_combo or 0)
global_step = 0

rows = []
for model_name in MODELS:
    results_dir = os.path.join(RESULTS_ROOT, model_name)
    checkpoint_dir = os.path.join(CHECKPOINTS_ROOT, model_name)

    for ft_method, dataset in product(FT_METHODS, DATASETS):
        cov_path = f"{results_dir}/covariances_strain_n{NUM_SAMPLES}_b{BATCH_SIZE}_tsm_efull_ft{ft_method}/covariance_{dataset}.npz"
        if not os.path.exists(cov_path):
            print(f"Missing covariance: {cov_path}")
            continue
        covs = np.load(cov_path, allow_pickle=True)

        pretrained_checkpoint = f"{checkpoint_dir}/{dataset}/zeroshot.pt"
        finetuned_checkpoint = f"{checkpoint_dir}/{dataset}/finetuned.pt"
        task_vector = LanguageNonLinearTaskVector(
            pretrained_checkpoint,
            finetuned_checkpoint,
        )

        num_added = 0
        if TOTAL == 0 and MAX_LAYERS is None:
            TOTAL = len(MODELS) * len(FT_METHODS) * len(DATASETS) * len(task_vector.vector)
        for k, m in task_vector.vector.items():
            kp = param_key_to_cov_key(k)
            if len(m.shape) != 2 or kp not in covs.keys():
                continue
            m = m.to(DEVICE)
            c = torch.from_numpy(covs[kp]).to(m.dtype).to(DEVICE)
            c_hat_ident = torch.eye(c.shape[0], c.shape[1], dtype=c.dtype, device=DEVICE)
            c_hat_ec = m.T @ m
            c_hat_rand = torch.randn_like(c, device=DEVICE)
            for method, c_hat in [
                ("EigenCov", c_hat_ec),
                ("Random", c_hat_rand),
                ("Identity", c_hat_ident),
            ]:
                rows.append({
                    "model": model_name, "dataset": dataset, "layer_name": k,
                    "layer_idx": num_added, "method": method,
                    "error": dist_cos_noabs(c, c_hat).item(), "ft_method": ft_method,
                })
            global_step += 1
            print(f"[{global_step}/{TOTAL}] {model_name} | {ft_method} | {dataset} | layer {num_added} | {k.split('.')[-2]}")
            num_added += 1
            if MAX_LAYERS is not None and num_added > MAX_LAYERS:
                break

df_lang = pd.DataFrame(rows)
df_lang.to_csv(SAVE_PATH, index=False)
# Out:
# [1/3640] t5-base | standard | qasc | layer 0 | q
# [2/3640] t5-base | standard | qasc | layer 1 | k
# [3/3640] t5-base | standard | qasc | layer 2 | v
# [4/3640] t5-base | standard | qasc | layer 3 | o
# [5/3640] t5-base | standard | qasc | layer 4 | wi
# [6/3640] t5-base | standard | qasc | layer 5 | wo
# [7/3640] t5-base | standard | qasc | layer 6 | q
# [8/3640] t5-base | standard | qasc | layer 7 | k
# [9/3640] t5-base | standard | qasc | layer 8 | v
# [10/3640] t5-base | standard | qasc | layer 9 | o
# [11/3640] t5-base | standard | qasc | layer 10 | wi
# [12/3640] t5-base | standard | qasc | layer 11 | wo
# [13/3640] t5-base | standard | qasc | layer 12 | q
# [14/3640] t5-base | standard | qasc | layer 13 | k
# [15/3640] t5-base | standard | qasc | layer 14 | v
# [16/3640] t5-base | standard | qasc | layer 15 | o
# [17/3640] t5-base | standard | qasc | layer 16 | wi
# [18/3640] t5-base | standard | qasc | layer 17 | wo
# [19/3640] t5-base | standard | qasc | layer 18 | q
# [20/3640] t5-base | standard | qasc | layer 19 | k
# [21/3640] t5-base | standard | qasc | layer 20 | v
# [22/3640] t5-base | standard | qasc | layer 21 | o
# [23/3640] t5-base | standard | qasc | layer 22 | wi
# [24/3640] t5-base | standard | qasc | layer 23 | wo
# [25/3640] t5-base | standard | qasc | layer 24 | q
# [26/3640] t5-base | standard | qasc | layer 25 | k
# [27/3640] t5-base | standard | qasc | layer 26 | v
# [28/3640] t5-base | standard | qasc | layer 27 | o
# [29/3640] t5-base | standard | qasc | layer 28 | wi
# [30/3640] t5-base | standard | qasc | layer 29 | wo
# [31/3640] t5-base | standard | qasc | layer 30 | q
# [32/3640] t5-base | standard | qasc | layer 31 | k
# [33/3640] t5-base | standard | qasc | layer 32 | v
# [34/3640] t5-base | standard | qasc | layer 33 | o
# [35/3640] t5-base | standard | qasc | layer 34 | wi
# [36/3640] t5-base | standard | qasc | layer 35 | wo
# [37/3640] t5-base | standard | qasc | layer 36 | q
# [38/3640] t5-base | standard | qasc | layer 37 | k
# [39/3640] t5-base | standard | qasc | layer 38 | v
# [40/3640] t5-base | standard | qasc | layer 39 | o
# [41/3640] t5-base | standard | qasc | layer 40 | wi
# [42/3640] t5-base | standard | qasc | layer 41 | wo
# [43/3640] t5-base | standard | qasc | layer 42 | q
# [44/3640] t5-base | standard | qasc | layer 43 | k
# [45/3640] t5-base | standard | qasc | layer 44 | v
# [46/3640] t5-base | standard | qasc | layer 45 | o
# [47/3640] t5-base | standard | qasc | layer 46 | wi
# [48/3640] t5-base | standard | qasc | layer 47 | wo
# [49/3640] t5-base | standard | qasc | layer 48 | q
# [50/3640] t5-base | standard | qasc | layer 49 | k
# [51/3640] t5-base | standard | qasc | layer 50 | v
# [52/3640] t5-base | standard | qasc | layer 51 | o
# [53/3640] t5-base | standard | qasc | layer 52 | wi
# [54/3640] t5-base | standard | qasc | layer 53 | wo
# [55/3640] t5-base | standard | qasc | layer 54 | q
# [56/3640] t5-base | standard | qasc | layer 55 | k
# [57/3640] t5-base | standard | qasc | layer 56 | v
# [58/3640] t5-base | standard | qasc | layer 57 | o
# [59/3640] t5-base | standard | qasc | layer 58 | wi
# [60/3640] t5-base | standard | qasc | layer 59 | wo
# [61/3640] t5-base | standard | qasc | layer 60 | q
# [62/3640] t5-base | standard | qasc | layer 61 | k
# [63/3640] t5-base | standard | qasc | layer 62 | v
# [64/3640] t5-base | standard | qasc | layer 63 | o
# [65/3640] t5-base | standard | qasc | layer 64 | wi
# [66/3640] t5-base | standard | qasc | layer 65 | wo
# [67/3640] t5-base | standard | qasc | layer 66 | q
# [68/3640] t5-base | standard | qasc | layer 67 | k
# [69/3640] t5-base | standard | qasc | layer 68 | v
# [70/3640] t5-base | standard | qasc | layer 69 | o
# [71/3640] t5-base | standard | qasc | layer 70 | wi
# [72/3640] t5-base | standard | qasc | layer 71 | wo
# [73/3640] t5-base | standard | qasc | layer 72 | q
# [74/3640] t5-base | standard | qasc | layer 73 | k
# [75/3640] t5-base | standard | qasc | layer 74 | v
# [76/3640] t5-base | standard | qasc | layer 75 | o
# [77/3640] t5-base | standard | qasc | layer 76 | q
# [78/3640] t5-base | standard | qasc | layer 77 | k
# [79/3640] t5-base | standard | qasc | layer 78 | v
# [80/3640] t5-base | standard | qasc | layer 79 | o
# [81/3640] t5-base | standard | qasc | layer 80 | wi
# [82/3640] t5-base | standard | qasc | layer 81 | wo
# [83/3640] t5-base | standard | qasc | layer 82 | q
# [84/3640] t5-base | standard | qasc | layer 83 | k
# [85/3640] t5-base | standard | qasc | layer 84 | v
# [86/3640] t5-base | standard | qasc | layer 85 | o
# [87/3640] t5-base | standard | qasc | layer 86 | q
# [88/3640] t5-base | standard | qasc | layer 87 | k
# [89/3640] t5-base | standard | qasc | layer 88 | v
# [90/3640] t5-base | standard | qasc | layer 89 | o
# [91/3640] t5-base | standard | qasc | layer 90 | wi
# [92/3640] t5-base | standard | qasc | layer 91 | wo
# [93/3640] t5-base | standard | qasc | layer 92 | q
# [94/3640] t5-base | standard | qasc | layer 93 | k
# [95/3640] t5-base | standard | qasc | layer 94 | v
# [96/3640] t5-base | standard | qasc | layer 95 | o
# [97/3640] t5-base | standard | qasc | layer 96 | q
# [98/3640] t5-base | standard | qasc | layer 97 | k
# [99/3640] t5-base | standard | qasc | layer 98 | v
# [100/3640] t5-base | standard | qasc | layer 99 | o
# [101/3640] t5-base | standard | qasc | layer 100 | wi
# [102/3640] t5-base | standard | qasc | layer 101 | wo
# [103/3640] t5-base | standard | qasc | layer 102 | q
# [104/3640] t5-base | standard | qasc | layer 103 | k
# [105/3640] t5-base | standard | qasc | layer 104 | v
# [106/3640] t5-base | standard | qasc | layer 105 | o
# [107/3640] t5-base | standard | qasc | layer 106 | q
# [108/3640] t5-base | standard | qasc | layer 107 | k
# [109/3640] t5-base | standard | qasc | layer 108 | v
# [110/3640] t5-base | standard | qasc | layer 109 | o
# [111/3640] t5-base | standard | qasc | layer 110 | wi
# [112/3640] t5-base | standard | qasc | layer 111 | wo
# [113/3640] t5-base | standard | qasc | layer 112 | q
# [114/3640] t5-base | standard | qasc | layer 113 | k
# [115/3640] t5-base | standard | qasc | layer 114 | v
# [116/3640] t5-base | standard | qasc | layer 115 | o
# [117/3640] t5-base | standard | qasc | layer 116 | q
# [118/3640] t5-base | standard | qasc | layer 117 | k
# [119/3640] t5-base | standard | qasc | layer 118 | v
# [120/3640] t5-base | standard | qasc | layer 119 | o
# [121/3640] t5-base | standard | qasc | layer 120 | wi
# [122/3640] t5-base | standard | qasc | layer 121 | wo
# [123/3640] t5-base | standard | qasc | layer 122 | q
# [124/3640] t5-base | standard | qasc | layer 123 | k
# [125/3640] t5-base | standard | qasc | layer 124 | v
# [126/3640] t5-base | standard | qasc | layer 125 | o
# [127/3640] t5-base | standard | qasc | layer 126 | q
# [128/3640] t5-base | standard | qasc | layer 127 | k
# [129/3640] t5-base | standard | qasc | layer 128 | v
# [130/3640] t5-base | standard | qasc | layer 129 | o
# [131/3640] t5-base | standard | qasc | layer 130 | wi
# [132/3640] t5-base | standard | qasc | layer 131 | wo
# [133/3640] t5-base | standard | qasc | layer 132 | q
# [134/3640] t5-base | standard | qasc | layer 133 | k
# [135/3640] t5-base | standard | qasc | layer 134 | v
# [136/3640] t5-base | standard | qasc | layer 135 | o
# [137/3640] t5-base | standard | qasc | layer 136 | q
# [138/3640] t5-base | standard | qasc | layer 137 | k
# [139/3640] t5-base | standard | qasc | layer 138 | v
# [140/3640] t5-base | standard | qasc | layer 139 | o
# [141/3640] t5-base | standard | qasc | layer 140 | wi
# [142/3640] t5-base | standard | qasc | layer 141 | wo
# [143/3640] t5-base | standard | qasc | layer 142 | q
# [144/3640] t5-base | standard | qasc | layer 143 | k
# [145/3640] t5-base | standard | qasc | layer 144 | v
# [146/3640] t5-base | standard | qasc | layer 145 | o
# [147/3640] t5-base | standard | qasc | layer 146 | q
# [148/3640] t5-base | standard | qasc | layer 147 | k
# [149/3640] t5-base | standard | qasc | layer 148 | v
# [150/3640] t5-base | standard | qasc | layer 149 | o
# [151/3640] t5-base | standard | qasc | layer 150 | wi
# [152/3640] t5-base | standard | qasc | layer 151 | wo
# [153/3640] t5-base | standard | qasc | layer 152 | q
# [154/3640] t5-base | standard | qasc | layer 153 | k
# [155/3640] t5-base | standard | qasc | layer 154 | v
# [156/3640] t5-base | standard | qasc | layer 155 | o
# [157/3640] t5-base | standard | qasc | layer 156 | q
# [158/3640] t5-base | standard | qasc | layer 157 | k
# [159/3640] t5-base | standard | qasc | layer 158 | v
# [160/3640] t5-base | standard | qasc | layer 159 | o
# [161/3640] t5-base | standard | qasc | layer 160 | wi
# [162/3640] t5-base | standard | qasc | layer 161 | wo
# [163/3640] t5-base | standard | qasc | layer 162 | q
# [164/3640] t5-base | standard | qasc | layer 163 | k
# [165/3640] t5-base | standard | qasc | layer 164 | v
# [166/3640] t5-base | standard | qasc | layer 165 | o
# [167/3640] t5-base | standard | qasc | layer 166 | q
# [168/3640] t5-base | standard | qasc | layer 167 | k
# [169/3640] t5-base | standard | qasc | layer 168 | v
# [170/3640] t5-base | standard | qasc | layer 169 | o
# [171/3640] t5-base | standard | qasc | layer 170 | wi
# [172/3640] t5-base | standard | qasc | layer 171 | wo
# [173/3640] t5-base | standard | qasc | layer 172 | q
# [174/3640] t5-base | standard | qasc | layer 173 | k
# [175/3640] t5-base | standard | qasc | layer 174 | v
# [176/3640] t5-base | standard | qasc | layer 175 | o
# [177/3640] t5-base | standard | qasc | layer 176 | q
# [178/3640] t5-base | standard | qasc | layer 177 | k
# [179/3640] t5-base | standard | qasc | layer 178 | v
# [180/3640] t5-base | standard | qasc | layer 179 | o
# [181/3640] t5-base | standard | qasc | layer 180 | wi
# [182/3640] t5-base | standard | qasc | layer 181 | wo
# [183/3640] t5-base | standard | qasc | layer 182 | q
# [184/3640] t5-base | standard | qasc | layer 183 | k
# [185/3640] t5-base | standard | qasc | layer 184 | v
# [186/3640] t5-base | standard | qasc | layer 185 | o
# [187/3640] t5-base | standard | qasc | layer 186 | q
# [188/3640] t5-base | standard | qasc | layer 187 | k
# [189/3640] t5-base | standard | qasc | layer 188 | v
# [190/3640] t5-base | standard | qasc | layer 189 | o
# [191/3640] t5-base | standard | qasc | layer 190 | wi
# [192/3640] t5-base | standard | qasc | layer 191 | wo
# [193/3640] t5-base | standard | qasc | layer 192 | lm_head
# [194/3640] t5-base | standard | wiki_qa | layer 0 | q
# [195/3640] t5-base | standard | wiki_qa | layer 1 | k
# [196/3640] t5-base | standard | wiki_qa | layer 2 | v
# [197/3640] t5-base | standard | wiki_qa | layer 3 | o
# [198/3640] t5-base | standard | wiki_qa | layer 4 | wi
# [199/3640] t5-base | standard | wiki_qa | layer 5 | wo
# [200/3640] t5-base | standard | wiki_qa | layer 6 | q
# [201/3640] t5-base | standard | wiki_qa | layer 7 | k
# [202/3640] t5-base | standard | wiki_qa | layer 8 | v
# [203/3640] t5-base | standard | wiki_qa | layer 9 | o
# [204/3640] t5-base | standard | wiki_qa | layer 10 | wi
# [205/3640] t5-base | standard | wiki_qa | layer 11 | wo
# [206/3640] t5-base | standard | wiki_qa | layer 12 | q
# [207/3640] t5-base | standard | wiki_qa | layer 13 | k
# [208/3640] t5-base | standard | wiki_qa | layer 14 | v
# [209/3640] t5-base | standard | wiki_qa | layer 15 | o
# [210/3640] t5-base | standard | wiki_qa | layer 16 | wi
# [211/3640] t5-base | standard | wiki_qa | layer 17 | wo
# [212/3640] t5-base | standard | wiki_qa | layer 18 | q
# [213/3640] t5-base | standard | wiki_qa | layer 19 | k
# [214/3640] t5-base | standard | wiki_qa | layer 20 | v
# [215/3640] t5-base | standard | wiki_qa | layer 21 | o
# [216/3640] t5-base | standard | wiki_qa | layer 22 | wi
# [217/3640] t5-base | standard | wiki_qa | layer 23 | wo
# [218/3640] t5-base | standard | wiki_qa | layer 24 | q
# [219/3640] t5-base | standard | wiki_qa | layer 25 | k
# [220/3640] t5-base | standard | wiki_qa | layer 26 | v
# [221/3640] t5-base | standard | wiki_qa | layer 27 | o
# [222/3640] t5-base | standard | wiki_qa | layer 28 | wi
# [223/3640] t5-base | standard | wiki_qa | layer 29 | wo
# [224/3640] t5-base | standard | wiki_qa | layer 30 | q
# [225/3640] t5-base | standard | wiki_qa | layer 31 | k
# [226/3640] t5-base | standard | wiki_qa | layer 32 | v
# [227/3640] t5-base | standard | wiki_qa | layer 33 | o
# [228/3640] t5-base | standard | wiki_qa | layer 34 | wi
# [229/3640] t5-base | standard | wiki_qa | layer 35 | wo
# [230/3640] t5-base | standard | wiki_qa | layer 36 | q
# [231/3640] t5-base | standard | wiki_qa | layer 37 | k
# [232/3640] t5-base | standard | wiki_qa | layer 38 | v
# [233/3640] t5-base | standard | wiki_qa | layer 39 | o
# [234/3640] t5-base | standard | wiki_qa | layer 40 | wi
# [235/3640] t5-base | standard | wiki_qa | layer 41 | wo
# [236/3640] t5-base | standard | wiki_qa | layer 42 | q
# [237/3640] t5-base | standard | wiki_qa | layer 43 | k
# [238/3640] t5-base | standard | wiki_qa | layer 44 | v
# [239/3640] t5-base | standard | wiki_qa | layer 45 | o
# [240/3640] t5-base | standard | wiki_qa | layer 46 | wi
# [241/3640] t5-base | standard | wiki_qa | layer 47 | wo
# [242/3640] t5-base | standard | wiki_qa | layer 48 | q
# [243/3640] t5-base | standard | wiki_qa | layer 49 | k
# [244/3640] t5-base | standard | wiki_qa | layer 50 | v
# [245/3640] t5-base | standard | wiki_qa | layer 51 | o
# [246/3640] t5-base | standard | wiki_qa | layer 52 | wi
# [247/3640] t5-base | standard | wiki_qa | layer 53 | wo
# [248/3640] t5-base | standard | wiki_qa | layer 54 | q
# [249/3640] t5-base | standard | wiki_qa | layer 55 | k
# [250/3640] t5-base | standard | wiki_qa | layer 56 | v
# [251/3640] t5-base | standard | wiki_qa | layer 57 | o
# [252/3640] t5-base | standard | wiki_qa | layer 58 | wi
# [253/3640] t5-base | standard | wiki_qa | layer 59 | wo
# [254/3640] t5-base | standard | wiki_qa | layer 60 | q
# [255/3640] t5-base | standard | wiki_qa | layer 61 | k
# [256/3640] t5-base | standard | wiki_qa | layer 62 | v
# [257/3640] t5-base | standard | wiki_qa | layer 63 | o
# [258/3640] t5-base | standard | wiki_qa | layer 64 | wi
# [259/3640] t5-base | standard | wiki_qa | layer 65 | wo
# [260/3640] t5-base | standard | wiki_qa | layer 66 | q
# [261/3640] t5-base | standard | wiki_qa | layer 67 | k
# [262/3640] t5-base | standard | wiki_qa | layer 68 | v
# [263/3640] t5-base | standard | wiki_qa | layer 69 | o
# [264/3640] t5-base | standard | wiki_qa | layer 70 | wi
# [265/3640] t5-base | standard | wiki_qa | layer 71 | wo
# [266/3640] t5-base | standard | wiki_qa | layer 72 | q
# [267/3640] t5-base | standard | wiki_qa | layer 73 | k
# [268/3640] t5-base | standard | wiki_qa | layer 74 | v
# [269/3640] t5-base | standard | wiki_qa | layer 75 | o
# [270/3640] t5-base | standard | wiki_qa | layer 76 | q
# [271/3640] t5-base | standard | wiki_qa | layer 77 | k
# [272/3640] t5-base | standard | wiki_qa | layer 78 | v
# [273/3640] t5-base | standard | wiki_qa | layer 79 | o
# [274/3640] t5-base | standard | wiki_qa | layer 80 | wi
# [275/3640] t5-base | standard | wiki_qa | layer 81 | wo
# [276/3640] t5-base | standard | wiki_qa | layer 82 | q
# [277/3640] t5-base | standard | wiki_qa | layer 83 | k
# [278/3640] t5-base | standard | wiki_qa | layer 84 | v
# [279/3640] t5-base | standard | wiki_qa | layer 85 | o
# [280/3640] t5-base | standard | wiki_qa | layer 86 | q
# [281/3640] t5-base | standard | wiki_qa | layer 87 | k
# [282/3640] t5-base | standard | wiki_qa | layer 88 | v
# [283/3640] t5-base | standard | wiki_qa | layer 89 | o
# [284/3640] t5-base | standard | wiki_qa | layer 90 | wi
# [285/3640] t5-base | standard | wiki_qa | layer 91 | wo
# [286/3640] t5-base | standard | wiki_qa | layer 92 | q
# [287/3640] t5-base | standard | wiki_qa | layer 93 | k
# [288/3640] t5-base | standard | wiki_qa | layer 94 | v
# [289/3640] t5-base | standard | wiki_qa | layer 95 | o
# [290/3640] t5-base | standard | wiki_qa | layer 96 | q
# [291/3640] t5-base | standard | wiki_qa | layer 97 | k
# [292/3640] t5-base | standard | wiki_qa | layer 98 | v
# [293/3640] t5-base | standard | wiki_qa | layer 99 | o
# [294/3640] t5-base | standard | wiki_qa | layer 100 | wi
# [295/3640] t5-base | standard | wiki_qa | layer 101 | wo
# [296/3640] t5-base | standard | wiki_qa | layer 102 | q
# [297/3640] t5-base | standard | wiki_qa | layer 103 | k
# [298/3640] t5-base | standard | wiki_qa | layer 104 | v
# [299/3640] t5-base | standard | wiki_qa | layer 105 | o
# [300/3640] t5-base | standard | wiki_qa | layer 106 | q
# [301/3640] t5-base | standard | wiki_qa | layer 107 | k
# [302/3640] t5-base | standard | wiki_qa | layer 108 | v
# [303/3640] t5-base | standard | wiki_qa | layer 109 | o
# [304/3640] t5-base | standard | wiki_qa | layer 110 | wi
# [305/3640] t5-base | standard | wiki_qa | layer 111 | wo
# [306/3640] t5-base | standard | wiki_qa | layer 112 | q
# [307/3640] t5-base | standard | wiki_qa | layer 113 | k
# [308/3640] t5-base | standard | wiki_qa | layer 114 | v
# [309/3640] t5-base | standard | wiki_qa | layer 115 | o
# [310/3640] t5-base | standard | wiki_qa | layer 116 | q
# [311/3640] t5-base | standard | wiki_qa | layer 117 | k
# [312/3640] t5-base | standard | wiki_qa | layer 118 | v
# [313/3640] t5-base | standard | wiki_qa | layer 119 | o
# [314/3640] t5-base | standard | wiki_qa | layer 120 | wi
# [315/3640] t5-base | standard | wiki_qa | layer 121 | wo
# [316/3640] t5-base | standard | wiki_qa | layer 122 | q
# [317/3640] t5-base | standard | wiki_qa | layer 123 | k
# [318/3640] t5-base | standard | wiki_qa | layer 124 | v
# [319/3640] t5-base | standard | wiki_qa | layer 125 | o
# [320/3640] t5-base | standard | wiki_qa | layer 126 | q
# [321/3640] t5-base | standard | wiki_qa | layer 127 | k
# [322/3640] t5-base | standard | wiki_qa | layer 128 | v
# [323/3640] t5-base | standard | wiki_qa | layer 129 | o
# [324/3640] t5-base | standard | wiki_qa | layer 130 | wi
# [325/3640] t5-base | standard | wiki_qa | layer 131 | wo
# [326/3640] t5-base | standard | wiki_qa | layer 132 | q
# [327/3640] t5-base | standard | wiki_qa | layer 133 | k
# [328/3640] t5-base | standard | wiki_qa | layer 134 | v
# [329/3640] t5-base | standard | wiki_qa | layer 135 | o
# [330/3640] t5-base | standard | wiki_qa | layer 136 | q
# [331/3640] t5-base | standard | wiki_qa | layer 137 | k
# [332/3640] t5-base | standard | wiki_qa | layer 138 | v
# [333/3640] t5-base | standard | wiki_qa | layer 139 | o
# [334/3640] t5-base | standard | wiki_qa | layer 140 | wi
# [335/3640] t5-base | standard | wiki_qa | layer 141 | wo
# [336/3640] t5-base | standard | wiki_qa | layer 142 | q
# [337/3640] t5-base | standard | wiki_qa | layer 143 | k
# [338/3640] t5-base | standard | wiki_qa | layer 144 | v
# [339/3640] t5-base | standard | wiki_qa | layer 145 | o
# [340/3640] t5-base | standard | wiki_qa | layer 146 | q
# [341/3640] t5-base | standard | wiki_qa | layer 147 | k
# [342/3640] t5-base | standard | wiki_qa | layer 148 | v
# [343/3640] t5-base | standard | wiki_qa | layer 149 | o
# [344/3640] t5-base | standard | wiki_qa | layer 150 | wi
# [345/3640] t5-base | standard | wiki_qa | layer 151 | wo
# [346/3640] t5-base | standard | wiki_qa | layer 152 | q
# [347/3640] t5-base | standard | wiki_qa | layer 153 | k
# [348/3640] t5-base | standard | wiki_qa | layer 154 | v
# [349/3640] t5-base | standard | wiki_qa | layer 155 | o
# [350/3640] t5-base | standard | wiki_qa | layer 156 | q
# [351/3640] t5-base | standard | wiki_qa | layer 157 | k
# [352/3640] t5-base | standard | wiki_qa | layer 158 | v
# [353/3640] t5-base | standard | wiki_qa | layer 159 | o
# [354/3640] t5-base | standard | wiki_qa | layer 160 | wi
# [355/3640] t5-base | standard | wiki_qa | layer 161 | wo
# [356/3640] t5-base | standard | wiki_qa | layer 162 | q
# [357/3640] t5-base | standard | wiki_qa | layer 163 | k
# [358/3640] t5-base | standard | wiki_qa | layer 164 | v
# [359/3640] t5-base | standard | wiki_qa | layer 165 | o
# [360/3640] t5-base | standard | wiki_qa | layer 166 | q
# [361/3640] t5-base | standard | wiki_qa | layer 167 | k
# [362/3640] t5-base | standard | wiki_qa | layer 168 | v
# [363/3640] t5-base | standard | wiki_qa | layer 169 | o
# [364/3640] t5-base | standard | wiki_qa | layer 170 | wi
# [365/3640] t5-base | standard | wiki_qa | layer 171 | wo
# [366/3640] t5-base | standard | wiki_qa | layer 172 | q
# [367/3640] t5-base | standard | wiki_qa | layer 173 | k
# [368/3640] t5-base | standard | wiki_qa | layer 174 | v
# [369/3640] t5-base | standard | wiki_qa | layer 175 | o
# [370/3640] t5-base | standard | wiki_qa | layer 176 | q
# [371/3640] t5-base | standard | wiki_qa | layer 177 | k
# [372/3640] t5-base | standard | wiki_qa | layer 178 | v
# [373/3640] t5-base | standard | wiki_qa | layer 179 | o
# [374/3640] t5-base | standard | wiki_qa | layer 180 | wi
# [375/3640] t5-base | standard | wiki_qa | layer 181 | wo
# [376/3640] t5-base | standard | wiki_qa | layer 182 | q
# [377/3640] t5-base | standard | wiki_qa | layer 183 | k
# [378/3640] t5-base | standard | wiki_qa | layer 184 | v
# [379/3640] t5-base | standard | wiki_qa | layer 185 | o
# [380/3640] t5-base | standard | wiki_qa | layer 186 | q
# [381/3640] t5-base | standard | wiki_qa | layer 187 | k
# [382/3640] t5-base | standard | wiki_qa | layer 188 | v
# [383/3640] t5-base | standard | wiki_qa | layer 189 | o
# [384/3640] t5-base | standard | wiki_qa | layer 190 | wi
# [385/3640] t5-base | standard | wiki_qa | layer 191 | wo
# [386/3640] t5-base | standard | wiki_qa | layer 192 | lm_head
# [387/3640] t5-base | standard | quartz | layer 0 | q
# [388/3640] t5-base | standard | quartz | layer 1 | k
# [389/3640] t5-base | standard | quartz | layer 2 | v
# [390/3640] t5-base | standard | quartz | layer 3 | o
# [391/3640] t5-base | standard | quartz | layer 4 | wi
# [392/3640] t5-base | standard | quartz | layer 5 | wo
# [393/3640] t5-base | standard | quartz | layer 6 | q
# [394/3640] t5-base | standard | quartz | layer 7 | k
# [395/3640] t5-base | standard | quartz | layer 8 | v
# [396/3640] t5-base | standard | quartz | layer 9 | o
# [397/3640] t5-base | standard | quartz | layer 10 | wi
# [398/3640] t5-base | standard | quartz | layer 11 | wo
# [399/3640] t5-base | standard | quartz | layer 12 | q
# [400/3640] t5-base | standard | quartz | layer 13 | k
# [401/3640] t5-base | standard | quartz | layer 14 | v
# [402/3640] t5-base | standard | quartz | layer 15 | o
# [403/3640] t5-base | standard | quartz | layer 16 | wi
# [404/3640] t5-base | standard | quartz | layer 17 | wo
# [405/3640] t5-base | standard | quartz | layer 18 | q
# [406/3640] t5-base | standard | quartz | layer 19 | k
# [407/3640] t5-base | standard | quartz | layer 20 | v
# [408/3640] t5-base | standard | quartz | layer 21 | o
# [409/3640] t5-base | standard | quartz | layer 22 | wi
# [410/3640] t5-base | standard | quartz | layer 23 | wo
# [411/3640] t5-base | standard | quartz | layer 24 | q
# [412/3640] t5-base | standard | quartz | layer 25 | k
# [413/3640] t5-base | standard | quartz | layer 26 | v
# [414/3640] t5-base | standard | quartz | layer 27 | o
# [415/3640] t5-base | standard | quartz | layer 28 | wi
# [416/3640] t5-base | standard | quartz | layer 29 | wo
# [417/3640] t5-base | standard | quartz | layer 30 | q
# [418/3640] t5-base | standard | quartz | layer 31 | k
# [419/3640] t5-base | standard | quartz | layer 32 | v
# [420/3640] t5-base | standard | quartz | layer 33 | o
# [421/3640] t5-base | standard | quartz | layer 34 | wi
# [422/3640] t5-base | standard | quartz | layer 35 | wo
# [423/3640] t5-base | standard | quartz | layer 36 | q
# [424/3640] t5-base | standard | quartz | layer 37 | k
# [425/3640] t5-base | standard | quartz | layer 38 | v
# [426/3640] t5-base | standard | quartz | layer 39 | o
# [427/3640] t5-base | standard | quartz | layer 40 | wi
# [428/3640] t5-base | standard | quartz | layer 41 | wo
# [429/3640] t5-base | standard | quartz | layer 42 | q
# [430/3640] t5-base | standard | quartz | layer 43 | k
# [431/3640] t5-base | standard | quartz | layer 44 | v
# [432/3640] t5-base | standard | quartz | layer 45 | o
# [433/3640] t5-base | standard | quartz | layer 46 | wi
# [434/3640] t5-base | standard | quartz | layer 47 | wo
# [435/3640] t5-base | standard | quartz | layer 48 | q
# [436/3640] t5-base | standard | quartz | layer 49 | k
# [437/3640] t5-base | standard | quartz | layer 50 | v
# [438/3640] t5-base | standard | quartz | layer 51 | o
# [439/3640] t5-base | standard | quartz | layer 52 | wi
# [440/3640] t5-base | standard | quartz | layer 53 | wo
# [441/3640] t5-base | standard | quartz | layer 54 | q
# [442/3640] t5-base | standard | quartz | layer 55 | k
# [443/3640] t5-base | standard | quartz | layer 56 | v
# [444/3640] t5-base | standard | quartz | layer 57 | o
# [445/3640] t5-base | standard | quartz | layer 58 | wi
# [446/3640] t5-base | standard | quartz | layer 59 | wo
# [447/3640] t5-base | standard | quartz | layer 60 | q
# [448/3640] t5-base | standard | quartz | layer 61 | k
# [449/3640] t5-base | standard | quartz | layer 62 | v
# [450/3640] t5-base | standard | quartz | layer 63 | o
# [451/3640] t5-base | standard | quartz | layer 64 | wi
# [452/3640] t5-base | standard | quartz | layer 65 | wo
# [453/3640] t5-base | standard | quartz | layer 66 | q
# [454/3640] t5-base | standard | quartz | layer 67 | k
# [455/3640] t5-base | standard | quartz | layer 68 | v
# [456/3640] t5-base | standard | quartz | layer 69 | o
# [457/3640] t5-base | standard | quartz | layer 70 | wi
# [458/3640] t5-base | standard | quartz | layer 71 | wo
# [459/3640] t5-base | standard | quartz | layer 72 | q
# [460/3640] t5-base | standard | quartz | layer 73 | k
# [461/3640] t5-base | standard | quartz | layer 74 | v
# [462/3640] t5-base | standard | quartz | layer 75 | o
# [463/3640] t5-base | standard | quartz | layer 76 | q
# [464/3640] t5-base | standard | quartz | layer 77 | k
# [465/3640] t5-base | standard | quartz | layer 78 | v
# [466/3640] t5-base | standard | quartz | layer 79 | o
# [467/3640] t5-base | standard | quartz | layer 80 | wi
# [468/3640] t5-base | standard | quartz | layer 81 | wo
# [469/3640] t5-base | standard | quartz | layer 82 | q
# [470/3640] t5-base | standard | quartz | layer 83 | k
# [471/3640] t5-base | standard | quartz | layer 84 | v
# [472/3640] t5-base | standard | quartz | layer 85 | o
# [473/3640] t5-base | standard | quartz | layer 86 | q
# [474/3640] t5-base | standard | quartz | layer 87 | k
# [475/3640] t5-base | standard | quartz | layer 88 | v
# [476/3640] t5-base | standard | quartz | layer 89 | o
# [477/3640] t5-base | standard | quartz | layer 90 | wi
# [478/3640] t5-base | standard | quartz | layer 91 | wo
# [479/3640] t5-base | standard | quartz | layer 92 | q
# [480/3640] t5-base | standard | quartz | layer 93 | k
# [481/3640] t5-base | standard | quartz | layer 94 | v
# [482/3640] t5-base | standard | quartz | layer 95 | o
# [483/3640] t5-base | standard | quartz | layer 96 | q
# [484/3640] t5-base | standard | quartz | layer 97 | k
# [485/3640] t5-base | standard | quartz | layer 98 | v
# [486/3640] t5-base | standard | quartz | layer 99 | o
# [487/3640] t5-base | standard | quartz | layer 100 | wi
# [488/3640] t5-base | standard | quartz | layer 101 | wo
# [489/3640] t5-base | standard | quartz | layer 102 | q
# [490/3640] t5-base | standard | quartz | layer 103 | k
# [491/3640] t5-base | standard | quartz | layer 104 | v
# [492/3640] t5-base | standard | quartz | layer 105 | o
# [493/3640] t5-base | standard | quartz | layer 106 | q
# [494/3640] t5-base | standard | quartz | layer 107 | k
# [495/3640] t5-base | standard | quartz | layer 108 | v
# [496/3640] t5-base | standard | quartz | layer 109 | o
# [497/3640] t5-base | standard | quartz | layer 110 | wi
# [498/3640] t5-base | standard | quartz | layer 111 | wo
# [499/3640] t5-base | standard | quartz | layer 112 | q
# [500/3640] t5-base | standard | quartz | layer 113 | k
# [501/3640] t5-base | standard | quartz | layer 114 | v
# [502/3640] t5-base | standard | quartz | layer 115 | o
# [503/3640] t5-base | standard | quartz | layer 116 | q
# [504/3640] t5-base | standard | quartz | layer 117 | k
# [505/3640] t5-base | standard | quartz | layer 118 | v
# [506/3640] t5-base | standard | quartz | layer 119 | o
# [507/3640] t5-base | standard | quartz | layer 120 | wi
# [508/3640] t5-base | standard | quartz | layer 121 | wo
# [509/3640] t5-base | standard | quartz | layer 122 | q
# [510/3640] t5-base | standard | quartz | layer 123 | k
# [511/3640] t5-base | standard | quartz | layer 124 | v
# [512/3640] t5-base | standard | quartz | layer 125 | o
# [513/3640] t5-base | standard | quartz | layer 126 | q
# [514/3640] t5-base | standard | quartz | layer 127 | k
# [515/3640] t5-base | standard | quartz | layer 128 | v
# [516/3640] t5-base | standard | quartz | layer 129 | o
# [517/3640] t5-base | standard | quartz | layer 130 | wi
# [518/3640] t5-base | standard | quartz | layer 131 | wo
# [519/3640] t5-base | standard | quartz | layer 132 | q
# [520/3640] t5-base | standard | quartz | layer 133 | k
# [521/3640] t5-base | standard | quartz | layer 134 | v
# [522/3640] t5-base | standard | quartz | layer 135 | o
# [523/3640] t5-base | standard | quartz | layer 136 | q
# [524/3640] t5-base | standard | quartz | layer 137 | k
# [525/3640] t5-base | standard | quartz | layer 138 | v
# [526/3640] t5-base | standard | quartz | layer 139 | o
# [527/3640] t5-base | standard | quartz | layer 140 | wi
# [528/3640] t5-base | standard | quartz | layer 141 | wo
# [529/3640] t5-base | standard | quartz | layer 142 | q
# [530/3640] t5-base | standard | quartz | layer 143 | k
# [531/3640] t5-base | standard | quartz | layer 144 | v
# [532/3640] t5-base | standard | quartz | layer 145 | o
# [533/3640] t5-base | standard | quartz | layer 146 | q
# [534/3640] t5-base | standard | quartz | layer 147 | k
# [535/3640] t5-base | standard | quartz | layer 148 | v
# [536/3640] t5-base | standard | quartz | layer 149 | o
# [537/3640] t5-base | standard | quartz | layer 150 | wi
# [538/3640] t5-base | standard | quartz | layer 151 | wo
# [539/3640] t5-base | standard | quartz | layer 152 | q
# [540/3640] t5-base | standard | quartz | layer 153 | k
# [541/3640] t5-base | standard | quartz | layer 154 | v
# [542/3640] t5-base | standard | quartz | layer 155 | o
# [543/3640] t5-base | standard | quartz | layer 156 | q
# [544/3640] t5-base | standard | quartz | layer 157 | k
# [545/3640] t5-base | standard | quartz | layer 158 | v
# [546/3640] t5-base | standard | quartz | layer 159 | o
# [547/3640] t5-base | standard | quartz | layer 160 | wi
# [548/3640] t5-base | standard | quartz | layer 161 | wo
# [549/3640] t5-base | standard | quartz | layer 162 | q
# [550/3640] t5-base | standard | quartz | layer 163 | k
# [551/3640] t5-base | standard | quartz | layer 164 | v
# [552/3640] t5-base | standard | quartz | layer 165 | o
# [553/3640] t5-base | standard | quartz | layer 166 | q
# [554/3640] t5-base | standard | quartz | layer 167 | k
# [555/3640] t5-base | standard | quartz | layer 168 | v
# [556/3640] t5-base | standard | quartz | layer 169 | o
# [557/3640] t5-base | standard | quartz | layer 170 | wi
# [558/3640] t5-base | standard | quartz | layer 171 | wo
# [559/3640] t5-base | standard | quartz | layer 172 | q
# [560/3640] t5-base | standard | quartz | layer 173 | k
# [561/3640] t5-base | standard | quartz | layer 174 | v
# [562/3640] t5-base | standard | quartz | layer 175 | o
# [563/3640] t5-base | standard | quartz | layer 176 | q
# [564/3640] t5-base | standard | quartz | layer 177 | k
# [565/3640] t5-base | standard | quartz | layer 178 | v
# [566/3640] t5-base | standard | quartz | layer 179 | o
# [567/3640] t5-base | standard | quartz | layer 180 | wi
# [568/3640] t5-base | standard | quartz | layer 181 | wo
# [569/3640] t5-base | standard | quartz | layer 182 | q
# [570/3640] t5-base | standard | quartz | layer 183 | k
# [571/3640] t5-base | standard | quartz | layer 184 | v
# [572/3640] t5-base | standard | quartz | layer 185 | o
# [573/3640] t5-base | standard | quartz | layer 186 | q
# [574/3640] t5-base | standard | quartz | layer 187 | k
# [575/3640] t5-base | standard | quartz | layer 188 | v
# [576/3640] t5-base | standard | quartz | layer 189 | o
# [577/3640] t5-base | standard | quartz | layer 190 | wi
# [578/3640] t5-base | standard | quartz | layer 191 | wo
# [579/3640] t5-base | standard | quartz | layer 192 | lm_head
# [580/3640] t5-base | standard | paws | layer 0 | q
# [581/3640] t5-base | standard | paws | layer 1 | k
# [582/3640] t5-base | standard | paws | layer 2 | v
# [583/3640] t5-base | standard | paws | layer 3 | o
# [584/3640] t5-base | standard | paws | layer 4 | wi
# [585/3640] t5-base | standard | paws | layer 5 | wo
# [586/3640] t5-base | standard | paws | layer 6 | q
# [587/3640] t5-base | standard | paws | layer 7 | k
# [588/3640] t5-base | standard | paws | layer 8 | v
# [589/3640] t5-base | standard | paws | layer 9 | o
# [590/3640] t5-base | standard | paws | layer 10 | wi
# [591/3640] t5-base | standard | paws | layer 11 | wo
# [592/3640] t5-base | standard | paws | layer 12 | q
# [593/3640] t5-base | standard | paws | layer 13 | k
# [594/3640] t5-base | standard | paws | layer 14 | v
# [595/3640] t5-base | standard | paws | layer 15 | o
# [596/3640] t5-base | standard | paws | layer 16 | wi
# [597/3640] t5-base | standard | paws | layer 17 | wo
# [598/3640] t5-base | standard | paws | layer 18 | q
# [599/3640] t5-base | standard | paws | layer 19 | k
# [600/3640] t5-base | standard | paws | layer 20 | v
# [601/3640] t5-base | standard | paws | layer 21 | o
# [602/3640] t5-base | standard | paws | layer 22 | wi
# [603/3640] t5-base | standard | paws | layer 23 | wo
# [604/3640] t5-base | standard | paws | layer 24 | q
# [605/3640] t5-base | standard | paws | layer 25 | k
# [606/3640] t5-base | standard | paws | layer 26 | v
# [607/3640] t5-base | standard | paws | layer 27 | o
# [608/3640] t5-base | standard | paws | layer 28 | wi
# [609/3640] t5-base | standard | paws | layer 29 | wo
# [610/3640] t5-base | standard | paws | layer 30 | q
# [611/3640] t5-base | standard | paws | layer 31 | k
# [612/3640] t5-base | standard | paws | layer 32 | v
# [613/3640] t5-base | standard | paws | layer 33 | o
# [614/3640] t5-base | standard | paws | layer 34 | wi
# [615/3640] t5-base | standard | paws | layer 35 | wo
# [616/3640] t5-base | standard | paws | layer 36 | q
# [617/3640] t5-base | standard | paws | layer 37 | k
# [618/3640] t5-base | standard | paws | layer 38 | v
# [619/3640] t5-base | standard | paws | layer 39 | o
# [620/3640] t5-base | standard | paws | layer 40 | wi
# [621/3640] t5-base | standard | paws | layer 41 | wo
# [622/3640] t5-base | standard | paws | layer 42 | q
# [623/3640] t5-base | standard | paws | layer 43 | k
# [624/3640] t5-base | standard | paws | layer 44 | v
# [625/3640] t5-base | standard | paws | layer 45 | o
# [626/3640] t5-base | standard | paws | layer 46 | wi
# [627/3640] t5-base | standard | paws | layer 47 | wo
# [628/3640] t5-base | standard | paws | layer 48 | q
# [629/3640] t5-base | standard | paws | layer 49 | k
# [630/3640] t5-base | standard | paws | layer 50 | v
# [631/3640] t5-base | standard | paws | layer 51 | o
# [632/3640] t5-base | standard | paws | layer 52 | wi
# [633/3640] t5-base | standard | paws | layer 53 | wo
# [634/3640] t5-base | standard | paws | layer 54 | q
# [635/3640] t5-base | standard | paws | layer 55 | k
# [636/3640] t5-base | standard | paws | layer 56 | v
# [637/3640] t5-base | standard | paws | layer 57 | o
# [638/3640] t5-base | standard | paws | layer 58 | wi
# [639/3640] t5-base | standard | paws | layer 59 | wo
# [640/3640] t5-base | standard | paws | layer 60 | q
# [641/3640] t5-base | standard | paws | layer 61 | k
# [642/3640] t5-base | standard | paws | layer 62 | v
# [643/3640] t5-base | standard | paws | layer 63 | o
# [644/3640] t5-base | standard | paws | layer 64 | wi
# [645/3640] t5-base | standard | paws | layer 65 | wo
# [646/3640] t5-base | standard | paws | layer 66 | q
# [647/3640] t5-base | standard | paws | layer 67 | k
# [648/3640] t5-base | standard | paws | layer 68 | v
# [649/3640] t5-base | standard | paws | layer 69 | o
# [650/3640] t5-base | standard | paws | layer 70 | wi
# [651/3640] t5-base | standard | paws | layer 71 | wo
# [652/3640] t5-base | standard | paws | layer 72 | q
# [653/3640] t5-base | standard | paws | layer 73 | k
# [654/3640] t5-base | standard | paws | layer 74 | v
# [655/3640] t5-base | standard | paws | layer 75 | o
# [656/3640] t5-base | standard | paws | layer 76 | q
# [657/3640] t5-base | standard | paws | layer 77 | k
# [658/3640] t5-base | standard | paws | layer 78 | v
# [659/3640] t5-base | standard | paws | layer 79 | o
# [660/3640] t5-base | standard | paws | layer 80 | wi
# [661/3640] t5-base | standard | paws | layer 81 | wo
# [662/3640] t5-base | standard | paws | layer 82 | q
# [663/3640] t5-base | standard | paws | layer 83 | k
# [664/3640] t5-base | standard | paws | layer 84 | v
# [665/3640] t5-base | standard | paws | layer 85 | o
# [666/3640] t5-base | standard | paws | layer 86 | q
# [667/3640] t5-base | standard | paws | layer 87 | k
# [668/3640] t5-base | standard | paws | layer 88 | v
# [669/3640] t5-base | standard | paws | layer 89 | o
# [670/3640] t5-base | standard | paws | layer 90 | wi
# [671/3640] t5-base | standard | paws | layer 91 | wo
# [672/3640] t5-base | standard | paws | layer 92 | q
# [673/3640] t5-base | standard | paws | layer 93 | k
# [674/3640] t5-base | standard | paws | layer 94 | v
# [675/3640] t5-base | standard | paws | layer 95 | o
# [676/3640] t5-base | standard | paws | layer 96 | q
# [677/3640] t5-base | standard | paws | layer 97 | k
# [678/3640] t5-base | standard | paws | layer 98 | v
# [679/3640] t5-base | standard | paws | layer 99 | o
# [680/3640] t5-base | standard | paws | layer 100 | wi
# [681/3640] t5-base | standard | paws | layer 101 | wo
# [682/3640] t5-base | standard | paws | layer 102 | q
# [683/3640] t5-base | standard | paws | layer 103 | k
# [684/3640] t5-base | standard | paws | layer 104 | v
# [685/3640] t5-base | standard | paws | layer 105 | o
# [686/3640] t5-base | standard | paws | layer 106 | q
# [687/3640] t5-base | standard | paws | layer 107 | k
# [688/3640] t5-base | standard | paws | layer 108 | v
# [689/3640] t5-base | standard | paws | layer 109 | o
# [690/3640] t5-base | standard | paws | layer 110 | wi
# [691/3640] t5-base | standard | paws | layer 111 | wo
# [692/3640] t5-base | standard | paws | layer 112 | q
# [693/3640] t5-base | standard | paws | layer 113 | k
# [694/3640] t5-base | standard | paws | layer 114 | v
# [695/3640] t5-base | standard | paws | layer 115 | o
# [696/3640] t5-base | standard | paws | layer 116 | q
# [697/3640] t5-base | standard | paws | layer 117 | k
# [698/3640] t5-base | standard | paws | layer 118 | v
# [699/3640] t5-base | standard | paws | layer 119 | o
# [700/3640] t5-base | standard | paws | layer 120 | wi
# [701/3640] t5-base | standard | paws | layer 121 | wo
# [702/3640] t5-base | standard | paws | layer 122 | q
# [703/3640] t5-base | standard | paws | layer 123 | k
# [704/3640] t5-base | standard | paws | layer 124 | v
# [705/3640] t5-base | standard | paws | layer 125 | o
# [706/3640] t5-base | standard | paws | layer 126 | q
# [707/3640] t5-base | standard | paws | layer 127 | k
# [708/3640] t5-base | standard | paws | layer 128 | v
# [709/3640] t5-base | standard | paws | layer 129 | o
# [710/3640] t5-base | standard | paws | layer 130 | wi
# [711/3640] t5-base | standard | paws | layer 131 | wo
# [712/3640] t5-base | standard | paws | layer 132 | q
# [713/3640] t5-base | standard | paws | layer 133 | k
# [714/3640] t5-base | standard | paws | layer 134 | v
# [715/3640] t5-base | standard | paws | layer 135 | o
# [716/3640] t5-base | standard | paws | layer 136 | q
# [717/3640] t5-base | standard | paws | layer 137 | k
# [718/3640] t5-base | standard | paws | layer 138 | v
# [719/3640] t5-base | standard | paws | layer 139 | o
# [720/3640] t5-base | standard | paws | layer 140 | wi
# [721/3640] t5-base | standard | paws | layer 141 | wo
# [722/3640] t5-base | standard | paws | layer 142 | q
# [723/3640] t5-base | standard | paws | layer 143 | k
# [724/3640] t5-base | standard | paws | layer 144 | v
# [725/3640] t5-base | standard | paws | layer 145 | o
# [726/3640] t5-base | standard | paws | layer 146 | q
# [727/3640] t5-base | standard | paws | layer 147 | k
# [728/3640] t5-base | standard | paws | layer 148 | v
# [729/3640] t5-base | standard | paws | layer 149 | o
# [730/3640] t5-base | standard | paws | layer 150 | wi
# [731/3640] t5-base | standard | paws | layer 151 | wo
# [732/3640] t5-base | standard | paws | layer 152 | q
# [733/3640] t5-base | standard | paws | layer 153 | k
# [734/3640] t5-base | standard | paws | layer 154 | v
# [735/3640] t5-base | standard | paws | layer 155 | o
# [736/3640] t5-base | standard | paws | layer 156 | q
# [737/3640] t5-base | standard | paws | layer 157 | k
# [738/3640] t5-base | standard | paws | layer 158 | v
# [739/3640] t5-base | standard | paws | layer 159 | o
# [740/3640] t5-base | standard | paws | layer 160 | wi
# [741/3640] t5-base | standard | paws | layer 161 | wo
# [742/3640] t5-base | standard | paws | layer 162 | q
# [743/3640] t5-base | standard | paws | layer 163 | k
# [744/3640] t5-base | standard | paws | layer 164 | v
# [745/3640] t5-base | standard | paws | layer 165 | o
# [746/3640] t5-base | standard | paws | layer 166 | q
# [747/3640] t5-base | standard | paws | layer 167 | k
# [748/3640] t5-base | standard | paws | layer 168 | v
# [749/3640] t5-base | standard | paws | layer 169 | o
# [750/3640] t5-base | standard | paws | layer 170 | wi
# [751/3640] t5-base | standard | paws | layer 171 | wo
# [752/3640] t5-base | standard | paws | layer 172 | q
# [753/3640] t5-base | standard | paws | layer 173 | k
# [754/3640] t5-base | standard | paws | layer 174 | v
# [755/3640] t5-base | standard | paws | layer 175 | o
# [756/3640] t5-base | standard | paws | layer 176 | q
# [757/3640] t5-base | standard | paws | layer 177 | k
# [758/3640] t5-base | standard | paws | layer 178 | v
# [759/3640] t5-base | standard | paws | layer 179 | o
# [760/3640] t5-base | standard | paws | layer 180 | wi
# [761/3640] t5-base | standard | paws | layer 181 | wo
# [762/3640] t5-base | standard | paws | layer 182 | q
# [763/3640] t5-base | standard | paws | layer 183 | k
# [764/3640] t5-base | standard | paws | layer 184 | v
# [765/3640] t5-base | standard | paws | layer 185 | o
# [766/3640] t5-base | standard | paws | layer 186 | q
# [767/3640] t5-base | standard | paws | layer 187 | k
# [768/3640] t5-base | standard | paws | layer 188 | v
# [769/3640] t5-base | standard | paws | layer 189 | o
# [770/3640] t5-base | standard | paws | layer 190 | wi
# [771/3640] t5-base | standard | paws | layer 191 | wo
# [772/3640] t5-base | standard | paws | layer 192 | lm_head
# [773/3640] t5-base | standard | story_cloze | layer 0 | q
# [774/3640] t5-base | standard | story_cloze | layer 1 | k
# [775/3640] t5-base | standard | story_cloze | layer 2 | v
# [776/3640] t5-base | standard | story_cloze | layer 3 | o
# [777/3640] t5-base | standard | story_cloze | layer 4 | wi
# [778/3640] t5-base | standard | story_cloze | layer 5 | wo
# [779/3640] t5-base | standard | story_cloze | layer 6 | q
# [780/3640] t5-base | standard | story_cloze | layer 7 | k
# [781/3640] t5-base | standard | story_cloze | layer 8 | v
# [782/3640] t5-base | standard | story_cloze | layer 9 | o
# [783/3640] t5-base | standard | story_cloze | layer 10 | wi
# [784/3640] t5-base | standard | story_cloze | layer 11 | wo
# [785/3640] t5-base | standard | story_cloze | layer 12 | q
# [786/3640] t5-base | standard | story_cloze | layer 13 | k
# [787/3640] t5-base | standard | story_cloze | layer 14 | v
# [788/3640] t5-base | standard | story_cloze | layer 15 | o
# [789/3640] t5-base | standard | story_cloze | layer 16 | wi
# [790/3640] t5-base | standard | story_cloze | layer 17 | wo
# [791/3640] t5-base | standard | story_cloze | layer 18 | q
# [792/3640] t5-base | standard | story_cloze | layer 19 | k
# [793/3640] t5-base | standard | story_cloze | layer 20 | v
# [794/3640] t5-base | standard | story_cloze | layer 21 | o
# [795/3640] t5-base | standard | story_cloze | layer 22 | wi
# [796/3640] t5-base | standard | story_cloze | layer 23 | wo
# [797/3640] t5-base | standard | story_cloze | layer 24 | q
# [798/3640] t5-base | standard | story_cloze | layer 25 | k
# [799/3640] t5-base | standard | story_cloze | layer 26 | v
# [800/3640] t5-base | standard | story_cloze | layer 27 | o
# [801/3640] t5-base | standard | story_cloze | layer 28 | wi
# [802/3640] t5-base | standard | story_cloze | layer 29 | wo
# [803/3640] t5-base | standard | story_cloze | layer 30 | q
# [804/3640] t5-base | standard | story_cloze | layer 31 | k
# [805/3640] t5-base | standard | story_cloze | layer 32 | v
# [806/3640] t5-base | standard | story_cloze | layer 33 | o
# [807/3640] t5-base | standard | story_cloze | layer 34 | wi
# [808/3640] t5-base | standard | story_cloze | layer 35 | wo
# [809/3640] t5-base | standard | story_cloze | layer 36 | q
# [810/3640] t5-base | standard | story_cloze | layer 37 | k
# [811/3640] t5-base | standard | story_cloze | layer 38 | v
# [812/3640] t5-base | standard | story_cloze | layer 39 | o
# [813/3640] t5-base | standard | story_cloze | layer 40 | wi
# [814/3640] t5-base | standard | story_cloze | layer 41 | wo
# [815/3640] t5-base | standard | story_cloze | layer 42 | q
# [816/3640] t5-base | standard | story_cloze | layer 43 | k
# [817/3640] t5-base | standard | story_cloze | layer 44 | v
# [818/3640] t5-base | standard | story_cloze | layer 45 | o
# [819/3640] t5-base | standard | story_cloze | layer 46 | wi
# [820/3640] t5-base | standard | story_cloze | layer 47 | wo
# [821/3640] t5-base | standard | story_cloze | layer 48 | q
# [822/3640] t5-base | standard | story_cloze | layer 49 | k
# [823/3640] t5-base | standard | story_cloze | layer 50 | v
# [824/3640] t5-base | standard | story_cloze | layer 51 | o
# [825/3640] t5-base | standard | story_cloze | layer 52 | wi
# [826/3640] t5-base | standard | story_cloze | layer 53 | wo
# [827/3640] t5-base | standard | story_cloze | layer 54 | q
# [828/3640] t5-base | standard | story_cloze | layer 55 | k
# [829/3640] t5-base | standard | story_cloze | layer 56 | v
# [830/3640] t5-base | standard | story_cloze | layer 57 | o
# [831/3640] t5-base | standard | story_cloze | layer 58 | wi
# [832/3640] t5-base | standard | story_cloze | layer 59 | wo
# [833/3640] t5-base | standard | story_cloze | layer 60 | q
# [834/3640] t5-base | standard | story_cloze | layer 61 | k
# [835/3640] t5-base | standard | story_cloze | layer 62 | v
# [836/3640] t5-base | standard | story_cloze | layer 63 | o
# [837/3640] t5-base | standard | story_cloze | layer 64 | wi
# [838/3640] t5-base | standard | story_cloze | layer 65 | wo
# [839/3640] t5-base | standard | story_cloze | layer 66 | q
# [840/3640] t5-base | standard | story_cloze | layer 67 | k
# [841/3640] t5-base | standard | story_cloze | layer 68 | v
# [842/3640] t5-base | standard | story_cloze | layer 69 | o
# [843/3640] t5-base | standard | story_cloze | layer 70 | wi
# [844/3640] t5-base | standard | story_cloze | layer 71 | wo
# [845/3640] t5-base | standard | story_cloze | layer 72 | q
# [846/3640] t5-base | standard | story_cloze | layer 73 | k
# [847/3640] t5-base | standard | story_cloze | layer 74 | v
# [848/3640] t5-base | standard | story_cloze | layer 75 | o
# [849/3640] t5-base | standard | story_cloze | layer 76 | q
# [850/3640] t5-base | standard | story_cloze | layer 77 | k
# [851/3640] t5-base | standard | story_cloze | layer 78 | v
# [852/3640] t5-base | standard | story_cloze | layer 79 | o
# [853/3640] t5-base | standard | story_cloze | layer 80 | wi
# [854/3640] t5-base | standard | story_cloze | layer 81 | wo
# [855/3640] t5-base | standard | story_cloze | layer 82 | q
# [856/3640] t5-base | standard | story_cloze | layer 83 | k
# [857/3640] t5-base | standard | story_cloze | layer 84 | v
# [858/3640] t5-base | standard | story_cloze | layer 85 | o
# [859/3640] t5-base | standard | story_cloze | layer 86 | q
# [860/3640] t5-base | standard | story_cloze | layer 87 | k
# [861/3640] t5-base | standard | story_cloze | layer 88 | v
# [862/3640] t5-base | standard | story_cloze | layer 89 | o
# [863/3640] t5-base | standard | story_cloze | layer 90 | wi
# [864/3640] t5-base | standard | story_cloze | layer 91 | wo
# [865/3640] t5-base | standard | story_cloze | layer 92 | q
# [866/3640] t5-base | standard | story_cloze | layer 93 | k
# [867/3640] t5-base | standard | story_cloze | layer 94 | v
# [868/3640] t5-base | standard | story_cloze | layer 95 | o
# [869/3640] t5-base | standard | story_cloze | layer 96 | q
# [870/3640] t5-base | standard | story_cloze | layer 97 | k
# [871/3640] t5-base | standard | story_cloze | layer 98 | v
# [872/3640] t5-base | standard | story_cloze | layer 99 | o
# [873/3640] t5-base | standard | story_cloze | layer 100 | wi
# [874/3640] t5-base | standard | story_cloze | layer 101 | wo
# [875/3640] t5-base | standard | story_cloze | layer 102 | q
# [876/3640] t5-base | standard | story_cloze | layer 103 | k
# [877/3640] t5-base | standard | story_cloze | layer 104 | v
# [878/3640] t5-base | standard | story_cloze | layer 105 | o
# [879/3640] t5-base | standard | story_cloze | layer 106 | q
# [880/3640] t5-base | standard | story_cloze | layer 107 | k
# ...
# [3752/3640] t5-large | standard | wsc | layer 90 | q
# [3753/3640] t5-large | standard | wsc | layer 91 | k
# [3754/3640] t5-large | standard | wsc | layer 92 | v
# [3755/3640] t5-large | standard | wsc | layer 93 | o
# [3756/3640] t5-large | standard | wsc | layer 94 | wi
# [3757/3640] t5-large | standard | wsc | layer 95 | wo
# [3758/3640] t5-large | standard | wsc | layer 96 | q
# [3759/3640] t5-large | standard | wsc | layer 97 | k
# [3760/3640] t5-large | standard | wsc | layer 98 | v
# [3761/3640] t5-large | standard | wsc | layer 99 | o
# [3762/3640] t5-large | standard | wsc | layer 100 | wi
# [3763/3640] t5-large | standard | wsc | layer 101 | wo
# [3764/3640] t5-large | standard | wsc | layer 102 | q
# [3765/3640] t5-large | standard | wsc | layer 103 | k
# [3766/3640] t5-large | standard | wsc | layer 104 | v
# [3767/3640] t5-large | standard | wsc | layer 105 | o
# [3768/3640] t5-large | standard | wsc | layer 106 | wi
# [3769/3640] t5-large | standard | wsc | layer 107 | wo
# [3770/3640] t5-large | standard | wsc | layer 108 | q
# [3771/3640] t5-large | standard | wsc | layer 109 | k
# [3772/3640] t5-large | standard | wsc | layer 110 | v
# [3773/3640] t5-large | standard | wsc | layer 111 | o
# [3774/3640] t5-large | standard | wsc | layer 112 | wi
# [3775/3640] t5-large | standard | wsc | layer 113 | wo
# [3776/3640] t5-large | standard | wsc | layer 114 | q
# [3777/3640] t5-large | standard | wsc | layer 115 | k
# [3778/3640] t5-large | standard | wsc | layer 116 | v
# [3779/3640] t5-large | standard | wsc | layer 117 | o
# [3780/3640] t5-large | standard | wsc | layer 118 | wi
# [3781/3640] t5-large | standard | wsc | layer 119 | wo
# [3782/3640] t5-large | standard | wsc | layer 120 | q
# [3783/3640] t5-large | standard | wsc | layer 121 | k
# [3784/3640] t5-large | standard | wsc | layer 122 | v
# [3785/3640] t5-large | standard | wsc | layer 123 | o
# [3786/3640] t5-large | standard | wsc | layer 124 | wi
# [3787/3640] t5-large | standard | wsc | layer 125 | wo
# [3788/3640] t5-large | standard | wsc | layer 126 | q
# [3789/3640] t5-large | standard | wsc | layer 127 | k
# [3790/3640] t5-large | standard | wsc | layer 128 | v
# [3791/3640] t5-large | standard | wsc | layer 129 | o
# [3792/3640] t5-large | standard | wsc | layer 130 | wi
# [3793/3640] t5-large | standard | wsc | layer 131 | wo
# [3794/3640] t5-large | standard | wsc | layer 132 | q
# [3795/3640] t5-large | standard | wsc | layer 133 | k
# [3796/3640] t5-large | standard | wsc | layer 134 | v
# [3797/3640] t5-large | standard | wsc | layer 135 | o
# [3798/3640] t5-large | standard | wsc | layer 136 | wi
# [3799/3640] t5-large | standard | wsc | layer 137 | wo
# [3800/3640] t5-large | standard | wsc | layer 138 | q
# [3801/3640] t5-large | standard | wsc | layer 139 | k
# [3802/3640] t5-large | standard | wsc | layer 140 | v
# [3803/3640] t5-large | standard | wsc | layer 141 | o
# [3804/3640] t5-large | standard | wsc | layer 142 | wi
# [3805/3640] t5-large | standard | wsc | layer 143 | wo
# [3806/3640] t5-large | standard | wsc | layer 144 | q
# [3807/3640] t5-large | standard | wsc | layer 145 | k
# [3808/3640] t5-large | standard | wsc | layer 146 | v
# [3809/3640] t5-large | standard | wsc | layer 147 | o
# [3810/3640] t5-large | standard | wsc | layer 148 | q
# [3811/3640] t5-large | standard | wsc | layer 149 | k
# [3812/3640] t5-large | standard | wsc | layer 150 | v
# [3813/3640] t5-large | standard | wsc | layer 151 | o
# [3814/3640] t5-large | standard | wsc | layer 152 | wi
# [3815/3640] t5-large | standard | wsc | layer 153 | wo
# [3816/3640] t5-large | standard | wsc | layer 154 | q
# [3817/3640] t5-large | standard | wsc | layer 155 | k
# [3818/3640] t5-large | standard | wsc | layer 156 | v
# [3819/3640] t5-large | standard | wsc | layer 157 | o
# [3820/3640] t5-large | standard | wsc | layer 158 | q
# [3821/3640] t5-large | standard | wsc | layer 159 | k
# [3822/3640] t5-large | standard | wsc | layer 160 | v
# [3823/3640] t5-large | standard | wsc | layer 161 | o
# [3824/3640] t5-large | standard | wsc | layer 162 | wi
# [3825/3640] t5-large | standard | wsc | layer 163 | wo
# [3826/3640] t5-large | standard | wsc | layer 164 | q
# [3827/3640] t5-large | standard | wsc | layer 165 | k
# [3828/3640] t5-large | standard | wsc | layer 166 | v
# [3829/3640] t5-large | standard | wsc | layer 167 | o
# [3830/3640] t5-large | standard | wsc | layer 168 | q
# [3831/3640] t5-large | standard | wsc | layer 169 | k
# [3832/3640] t5-large | standard | wsc | layer 170 | v
# [3833/3640] t5-large | standard | wsc | layer 171 | o
# [3834/3640] t5-large | standard | wsc | layer 172 | wi
# [3835/3640] t5-large | standard | wsc | layer 173 | wo
# [3836/3640] t5-large | standard | wsc | layer 174 | q
# [3837/3640] t5-large | standard | wsc | layer 175 | k
# [3838/3640] t5-large | standard | wsc | layer 176 | v
# [3839/3640] t5-large | standard | wsc | layer 177 | o
# [3840/3640] t5-large | standard | wsc | layer 178 | q
# [3841/3640] t5-large | standard | wsc | layer 179 | k
# [3842/3640] t5-large | standard | wsc | layer 180 | v
# [3843/3640] t5-large | standard | wsc | layer 181 | o
# [3844/3640] t5-large | standard | wsc | layer 182 | wi
# [3845/3640] t5-large | standard | wsc | layer 183 | wo
# [3846/3640] t5-large | standard | wsc | layer 184 | q
# [3847/3640] t5-large | standard | wsc | layer 185 | k
# [3848/3640] t5-large | standard | wsc | layer 186 | v
# [3849/3640] t5-large | standard | wsc | layer 187 | o
# [3850/3640] t5-large | standard | wsc | layer 188 | q
# [3851/3640] t5-large | standard | wsc | layer 189 | k
# [3852/3640] t5-large | standard | wsc | layer 190 | v
# [3853/3640] t5-large | standard | wsc | layer 191 | o
# [3854/3640] t5-large | standard | wsc | layer 192 | wi
# [3855/3640] t5-large | standard | wsc | layer 193 | wo
# [3856/3640] t5-large | standard | wsc | layer 194 | q
# [3857/3640] t5-large | standard | wsc | layer 195 | k
# [3858/3640] t5-large | standard | wsc | layer 196 | v
# [3859/3640] t5-large | standard | wsc | layer 197 | o
# [3860/3640] t5-large | standard | wsc | layer 198 | q
# [3861/3640] t5-large | standard | wsc | layer 199 | k
# [3862/3640] t5-large | standard | wsc | layer 200 | v
# [3863/3640] t5-large | standard | wsc | layer 201 | o
# [3864/3640] t5-large | standard | wsc | layer 202 | wi
# [3865/3640] t5-large | standard | wsc | layer 203 | wo
# [3866/3640] t5-large | standard | wsc | layer 204 | q
# [3867/3640] t5-large | standard | wsc | layer 205 | k
# [3868/3640] t5-large | standard | wsc | layer 206 | v
# [3869/3640] t5-large | standard | wsc | layer 207 | o
# [3870/3640] t5-large | standard | wsc | layer 208 | q
# [3871/3640] t5-large | standard | wsc | layer 209 | k
# [3872/3640] t5-large | standard | wsc | layer 210 | v
# [3873/3640] t5-large | standard | wsc | layer 211 | o
# [3874/3640] t5-large | standard | wsc | layer 212 | wi
# [3875/3640] t5-large | standard | wsc | layer 213 | wo
# [3876/3640] t5-large | standard | wsc | layer 214 | q
# [3877/3640] t5-large | standard | wsc | layer 215 | k
# [3878/3640] t5-large | standard | wsc | layer 216 | v
# [3879/3640] t5-large | standard | wsc | layer 217 | o
# [3880/3640] t5-large | standard | wsc | layer 218 | q
# [3881/3640] t5-large | standard | wsc | layer 219 | k
# [3882/3640] t5-large | standard | wsc | layer 220 | v
# [3883/3640] t5-large | standard | wsc | layer 221 | o
# [3884/3640] t5-large | standard | wsc | layer 222 | wi
# [3885/3640] t5-large | standard | wsc | layer 223 | wo
# [3886/3640] t5-large | standard | wsc | layer 224 | q
# [3887/3640] t5-large | standard | wsc | layer 225 | k
# [3888/3640] t5-large | standard | wsc | layer 226 | v
# [3889/3640] t5-large | standard | wsc | layer 227 | o
# [3890/3640] t5-large | standard | wsc | layer 228 | q
# [3891/3640] t5-large | standard | wsc | layer 229 | k
# [3892/3640] t5-large | standard | wsc | layer 230 | v
# [3893/3640] t5-large | standard | wsc | layer 231 | o
# [3894/3640] t5-large | standard | wsc | layer 232 | wi
# [3895/3640] t5-large | standard | wsc | layer 233 | wo
# [3896/3640] t5-large | standard | wsc | layer 234 | q
# [3897/3640] t5-large | standard | wsc | layer 235 | k
# [3898/3640] t5-large | standard | wsc | layer 236 | v
# [3899/3640] t5-large | standard | wsc | layer 237 | o
# [3900/3640] t5-large | standard | wsc | layer 238 | q
# [3901/3640] t5-large | standard | wsc | layer 239 | k
# [3902/3640] t5-large | standard | wsc | layer 240 | v
# [3903/3640] t5-large | standard | wsc | layer 241 | o
# [3904/3640] t5-large | standard | wsc | layer 242 | wi
# [3905/3640] t5-large | standard | wsc | layer 243 | wo
# [3906/3640] t5-large | standard | wsc | layer 244 | q
# [3907/3640] t5-large | standard | wsc | layer 245 | k
# [3908/3640] t5-large | standard | wsc | layer 246 | v
# [3909/3640] t5-large | standard | wsc | layer 247 | o
# [3910/3640] t5-large | standard | wsc | layer 248 | q
# [3911/3640] t5-large | standard | wsc | layer 249 | k
# [3912/3640] t5-large | standard | wsc | layer 250 | v
# [3913/3640] t5-large | standard | wsc | layer 251 | o
# [3914/3640] t5-large | standard | wsc | layer 252 | wi
# [3915/3640] t5-large | standard | wsc | layer 253 | wo
# [3916/3640] t5-large | standard | wsc | layer 254 | q
# [3917/3640] t5-large | standard | wsc | layer 255 | k
# [3918/3640] t5-large | standard | wsc | layer 256 | v
# [3919/3640] t5-large | standard | wsc | layer 257 | o
# [3920/3640] t5-large | standard | wsc | layer 258 | q
# [3921/3640] t5-large | standard | wsc | layer 259 | k
# [3922/3640] t5-large | standard | wsc | layer 260 | v
# [3923/3640] t5-large | standard | wsc | layer 261 | o
# [3924/3640] t5-large | standard | wsc | layer 262 | wi
# [3925/3640] t5-large | standard | wsc | layer 263 | wo
# [3926/3640] t5-large | standard | wsc | layer 264 | q
# [3927/3640] t5-large | standard | wsc | layer 265 | k
# [3928/3640] t5-large | standard | wsc | layer 266 | v
# [3929/3640] t5-large | standard | wsc | layer 267 | o
# [3930/3640] t5-large | standard | wsc | layer 268 | q
# [3931/3640] t5-large | standard | wsc | layer 269 | k
# [3932/3640] t5-large | standard | wsc | layer 270 | v
# [3933/3640] t5-large | standard | wsc | layer 271 | o
# [3934/3640] t5-large | standard | wsc | layer 272 | wi
# [3935/3640] t5-large | standard | wsc | layer 273 | wo
# [3936/3640] t5-large | standard | wsc | layer 274 | q
# [3937/3640] t5-large | standard | wsc | layer 275 | k
# [3938/3640] t5-large | standard | wsc | layer 276 | v
# [3939/3640] t5-large | standard | wsc | layer 277 | o
# [3940/3640] t5-large | standard | wsc | layer 278 | q
# [3941/3640] t5-large | standard | wsc | layer 279 | k
# [3942/3640] t5-large | standard | wsc | layer 280 | v
# [3943/3640] t5-large | standard | wsc | layer 281 | o
# [3944/3640] t5-large | standard | wsc | layer 282 | wi
# [3945/3640] t5-large | standard | wsc | layer 283 | wo
# [3946/3640] t5-large | standard | wsc | layer 284 | q
# [3947/3640] t5-large | standard | wsc | layer 285 | k
# [3948/3640] t5-large | standard | wsc | layer 286 | v
# [3949/3640] t5-large | standard | wsc | layer 287 | o
# [3950/3640] t5-large | standard | wsc | layer 288 | q
# [3951/3640] t5-large | standard | wsc | layer 289 | k
# [3952/3640] t5-large | standard | wsc | layer 290 | v
# [3953/3640] t5-large | standard | wsc | layer 291 | o
# [3954/3640] t5-large | standard | wsc | layer 292 | wi
# [3955/3640] t5-large | standard | wsc | layer 293 | wo
# [3956/3640] t5-large | standard | wsc | layer 294 | q
# [3957/3640] t5-large | standard | wsc | layer 295 | k
# [3958/3640] t5-large | standard | wsc | layer 296 | v
# [3959/3640] t5-large | standard | wsc | layer 297 | o
# [3960/3640] t5-large | standard | wsc | layer 298 | q
# [3961/3640] t5-large | standard | wsc | layer 299 | k
# [3962/3640] t5-large | standard | wsc | layer 300 | v
# [3963/3640] t5-large | standard | wsc | layer 301 | o
# [3964/3640] t5-large | standard | wsc | layer 302 | wi
# [3965/3640] t5-large | standard | wsc | layer 303 | wo
# [3966/3640] t5-large | standard | wsc | layer 304 | q
# [3967/3640] t5-large | standard | wsc | layer 305 | k
# [3968/3640] t5-large | standard | wsc | layer 306 | v
# [3969/3640] t5-large | standard | wsc | layer 307 | o
# [3970/3640] t5-large | standard | wsc | layer 308 | q
# [3971/3640] t5-large | standard | wsc | layer 309 | k
# [3972/3640] t5-large | standard | wsc | layer 310 | v
# [3973/3640] t5-large | standard | wsc | layer 311 | o
# [3974/3640] t5-large | standard | wsc | layer 312 | wi
# [3975/3640] t5-large | standard | wsc | layer 313 | wo
# [3976/3640] t5-large | standard | wsc | layer 314 | q
# [3977/3640] t5-large | standard | wsc | layer 315 | k
# [3978/3640] t5-large | standard | wsc | layer 316 | v
# [3979/3640] t5-large | standard | wsc | layer 317 | o
# [3980/3640] t5-large | standard | wsc | layer 318 | q
# [3981/3640] t5-large | standard | wsc | layer 319 | k
# [3982/3640] t5-large | standard | wsc | layer 320 | v
# [3983/3640] t5-large | standard | wsc | layer 321 | o
# [3984/3640] t5-large | standard | wsc | layer 322 | wi
# [3985/3640] t5-large | standard | wsc | layer 323 | wo
# [3986/3640] t5-large | standard | wsc | layer 324 | q
# [3987/3640] t5-large | standard | wsc | layer 325 | k
# [3988/3640] t5-large | standard | wsc | layer 326 | v
# [3989/3640] t5-large | standard | wsc | layer 327 | o
# [3990/3640] t5-large | standard | wsc | layer 328 | q
# [3991/3640] t5-large | standard | wsc | layer 329 | k
# [3992/3640] t5-large | standard | wsc | layer 330 | v
# [3993/3640] t5-large | standard | wsc | layer 331 | o
# [3994/3640] t5-large | standard | wsc | layer 332 | wi
# [3995/3640] t5-large | standard | wsc | layer 333 | wo
# [3996/3640] t5-large | standard | wsc | layer 334 | q
# [3997/3640] t5-large | standard | wsc | layer 335 | k
# [3998/3640] t5-large | standard | wsc | layer 336 | v
# [3999/3640] t5-large | standard | wsc | layer 337 | o
# [4000/3640] t5-large | standard | wsc | layer 338 | q
# [4001/3640] t5-large | standard | wsc | layer 339 | k
# [4002/3640] t5-large | standard | wsc | layer 340 | v
# [4003/3640] t5-large | standard | wsc | layer 341 | o
# [4004/3640] t5-large | standard | wsc | layer 342 | wi
# [4005/3640] t5-large | standard | wsc | layer 343 | wo
# [4006/3640] t5-large | standard | wsc | layer 344 | q
# [4007/3640] t5-large | standard | wsc | layer 345 | k
# [4008/3640] t5-large | standard | wsc | layer 346 | v
# [4009/3640] t5-large | standard | wsc | layer 347 | o
# [4010/3640] t5-large | standard | wsc | layer 348 | q
# [4011/3640] t5-large | standard | wsc | layer 349 | k
# [4012/3640] t5-large | standard | wsc | layer 350 | v
# [4013/3640] t5-large | standard | wsc | layer 351 | o
# [4014/3640] t5-large | standard | wsc | layer 352 | wi
# [4015/3640] t5-large | standard | wsc | layer 353 | wo
# [4016/3640] t5-large | standard | wsc | layer 354 | q
# [4017/3640] t5-large | standard | wsc | layer 355 | k
# [4018/3640] t5-large | standard | wsc | layer 356 | v
# [4019/3640] t5-large | standard | wsc | layer 357 | o
# [4020/3640] t5-large | standard | wsc | layer 358 | q
# [4021/3640] t5-large | standard | wsc | layer 359 | k
# [4022/3640] t5-large | standard | wsc | layer 360 | v
# [4023/3640] t5-large | standard | wsc | layer 361 | o
# [4024/3640] t5-large | standard | wsc | layer 362 | wi
# [4025/3640] t5-large | standard | wsc | layer 363 | wo
# [4026/3640] t5-large | standard | wsc | layer 364 | q
# [4027/3640] t5-large | standard | wsc | layer 365 | k
# [4028/3640] t5-large | standard | wsc | layer 366 | v
# [4029/3640] t5-large | standard | wsc | layer 367 | o
# [4030/3640] t5-large | standard | wsc | layer 368 | q
# [4031/3640] t5-large | standard | wsc | layer 369 | k
# [4032/3640] t5-large | standard | wsc | layer 370 | v
# [4033/3640] t5-large | standard | wsc | layer 371 | o
# [4034/3640] t5-large | standard | wsc | layer 372 | wi
# [4035/3640] t5-large | standard | wsc | layer 373 | wo
# [4036/3640] t5-large | standard | wsc | layer 374 | q
# [4037/3640] t5-large | standard | wsc | layer 375 | k
# [4038/3640] t5-large | standard | wsc | layer 376 | v
# [4039/3640] t5-large | standard | wsc | layer 377 | o
# [4040/3640] t5-large | standard | wsc | layer 378 | q
# [4041/3640] t5-large | standard | wsc | layer 379 | k
# [4042/3640] t5-large | standard | wsc | layer 380 | v
# [4043/3640] t5-large | standard | wsc | layer 381 | o
# [4044/3640] t5-large | standard | wsc | layer 382 | wi
# [4045/3640] t5-large | standard | wsc | layer 383 | wo
# [4046/3640] t5-large | standard | wsc | layer 384 | lm_head

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

BASE_FONTSIZE = 24
BATCH_SIZE = 32
NUM_SAMPLES = 10

sns.set_theme(rc={
    "font.size": BASE_FONTSIZE,
    "axes.titlesize": BASE_FONTSIZE,
    "axes.labelsize": BASE_FONTSIZE,
    "xtick.labelsize": BASE_FONTSIZE * 0.8,
    "ytick.labelsize": BASE_FONTSIZE * 0.8,
    "legend.fontsize": BASE_FONTSIZE * 0.8,
    "legend.title_fontsize": BASE_FONTSIZE * 0.8,
})

MODEL_MAP = {"t5-base": "T5-Base", "t5-large": "T5-Large"}

df_lang = pd.read_csv(f"../results/eigcov_estimation_error_lang_n{NUM_SAMPLES}_b{BATCH_SIZE}.csv")
df_lang = df_lang[df_lang["ft_method"] == "standard"]
df_lang = df_lang[df_lang["method"] != "Zeros"]
df_lang["model"] = df_lang["model"].map(MODEL_MAP).fillna(df_lang["model"])

g = sns.relplot(
    data=df_lang,
    x="layer_idx",
    y="error",
    hue="method",
    col="model",
    kind="line",
    legend="brief",
    facet_kws={"sharey": True, "sharex": False},
)

g.set_axis_labels("Layer Index", "Cosine Distance")
g.set_titles(col_template="{col_name}")
g.legend.set_title("Method")
g.figure.savefig(
    f"../results/eigcov_estimation_error_lang_layer_wise.pdf",
    dpi=300,
    bbox_inches="tight",
)

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

BASE_FONTSIZE = 24
BATCH_SIZE = 32
NUM_SAMPLES = 10

sns.set_theme(rc={
    "font.size": BASE_FONTSIZE,
    "axes.titlesize": BASE_FONTSIZE,
    "axes.labelsize": BASE_FONTSIZE,
    "xtick.labelsize": BASE_FONTSIZE * 0.8,
    "ytick.labelsize": BASE_FONTSIZE * 0.8,
    "legend.fontsize": BASE_FONTSIZE * 0.8,
    "legend.title_fontsize": BASE_FONTSIZE * 0.8,
})

MODEL_MAP = {"t5-base": "T5-Base", "t5-large": "T5-Large"}

df_lang = pd.read_csv(f"../results/eigcov_estimation_error_lang_n{NUM_SAMPLES}_b{BATCH_SIZE}.csv")
df_lang = df_lang[df_lang["ft_method"] == "standard"]
df_lang = df_lang[df_lang["method"] != "Zeros"]
df_lang["model"] = df_lang["model"].map(MODEL_MAP).fillna(df_lang["model"])

g = sns.catplot(
    data=df_lang,
    x="dataset",
    y="error",
    hue="method",
    col="model",
    kind="bar",
    legend="brief",
    sharey=True,
    hue_order=["EigenCov", "Identity", "Random"],
)

g.set_axis_labels("Dataset", "Cosine Distance")
g.set_titles(col_template="{col_name}")
g.legend.set_title("Method")
g.set_xticklabels(rotation=45, ha="right")
g.figure.savefig(
    f"../results/eigcov_estimation_error_lang_dataset_wise.pdf",
    dpi=300,
    bbox_inches="tight",
)

# %% [markdown]
# ## Fig. 2: (Assumption I) Cross Term Vanishing

# %%
import pandas as pd
import torch

def cosine_similarity(a: torch.Tensor, b: torch.Tensor) -> torch.Tensor:
    return torch.dot(a.flatten(), b.flatten()) / (a.norm() * b.norm())

def dist_cos(A: torch.Tensor, B: torch.Tensor, *args, **kwargs) -> torch.Tensor:
    a = A.flatten()
    b = B.flatten()
    cos_theta = torch.dot(a, b) / (a.norm() * b.norm())
    return 1 - cos_theta

root_dir = "../checkpoints-gcm-e2/ViT-B-16/"
DATASETS = [
    "Cars",
    "DTD",
    "EuroSAT",
    "GTSRB",
    "MNIST",
    "RESISC45",
    "SUN397",
    "SVHN",
]

errors = []
for d in DATASETS:
    for filename in os.listdir(os.path.join(root_dir, d + "Val")):
        if not "grad_cross" in filename:
            continue
        layer_name = filename.replace(".pt", "").replace("grad_cross_matrix_model_visual_transformer_resblocks_", "")
        gcm = torch.load(os.path.join(root_dir, d + "Val", filename))
        error = dist_cos(gcm['M_T_M'], gcm['S_sum'])
        errors.append({"dataset": d, "layer_name": layer_name, "error": error.item()})

df = pd.DataFrame(errors)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

RESULTS_DIR = "../results"
os.makedirs(RESULTS_DIR, exist_ok=True)
df = pd.DataFrame(errors)

plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x="dataset", y="error")
plt.ylim(0, 1.0)
plt.ylabel("Cosine Distance")
plt.xlabel("Dataset")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "cross_term_vanishing_datasets_vit-b-16.png"), bbox_inches="tight")

# %% [markdown]
# ## Fig. 3: (Assumption II) Correlation between Gradients and Activations

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from itertools import product

sns.set_theme()
BASE_FONTSIZE=28

model = "ViT-B-16"
batch_size = 1
num_samples = 100
num_indices = 32
tasks = ["Cars", "DTD", "EuroSAT", "GTSRB", "MNIST", "RESISC45", "SUN397", "SVHN"]
ft_methods = ["standard"]
ignore = ["ln_", "ls_", "conv", "patch_dropout"]

corr = lambda x, y: np.corrcoef(x, y)[0, 1] if x.std() > 0 and y.std() > 0 else 0.0

rows = []
for task, ft_method in product(tasks, ft_methods):
    corr_dir = f"../results-v1/{model}/correlations_b{batch_size}_n{num_samples}_k{num_indices}_ft{ft_method}"
    path = f"{corr_dir}/correlation_{task}.npz"
    if not os.path.exists(path):
        continue
    data = np.load(path)
    # remove "g_sq/" prefix
    layers = [k[5:] for k in data.files if k.startswith("g_sq/")]
    layers = [l for l in layers if not any(ig in l for ig in ignore)]

    for idx_l, l in enumerate(layers):
        g, aat = data[f"g_sq/{l}"], data[f"aat_samples/{l}"]
        N_samples, N_indices = aat.shape
        for idx_i in range(N_indices):
            rho = np.abs(corr(g, aat[:, idx_i]))
            rows.append({'task': task, 'layer': l, 'layer_idx': idx_l, 'entry_idx': idx_i, 'rho': rho, 'ft_method': ft_method})

df = pd.DataFrame(rows)
# print(df)
fig, ax = plt.subplots(figsize=(10, 6))
sns.violinplot(data=df, x="task", y="rho", ax=ax)

ax.set_xlabel("Task", fontsize=BASE_FONTSIZE)
ax.set_ylabel(r"$|\rho|$", fontsize=BASE_FONTSIZE)
ax.tick_params(axis='x', labelsize=BASE_FONTSIZE * 0.8, rotation=45)
ax.tick_params(axis='y', labelsize=BASE_FONTSIZE * 0.8)
# ax.legend(title="FT Method", fontsize=BASE_FONTSIZE * 0.8, title_fontsize=BASE_FONTSIZE * 0.8)
ax.set_ylim(0, 1.0)

plt.tight_layout()
plt.savefig(f"../results-v1/correlation_violin.pdf", dpi=300, bbox_inches='tight')
print(f"Saved to: ../results-v1/{model}/correlation_violin.pdf")
plt.show()

# Print summary
print("\nSummary Statistics (all points):")
print(df.groupby('task')['rho'].describe()[['mean', 'std', '50%', 'max']].round(3).to_string())
print(f"\nOverall mean |ρ|: {df['rho'].mean():.3f}")
print(f"% of all correlations < 0.1: {(df['rho'] < 0.1).mean() * 100:.1f}%")
# Out:
#       task                                              layer  layer_idx  \
# 0     Cars  image_encoder.model.visual.transformer.resbloc...          0
# 1     Cars  image_encoder.model.visual.transformer.resbloc...          0
# 2     Cars  image_encoder.model.visual.transformer.resbloc...          0
# 3     Cars  image_encoder.model.visual.transformer.resbloc...          0
# 4     Cars  image_encoder.model.visual.transformer.resbloc...          0
# ...    ...                                                ...        ...
# 6139  SVHN  image_encoder.model.visual.transformer.resbloc...         23
# 6140  SVHN  image_encoder.model.visual.transformer.resbloc...         23
# 6141  SVHN  image_encoder.model.visual.transformer.resbloc...         23
# 6142  SVHN  image_encoder.model.visual.transformer.resbloc...         23
# 6143  SVHN  image_encoder.model.visual.transformer.resbloc...         23
#
#       entry_idx       rho ft_method
# 0             0  0.080329  standard
# 1             1  0.001194  standard
# 2             2  0.314193  standard
# 3             3  0.022589  standard
# 4             4  0.136961  standard
# ...         ...       ...       ...
# 6139         27  0.134343  standard
# 6140         28  0.108202  standard
# 6141         29  0.004315  standard
# 6142         30  0.049886  standard
# 6143         31  0.051653  standard
#
# [6144 rows x 6 columns]
# Saved to: ../results-v1/ViT-B-16-2026-03-04/correlation_violin.pdf
# Summary Statistics (all points):
#            mean    std    50%    max
# task
# Cars      0.065  0.081  0.041  0.706
# DTD       0.070  0.083  0.044  0.700
# EuroSAT   0.061  0.070  0.041  0.575
# GTSRB     0.076  0.068  0.059  0.524
# MNIST     0.070  0.072  0.049  0.616
# RESISC45  0.068  0.073  0.045  0.554
# SUN397    0.060  0.082  0.034  0.786
# SVHN      0.067  0.068  0.047  0.592
#
# Overall mean |ρ|: 0.067
# % of all correlations < 0.1: 79.7%

# %% [markdown]
# ## Fig. 5: (Assumption III) Covariance Stationarity

# %%
import os
import numpy as np
import pandas as pd
import torch
# from tqdm import tqdm
from tqdm.notebook import tqdm

MODEL_NAME = "ViT-B-16"
RESULTS_DIR = f"../results/{MODEL_NAME}"
NUM_BATCHES = 10
BATCH_SIZE = 32
SPLIT = "train"
MAX_CKPT = 10

COV_PREFIX = f"covariances_s{SPLIT}_n{NUM_BATCHES}_b{BATCH_SIZE}_tsm_attnsplit_efull_ft"

DATASETS = ["Cars", "DTD", "EuroSAT", "GTSRB", "MNIST", "RESISC45", "SUN397", "SVHN"]


# def dist_cos(A, B):
#     a, b = torch.tensor(A).flatten().float(), torch.tensor(B).flatten().float()
#     return (1 - (torch.dot(a, b) / (a.norm() * b.norm())).abs()).item()

def dist_cos(A: torch.Tensor, B: torch.Tensor, *args, **kwargs) -> torch.Tensor:
    a, b = torch.tensor(A).flatten().float(), torch.tensor(B).flatten().float()
    cos_theta = torch.dot(a, b) / (a.norm() * b.norm())
    return (1 - cos_theta)


def cov_dir(ckpt_num):
    return f"{RESULTS_DIR}/{COV_PREFIX}checkpoint_{ckpt_num}"


# Discover checkpoints
checkpoints = sorted(
    int(name.removeprefix(COV_PREFIX + "checkpoint_"))
    for name in os.listdir(RESULTS_DIR)
    if name.startswith(COV_PREFIX + "checkpoint_")
)[:MAX_CKPT]
print(f"Checkpoints: {checkpoints}")
print(f"Reference: checkpoint_{checkpoints[-1]}")

# Compute stationarity errors
rows = []
for dataset in tqdm(DATASETS, desc="Datasets"):
    ref_cov_path = f"{cov_dir(checkpoints[-1])}/covariance_{dataset}.npz"
    print(ref_cov_path)
    ref_covs = np.load(ref_cov_path, allow_pickle=True)

    for ckpt in tqdm(checkpoints, desc=dataset, leave=False):
        path = f"{cov_dir(ckpt)}/covariance_{dataset}.npz"
        if not os.path.exists(path):
            continue
        covs = np.load(path, allow_pickle=True)

        for layer in ref_covs.files:
            if layer not in covs or covs[layer].ndim != 2:
                continue
            rows.append({
                "checkpoint": ckpt,
                "dataset": dataset,
                "layer": layer,
                "error": dist_cos(covs[layer], ref_covs[layer]),
            })

df_ckpt = pd.DataFrame(rows)
df_ckpt.to_csv(f"{RESULTS_DIR}/covariance_stationarity.csv", index=False)
print(df_ckpt.groupby("checkpoint")["error"].mean())
# Out:
# Checkpoints: [0, 200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800]
# Reference: checkpoint_1800
# Datasets:   0%|          | 0/8 [00:00<?, ?it/s]
# ../results/ViT-B-16/covariances_strain_n10_b32_tsm_attnsplit_efull_ftcheckpoint_1800/covariance_Cars.npz
# Cars:   0%|          | 0/10 [00:00<?, ?it/s]
# ../results/ViT-B-16/covariances_strain_n10_b32_tsm_attnsplit_efull_ftcheckpoint_1800/covariance_DTD.npz
# DTD:   0%|          | 0/10 [00:00<?, ?it/s]
# ../results/ViT-B-16/covariances_strain_n10_b32_tsm_attnsplit_efull_ftcheckpoint_1800/covariance_EuroSAT.npz
# EuroSAT:   0%|          | 0/10 [00:00<?, ?it/s]
# ../results/ViT-B-16/covariances_strain_n10_b32_tsm_attnsplit_efull_ftcheckpoint_1800/covariance_GTSRB.npz
# GTSRB:   0%|          | 0/10 [00:00<?, ?it/s]
# ../results/ViT-B-16/covariances_strain_n10_b32_tsm_attnsplit_efull_ftcheckpoint_1800/covariance_MNIST.npz
# MNIST:   0%|          | 0/10 [00:00<?, ?it/s]
# ../results/ViT-B-16/covariances_strain_n10_b32_tsm_attnsplit_efull_ftcheckpoint_1800/covariance_RESISC45.npz
# RESISC45:   0%|          | 0/10 [00:00<?, ?it/s]
# ../results/ViT-B-16/covariances_strain_n10_b32_tsm_attnsplit_efull_ftcheckpoint_1800/covariance_SUN397.npz
# SUN397:   0%|          | 0/10 [00:00<?, ?it/s]
# ../results/ViT-B-16/covariances_strain_n10_b32_tsm_attnsplit_efull_ftcheckpoint_1800/covariance_SVHN.npz
# SVHN:   0%|          | 0/10 [00:00<?, ?it/s]
# checkpoint
# 0       0.264626
# 200     0.219691
# 400     0.175717
# 600     0.158471
# 800     0.137337
# 1000    0.117444
# 1200    0.071549
# 1400    0.038754
# 1600    0.016567
# 1800   -0.000217
# Name: error, dtype: object

# %%
MODEL_NAME = "ViT-B-16"
RESULTS_DIR = f"../results/{MODEL_NAME}"

df_ckpt = pd.read_csv(f"{RESULTS_DIR}/covariance_stationarity.csv")
# Filter to only include certain datasets (e.g., Cars, DTD, EuroSAT)
# datasets_to_plot = ["Cars", "DTD", "EuroSAT"]
# df_ckpt = df_ckpt[df_ckpt["dataset"].isin(datasets_to_plot)]

# ── Plot ──────────────────────────────────────────────────────────────────────
BASE_FONTSIZE = 28
sns.set_theme(rc={
    "font.size": BASE_FONTSIZE,
    "axes.titlesize": BASE_FONTSIZE,
    "axes.labelsize": BASE_FONTSIZE,
    "xtick.labelsize": BASE_FONTSIZE * 0.8,
    "ytick.labelsize": BASE_FONTSIZE * 0.8,
    "legend.fontsize": BASE_FONTSIZE * 0.8,
    "legend.title_fontsize": BASE_FONTSIZE * 0.8,
})

# Rename columns for plotting
df_ckpt = df_ckpt.rename(columns={"error": "Cosine Distance", "checkpoint": "Iteration"})

fig, ax = plt.subplots(figsize=(10, 6))
line = sns.lineplot(data=df_ckpt, x="Iteration", y="Cosine Distance", hue="dataset", ax=ax)
ax.set_xlabel("Iteration")
ax.set_ylabel("Cosine Distance")
ax.set_ylim(0, 1)
plt.xticks(np.arange(0, df_ckpt["Iteration"].max() + 1, 500))

legend = ax.get_legend()
if legend is not None:
    legend.set_title("Dataset")

plt.savefig(f"../results/{MODEL_NAME}/covariance_stationarity.pdf", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Fig. 3 : Accuracy vs. Number of Samples used for Covariance Estimation

# %%
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt

BASE_FONTSIZE = 28

shared_params = {
    "model": "ViT-B-16",
    "split": "train",
    "cov_type": "sm",
    "estimator": "full",
    "finetune_mode": "full",
    "method": "RegMean",
}

rows = [
    {**shared_params, "n": 1, "acc_abs": 0.728, "acc_rel": 0.772},
    {**shared_params, "n": 10, "acc_abs": 0.824, "acc_rel": 0.871},
    {**shared_params, "n": 25, "acc_abs": 0.847, "acc_rel": 0.895},
    {**shared_params, "n": 50, "acc_abs": 0.863, "acc_rel": 0.911},
    {**shared_params, "n": 75, "acc_abs": 0.864, "acc_rel": 0.913},
    {**shared_params, "n": 320, "acc_abs": 0.871, "acc_rel": 0.918},
    {**shared_params, "n": 200, "acc_abs": 0.871, "acc_rel": 0.919},
    {**shared_params, "n": 500, "acc_abs": 0.875, "acc_rel": 0.923},
]

df = pd.DataFrame(rows)

sns.set_theme()
g = sns.relplot(data=df, x="n", y="acc_abs", hue="method", style="method", kind="line", markers=True)
g.set_ylabels("Accuracy", fontsize=BASE_FONTSIZE)
g.set_xlabels("Number of samples", fontsize=BASE_FONTSIZE)
g.ax.tick_params(axis='x', labelsize=BASE_FONTSIZE * 0.8)
g.ax.tick_params(axis='y', labelsize=BASE_FONTSIZE * 0.8)
g.ax.axhline(y=0.87, color=sns.color_palette()[1], linestyle="--", label="EigenCov")
handles, labels = g.ax.get_legend_handles_labels()
g.ax.legend(handles, labels, title="Method", fontsize=BASE_FONTSIZE * 0.7, title_fontsize=BASE_FONTSIZE * 0.7)
g._legend.remove()

# Save as pdf
corr_dir = f"../results"
model = "ViT-B-16"
os.makedirs(corr_dir, exist_ok=True)
plt.savefig(f"{corr_dir}/{model.lower()}_acc_vs_n.pdf", dpi=300, bbox_inches="tight")

# %% [markdown]
# ## Fig. 4: RegMean vs. EigCov estimation

# %%
import os
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

MODEL_NAME = "ViT-B-16"
RESULTS_DIR = f"../results/{MODEL_NAME}"
CHECKPOINT_DIR = f"../checkpoints/{MODEL_NAME}"
FT_METHOD = "standard"
BATCH_SIZE = 1
N_VALS = [1, 10, 100, 500, 1000]
N_MAX = max(N_VALS)
K_VALS = [8, 32, 64]
TASKS = ["Cars", "DTD", "EuroSAT", "GTSRB", "MNIST", "RESISC45", "SUN397", "SVHN"]

param_name_to_module_name = lambda name: "image_encoder." + name.replace(".weight", "")

rows = []
for task in tqdm(TASKS, desc="Tasks"):
    target_path = f"{RESULTS_DIR}/covariances_strain_n{N_MAX}_b{BATCH_SIZE}_tsm_attnsplit_efull_ft{FT_METHOD}/covariance_{task}.npz"
    if not os.path.exists(target_path):
        print(f"Missing target: {target_path}")
        continue
    target_covs = np.load(target_path, allow_pickle=True)

    pretrained_checkpoint = f"{CHECKPOINT_DIR}/{task}Val/zeroshot.pt"
    finetuned_checkpoint = f"{CHECKPOINT_DIR}/{task}Val/finetuned.pt"
    tv = NonLinearTaskVector(pretrained_checkpoint, finetuned_checkpoint)

    layers = [(k, m) for k, m in tv.vector.items() if len(m.shape) == 2 and param_name_to_module_name(k) in target_covs]
    for key, m in tqdm(layers, desc=f"  {task} layers", leave=False):
        kp = param_name_to_module_name(key)
        c_target = torch.from_numpy(target_covs[kp]).float()
        c_ec = (m.T @ m).float()

        for n in N_VALS:
            cov_path = f"{RESULTS_DIR}/covariances_strain_n{n}_b{BATCH_SIZE}_tsm_attnsplit_efull_ft{FT_METHOD}/covariance_{task}.npz"
            if not os.path.exists(cov_path):
                print(f"Missing: {cov_path}")
                continue
            covs = np.load(cov_path, allow_pickle=True)
            if kp not in covs:
                continue
            c_rm = torch.from_numpy(covs[kp]).float()

            for kk in K_VALS:
                rows.append({"task": task, "layer": key, "n": n, "k": kk, "method": "RegMean", "error": dist_fn(c_rm, c_target, kk)})
                rows.append({"task": task, "layer": key, "n": n, "k": kk, "method": "EigenCov", "error": dist_fn(c_ec, c_target, kk)})

df_est = pd.DataFrame(rows)
print(df_est.groupby(["method", "n", "k"])["error"].mean().unstack("method"))

# %%
import os
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import sys

# Add src to path
sys.path.append("..")

from src.vision.task_vectors import NonLinearTaskVector

MODEL_NAME = "ViT-B-16"
RESULTS_DIR = f"../results/{MODEL_NAME}"
CHECKPOINT_DIR = f"../checkpoints/{MODEL_NAME}"
FT_METHOD = "standard"
BATCH_SIZE = 1
N_VALS = [1, 10, 100, 500, 1000]
N_MAX = max(N_VALS)
TASKS = ["Cars", "DTD", "EuroSAT", "GTSRB", "MNIST", "RESISC45", "SUN397", "SVHN"]

param_name_to_module_name = lambda name: "image_encoder." + name.replace(".weight", "")

def frob_error(C, C_target):
    """||C_target - C||_F / ||C_target||_F"""
    diff = torch.linalg.norm(C_target - C, ord="fro")
    norm = torch.linalg.norm(C_target, ord="fro")
    return (diff / norm).item() if norm > 1e-12 else float("nan")

rows = []
for task in tqdm(TASKS, desc="Tasks"):
    # Load target covariance (largest n)
    target_path = f"{RESULTS_DIR}/covariances_strain_n{N_MAX}_b{BATCH_SIZE}_tsm_attnsplit_efull_ft{FT_METHOD}/covariance_{task}.npz"
    if not os.path.exists(target_path):
        print(f"Missing target: {target_path}")
        continue
    target_covs = np.load(target_path, allow_pickle=True)

    # Load task vector and compute c_ec = M.T @ M (constant across n)
    pretrained_checkpoint = f"{CHECKPOINT_DIR}/{task}Val/zeroshot.pt"
    finetuned_checkpoint = f"{CHECKPOINT_DIR}/{task}Val/finetuned.pt"
    tv = NonLinearTaskVector(pretrained_checkpoint, finetuned_checkpoint)

    layers = [(k, m) for k, m in tv.vector.items() if len(m.shape) == 2 and param_name_to_module_name(k) in target_covs]
    for k, m in tqdm(layers, desc=f"  {task} layers", leave=False):
        kp = param_name_to_module_name(k)
        c_target = torch.from_numpy(target_covs[kp]).float()
        c_ec = (m.T @ m).float()
        ec_err = frob_error(c_ec, c_target)

        for n in N_VALS:
            cov_path = f"{RESULTS_DIR}/covariances_strain_n{n}_b{BATCH_SIZE}_tsm_attnsplit_efull_ft{FT_METHOD}/covariance_{task}.npz"
            if not os.path.exists(cov_path):
                print(f"Missing: {cov_path}")
                continue
            covs = np.load(cov_path, allow_pickle=True)
            if kp not in covs:
                continue
            c_rm = torch.from_numpy(covs[kp]).float()
            rows.append({"task": task, "layer": k, "n": n, "method": "RegMean", "error": frob_error(c_rm, c_target)})
            rows.append({"task": task, "layer": k, "n": n, "method": "EigenCov", "error": ec_err})

df_est = pd.DataFrame(rows)
print(df_est.groupby(["method", "n"])["error"].mean().unstack("method"))
# Out:
# Tasks:   0%|          | 0/8 [00:00<?, ?it/s]
#   Cars layers:   0%|          | 0/24 [00:00<?, ?it/s]
#   DTD layers:   0%|          | 0/24 [00:00<?, ?it/s]
#   EuroSAT layers:   0%|          | 0/24 [00:00<?, ?it/s]

# %%
BASE_FONTSIZE = 24

sns.set_theme(rc={
    "font.size": BASE_FONTSIZE,
    "axes.titlesize": BASE_FONTSIZE,
    "axes.labelsize": BASE_FONTSIZE,
    "xtick.labelsize": BASE_FONTSIZE * 0.8,
    "ytick.labelsize": BASE_FONTSIZE * 0.8,
    "legend.fontsize": BASE_FONTSIZE * 0.8,
    "legend.title_fontsize": BASE_FONTSIZE * 0.8,
})

df_plot = df_est.groupby(["method", "n", "k"])["error"].mean().reset_index()

# EigenCov is constant across n; plot as horizontal dashed line per k facet
palette = {"RegMean": sns.color_palette()[0], "EigenCov": sns.color_palette()[1]}

g = sns.relplot(
    data=df_plot[df_plot["method"] == "RegMean"],
    x="n", y="error",
    col="k",
    kind="line",
    markers=True,
    label="RegMean",
    color=palette["RegMean"],
    facet_kws={"sharey": False, "legend_out": True},
)

# Add EigenCov as a horizontal dashed line per facet
for ax, kk in zip(g.axes.flat, K_VALS):
    ec_err = df_plot[(df_plot["method"] == "EigenCov") & (df_plot["k"] == kk)]["error"].mean()
    ax.axhline(ec_err, linestyle="--", color=palette["EigenCov"], label="EigenCov")
    ax.set_xscale("log")
    ax.set_xticks(N_VALS)
    ax.set_xticklabels(N_VALS, rotation=45)

g.axes.flat[0].legend(title="Method")
g.set_axis_labels("Number of Samples ($n$)", "Grassmann Distance")
g.set_titles(col_template="k = {col_name}")

g.figure.savefig(f"{RESULTS_DIR}/regmean_vs_eigcov_grassmann_vs_n.pdf", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Table 1 & 2. Merging Performance on Standard and LoRA finetuning

# %%
import json
import pandas as pd


METRIC = "test_avg_top1"
COLS = ["T5-Base", "T5-Large", "ViT-B/16", "ViT-B/32", "ViT-L/14"]

MODEL_MAP = {
    "t5-base": "T5-Base",
    "t5-large": "T5-Large",
    "T5-Base": "T5-Base",
    "T5-Large": "T5-Large",
    "ViT-B-16": "ViT-B/16",
    "ViT-B-32": "ViT-B/32",
    "ViT-L-14": "ViT-L/14",
}

METHOD_MAP = {
    "mean": "Average",
    "sum": "TA",
    "regmean": "RegMean",
    "eigcov": "EigenCov",
    "tsv": "TSV",
    "isoc_mean": "ISO-C",
    "knots_tsv": "KNOTS-TSV",
    "knots_isoc_mean": "KNOTS-ISO-C",
}

DATA_FREE = {
    "RegMean": True,
    "EigenCov": False,
    "TSV": False,
    "ISO-C": False,
    "KNOTS-TSV": False,
    "KNOTS-ISO-C": False,
}

def get_pivoted_table(ft_mode='lora'):

    with open("../results/results.jsonl", "r") as f:
        df = pd.DataFrame(json.loads(line) for line in f if line.strip())

    # with open("../results/results-hpopt.jsonl", "r") as f:
    #     df = pd.DataFrame(json.loads(line) for line in f if line.strip())

    df = df.copy()
    df["Model"] = df["model"].map(MODEL_MAP).fillna(df["model"])
    df["Method"] = df["merge_func"].map(METHOD_MAP).fillna(df["merge_func"])

    # Filter use only on standard finetuning
    df = df[df['finetuning_mode'] == ft_mode]

    best = df.groupby(["Method", "Model"], as_index=False)[METRIC].max()
    tbl = best.pivot(index="Method", columns="Model", values=METRIC).reindex(columns=COLS)

    # sort by acc on the ViT-B/16 model (descending)
    tbl = tbl.assign(sort_key=tbl["T5-Base"]).sort_values("sort_key", ascending=True).drop(columns="sort_key")

    tbl.insert(0, "Data-free", [r"\xmark" if DATA_FREE.get(m, False) else r"\cmark" for m in tbl.index])
    tbl.insert(0, "Method", [rf"\textsc{{{m}}}" for m in tbl.index])

    for c in COLS:
        tbl[c] = tbl[c].map(lambda x: "" if pd.isna(x) else f"{100*x:.1f}")

    return tbl


from IPython.display import display, Markdown
from IPython.display import display, HTML


def print_nice_latex_table(title, tbl):
    display(Markdown(f"### {title}"))
    display(Markdown("```latex\n" + tbl.reset_index(drop=True).to_latex(index=False, escape=False) + "\n```"))

def styled_table(tbl, title):
    styled = tbl.style.set_caption(title).format(precision=1).set_table_styles([
        {'selector': 'caption',
         'props': [('caption-side', 'top'), ('font-weight', 'bold'), ('font-size', '1.1em')]}
    ])  
    display(styled)

# Print latex tables
print_nice_latex_table("Standard", get_pivoted_table(ft_mode='standard'))
print_nice_latex_table("LoRA", get_pivoted_table(ft_mode='lora'))

# # # Print styled tables
# styled_table(get_pivoted_table(ft_mode='standard'), "Standard Finetuning Results")
# display(HTML("<hr style='margin: 2em 0;' />"))
# styled_table(get_pivoted_table(ft_mode='lora'), "LoRA Finetuning Results")
# Out:
# ### Standard
# ```latex
# \begin{tabular}{lllllll}
# \toprule
# Method & Data-free & T5-Base & T5-Large & ViT-B/16 & ViT-B/32 & ViT-L/14 \\
# \midrule
# \textsc{TA} & \cmark & 60.2 & 60.5 &  &  &  \\
# \textsc{Average} & \cmark & 64.7 & 54.6 &  &  &  \\
# \textsc{ISO-C} & \cmark & 67.4 & 63.5 &  &  &  \\
# \textsc{RegMean} & \xmark & 72.0 & 79.4 &  &  &  \\
# \textsc{TSV} & \cmark & 73.1 & 76.8 &  &  &  \\
# \textsc{EigenCov} & \cmark & 74.0 & 79.8 &  &  &  \\
# \bottomrule
# \end{tabular}
#
# ```
# ### LoRA
# ```latex
# \begin{tabular}{lllllll}
# \toprule
# Method & Data-free & T5-Base & T5-Large & ViT-B/16 & ViT-B/32 & ViT-L/14 \\
# \midrule
# \textsc{TA} & \cmark & 60.2 &  &  &  &  \\
# \textsc{Average} & \cmark & 64.7 &  &  &  &  \\
# \textsc{ISO-C} & \cmark & 67.4 & 63.5 &  &  &  \\
# \textsc{RegMean} & \xmark & 72.4 &  &  &  &  \\
# \textsc{TSV} & \cmark & 73.1 & 76.8 &  &  &  \\
# \textsc{EigenCov} & \cmark & 74.0 & 79.8 &  &  &  \\
# \textsc{KNOTS-ISO-C} & \cmark & 74.1 & 77.5 &  &  &  \\
# \textsc{KNOTS-TSV} & \cmark & 74.4 & 77.9 &  &  &  \\
# \bottomrule
# \end{tabular}
#
# ```

# %%
with open("../results/results-hpopt.jsonl", "r") as f:
    df = pd.DataFrame(json.loads(line) for line in f if line.strip())
df[["model", "merge_func", "finetuning_mode", "test_avg_top1"]]
# Out:
#       model merge_func finetuning_mode  test_avg_top1
# 0  ViT-B-16        sum        standard       0.761121
# 1  ViT-B-32        sum        standard       0.696859
# 2  ViT-L-14        sum        standard       0.842962

# %% [markdown]
# ## MISC

# %%
def dist_gm_proj(A, B, k):
    U_a, _, _ = torch.linalg.svd(A)
    U_b, _, _ = torch.linalg.svd(B)
    k = min(k, U_a.shape[1])
    U_a_k = U_a[:, :k]
    U_b_k = U_b[:, :k]
    sigmas = torch.linalg.svdvals(U_a_k.T @ U_b_k)
    thetas = torch.acos(sigmas.clamp(-1, 1))
    dist = torch.linalg.norm(thetas, ord=2)
    normalized_dist = dist / (math.sqrt(k) * torch.pi / 2)  # ∈ [0, 1]
    return normalized_dist

def dist_proj_residual(A: torch.Tensor, B: torch.Tensor, *args, **kwargs) -> torch.Tensor:
    a = A.flatten()
    b = B.flatten()
    c_opt = torch.dot(a, b) / torch.dot(b, b)
    residual = a - c_opt * b
    return (residual.norm() / a.norm())

def get_k_for_variance(C, threshold):
    """Get k that explains threshold fraction of variance."""
    eigvals = torch.linalg.eigvalsh(C)
    cumvar = eigvals.flip(0).cumsum(0) / eigvals.sum()
    return (cumvar < threshold).sum().item() + 1


dist_rel_err = lambda x, x_hat, *args, **kwargs: (torch.linalg.norm(x - x_hat, ord="fro") / torch.linalg.norm(x, ord="fro"))
def dist_gm_chordal(A, B, k):
    """Grassmann chordal distance between top-k eigenspaces of A and B."""
    _, U_a = torch.linalg.eigh(A.double())
    _, U_b = torch.linalg.eigh(B.double())
    k = min(k, U_a.shape[1])
    U_a = U_a[:, -k:]
    U_b = U_b[:, -k:]
    sigmas = torch.linalg.svdvals(U_a.T @ U_b)
    val = k - (sigmas**2).sum()
    return torch.sqrt(val.clamp(min=0)).item() / math.sqrt(k)
